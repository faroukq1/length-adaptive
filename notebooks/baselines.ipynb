# %% [markdown]
# # Paper Results Collection: Baseline Models Only
#
# **Publication-Ready Results for MovieLens-1M**
#
# ---
#
# ## 📋 Notebook Purpose
#
# This notebook collects **baseline model results** for comparison:
# - **5 Baseline Models:** BERT4Rec, SASRec, GRU4Rec, Caser, LightGCN
#
# **What this notebook generates:**
# 1. ✅ Comprehensive performance comparison tables (5 baseline models)
# 2. ✅ Training dynamics analysis (convergence, epochs)
# 3. ✅ Performance by sequence length (short vs medium)
# 4. ✅ Computational cost analysis (time, memory, parameters)
# 5. ✅ Hyperparameter details
# 6. ✅ Publication-ready figures and tables
# 7. ✅ LaTeX-formatted tables for paper
#
# **Models Evaluated (5 total):**
#
# **Baselines:**
# 1. BERT4Rec (bidirectional transformer)
# 2. SASRec (unidirectional transformer)
# 3. GRU4Rec (RNN-based)
# 4. Caser (CNN-based)
# 5. LightGCN (pure GNN)
#
# **Time: ~7-10 hours on GPU T4**
#
# ---
#
# ## 🎯 Quick Start
#
# 1. **Enable GPU T4** (Runtime → Change runtime type)
# 2. **Enable Internet**
# 3. **Run all cells** sequentially
# 4. **Download paper_results.zip** at the end

# %% [markdown]
# # 🔧 Kaggle Setup
#
# This notebook is designed to run on Kaggle with a GPU (T4 or P100).
# Choose **File → Save Version** to commit all outputs.
#
# **Required Settings:**
# - Accelerator: GPU T4 x2 or P100
# - Internet: ON
# - Persistence: Files only

# %%
# ══════════════════════════════════════════════════════════════
# CONFIG: Change DATASET to '1m' or '100k'
# ══════════════════════════════════════════════════════════════
DATASET = '100k'  # Change to '1m' for MovieLens-1M

import os
IS_KAGGLE = os.path.exists('/kaggle/working')
print(f'Running on Kaggle: {IS_KAGGLE}')
print(f'Dataset: MovieLens-{DATASET.upper()}')

# ── Dataset-specific paths ──
if DATASET == '100k':
    DATA_URL    = 'http://files.grouplens.org/datasets/movielens/ml-100k.zip'
    DATA_FILE   = 'data/ml-100k/processed/sequences.pkl'
    GRAPH_FILE  = 'data/ml-100k/graphs/cooccurrence_graph.pkl'
    RAW_DIR     = 'data/ml-100k/raw'
    RAW_FILE    = 'data/ml-100k/raw/ml-100k/u.data'
    ZIP_NAME    = 'ml-100k'
    PREPROCESS_CMD = 'python -m src.data.preprocess_ml100k'
    GRAPH_CMD   = f'python -m src.data.graph_builder --data_path {DATA_FILE} --output_path {GRAPH_FILE}'
elif DATASET == '1m':
    DATA_URL    = 'http://files.grouplens.org/datasets/movielens/ml-1m.zip'
    DATA_FILE   = 'data/1m/ml-1m/processed/sequences.pkl'
    GRAPH_FILE  = 'data/1m/graphs/cooccurrence_graph.pkl'
    RAW_DIR     = 'data/1m/raw'
    RAW_FILE    = 'data/1m/raw/ml-1m/ratings.dat'
    ZIP_NAME    = 'ml-1m'
    PREPROCESS_CMD = 'python -m src.data.preprocess'
    GRAPH_CMD   = 'python -m src.data.graph_builder'
else:
    raise ValueError(f'Unknown dataset: {DATASET}')

print(f'  Data path: {DATA_FILE}')
print(f'  Graph path: {GRAPH_FILE}')

if IS_KAGGLE:
    os.chdir('/kaggle/working')
    print('Working directory: /kaggle/working')
# Out:
# Running on Kaggle: True
# Dataset: MovieLens-100K
#   Data path: data/ml-100k/processed/sequences.pkl
#   Graph path: data/ml-100k/graphs/cooccurrence_graph.pkl
# Working directory: /kaggle/working

# %% [markdown]
# ## Step 1: Setup Environment

# %%
# Clone repository
import os, subprocess

subprocess.run(['git', 'clone', 'https://github.com/faroukq1/length-adaptive.git'], check=True)

if os.path.exists('/kaggle/working'):
    os.chdir('/kaggle/working/length-adaptive')
else:
    os.chdir('length-adaptive')

# Verify repository structure
subprocess.run(['ls', '-lh', 'scripts/'])

print("\n✅ Repository cloned successfully!")
# Out:
# Cloning into 'length-adaptive'...
# total 8.0K
# -rw-r--r-- 1 root root 4.3K Jun 15 05:32 run_baselines.sh
#
# ✅ Repository cloned successfully!

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
# Install required packages
import subprocess
subprocess.run(['pip', 'install', '-q', 'torch-geometric', 'tqdm',
                'scikit-learn', 'pandas', 'matplotlib', 'seaborn', 'scipy'])

# Verify GPU availability
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")
    major, minor = torch.cuda.get_device_capability(0)
    print(f"Compute Capability: {major}.{minor}")
    if major < 7:
        print("⚠️  GPU compute capability < 7.0 - may need older PyTorch. Upgrade to T4+ if possible.")

print("\n✅ All dependencies installed!")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.8 MB/s eta 0:00:00
# PyTorch version: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4
# GPU Memory: 14.56 GB
# Compute Capability: 7.5
#
# ✅ All dependencies installed!

# %% [markdown]
# ## Step 3: Prepare Data

# %%
import os
import subprocess

print('=' * 70)
print(f'🔍 Checking Data Files (MovieLens-{DATASET.upper()})')
print('=' * 70)

if os.path.exists(DATA_FILE):
    print(f'✅ Sequential data found: {DATA_FILE}')
    print(f'   Size: {os.path.getsize(DATA_FILE) / 1024 / 1024:.2f} MB')
else:
    print(f'❌ Sequential data NOT found: {DATA_FILE}')

if os.path.exists(GRAPH_FILE):
    print(f'✅ Graph data found: {GRAPH_FILE}')
    print(f'   Size: {os.path.getsize(GRAPH_FILE) / 1024 / 1024:.2f} MB')
else:
    print(f'❌ Graph data NOT found: {GRAPH_FILE}')

print('=' * 70)

if not os.path.exists(DATA_FILE) or not os.path.exists(GRAPH_FILE):
    print(f'\n🔧 Setting up data...')

    if not os.path.exists(RAW_FILE):
        print(f'📥 Downloading MovieLens-{DATASET.upper()}...')
        os.makedirs(RAW_DIR, exist_ok=True)
        for cmd in [
            f'wget -q {DATA_URL}',
            f'unzip -q {ZIP_NAME}.zip',
            f'mv {ZIP_NAME} {RAW_DIR}/',
            f'rm -f {ZIP_NAME}.zip',
        ]:
            subprocess.run(cmd, shell=True, check=True)
        print('✅ Download complete!')

    print('🔄 Preprocessing sequences...')
    subprocess.run(PREPROCESS_CMD, shell=True, check=True)

    print('\n🔄 Building co-occurrence graph...')
    subprocess.run(GRAPH_CMD, shell=True, check=True)

    print('\n✅ Data setup complete!')
else:
    print('\n✅ All data files ready!')

print('=' * 70)
# Out:
# ======================================================================
# 🔍 Checking Data Files (MovieLens-100K)
# ======================================================================
# ❌ Sequential data NOT found: data/ml-100k/processed/sequences.pkl
# ❌ Graph data NOT found: data/ml-100k/graphs/cooccurrence_graph.pkl
# ======================================================================
#
# 🔧 Setting up data...
# 📥 Downloading MovieLens-100K...
# ✅ Download complete!
# 🔄 Preprocessing sequences...
# <frozen runpy>:128: RuntimeWarning: 'src.data.preprocess_ml100k' found in sys.modules after import of package 'src.data', but prior to execution of 'src.data.preprocess_ml100k'; this may result in unpredictable behaviour
# ============================================================
# MOVIELENS-100K PREPROCESSING PIPELINE
# ============================================================
# Downloading MovieLens 100K from:
#   https://files.grouplens.org/datasets/movielens/ml-100k.zip
#   Saved to data/ml-100k/raw/ml-100k.zip
#   Already extracted: data/ml-100k/raw/ml-100k/u.data
# Loading ratings …
#   Loaded 100,000 ratings from data/ml-100k/raw/ml-100k/u.data
# Filtering ratings >= 4 …
#   Kept 55,375 positive interactions (55.4%)
# Building chronological sequences …
#   Processing rows: 100%|██████████| 55375/55375 [00:01<00:00, 40769.55it/s]
#   Built sequences for 942 users
# Filtering users with < 5 interactions …
#   Kept 938 users (99.6%)
#   Sequence length — min: 5, max: 378, mean: 59.0, median: 40.0
# Remapping user and item IDs …
#   Remapped → 938 users, 1,447 items
# Splitting into train / val / test (leave-one-out) …
#   Train: 938 users | Val: 938 | Test: 938
#
# Saving to data/ml-100k/processed/sequences.pkl …
# ✅  Preprocessing complete!
#    Users : 938
#    Items : 1,447
# ============================================================
#
# 🔄 Building co-occurrence graph...
# <frozen runpy>:128: RuntimeWarning: 'src.data.graph_builder' found in sys.modules after import of package 'src.data', but prior to execution of 'src.data.graph_builder'; this may result in unpredictable behaviour
# Processing sequences: 100%|██████████| 938/938 [00:00<00:00, 8307.22it/s]
# ============================================================
# CO-OCCURRENCE GRAPH CONSTRUCTION
# ============================================================
# Building co-occurrence graph (window=3)...
# Total unique edges: 59,433
# Pruning edges with count < 5...
# Kept 6,703 edges (11.3%)
#
# Graph Statistics:
# ==================================================
# Number of nodes: 640 / 1,447 items
# Number of edges: 6,703
# Average degree: 20.95
# Degree std: 26.08
# Min degree: 1
# Max degree: 162
#
# Edge weight distribution:
#   Min: 5
#   Max: 155
#   Mean: 8.64
#   Median: 7.00
#   95th percentile: 19.00
#
# Graph density: 0.006407 (0.6407%)
# ==================================================
# Converting to PyTorch Geometric format...
# Edge index shape: torch.Size([2, 13406])
# Edge weight shape: torch.Size([13406])
#
# Saving graph to data/ml-100k/graphs/cooccurrence_graph.pkl...
# ✅ Graph construction complete!
# ============================================================
#
# ✅ Data setup complete!
# ======================================================================

# %% [markdown]
# ## Step 4: Run Baseline Experiments
#
# **Training 5 baseline models with 200 epochs, early stopping (patience=20)**
#
# This is the longest step (~7-10 hours total with GPU T4)

# %%
import time
import os
import subprocess

print("=" * 80)
print("🎓 TRAINING BASELINE MODELS")
print("=" * 80)
print()
print("Training 5 baseline models:")
print()
print("BASELINES:")
print("  1. BERT4Rec (bidirectional transformer)")
print("  2. SASRec (unidirectional transformer)")
print("  3. GRU4Rec (RNN-based)")
print("  4. Caser (CNN-based)")
print("  5. LightGCN (pure GNN)")
print()
print("Configuration:")
print("  - Max epochs: 200")
print("  - Early stopping patience: 20")
print("  - Batch size: 256")
print("  - Learning rate: 0.001")
print("  - d_model: 64, n_heads: 2, n_blocks: 2, gnn_layers: 2")
print()
print("⏱️  Estimated time: 7-10 hours with GPU T4")
print("=" * 80)

# Record start time
start_time = time.time()

# Run baseline experiments only
subprocess.run(['bash', 'scripts/run_baselines.sh'], env={**os.environ, 'DATASET': DATASET})

# Record end time
total_time = time.time() - start_time
print("\n" + "=" * 80)
print("✅ All baseline experiments complete!")
print(f"⏱️  Total time: {total_time / 3600:.2f} hours")
print("=" * 80)
# Out:
# ================================================================================
# 🎓 TRAINING BASELINE MODELS
# ================================================================================
#
# Training 5 baseline models:
#
# BASELINES:
#   1. BERT4Rec (bidirectional transformer)
#   2. SASRec (unidirectional transformer)
#   3. GRU4Rec (RNN-based)
#   4. Caser (CNN-based)
#   5. LightGCN (pure GNN)
#
# Configuration:
#   - Max epochs: 200
#   - Early stopping patience: 20
#   - Batch size: 256
#   - Learning rate: 0.001
#   - d_model: 64, n_heads: 2, n_blocks: 2, gnn_layers: 2
#
# ⏱️  Estimated time: 7-10 hours with GPU T4
# ================================================================================
# ========================================
# PAPER-LEVEL EXPERIMENTS - BASELINES
# ========================================
#
# Working directory: /kaggle/working/length-adaptive
#
# Training with 200 epochs, early stopping patience=20
# Expected to converge at epoch 30-50
#
# Models:
#   Baselines: SASRec, BERT4Rec, GRU4Rec, LightGCN, Caser
#
# ⚠️  Time estimate:
#    GPU: ~5-6 hours total
#    CPU: ~25-30 hours total
#
# Starting experiments...
#
#
# [1/5] Training SASRec (Transformer baseline)...
# Using device: cuda
#
# [1/5] Loading preprocessed data...
#   Users: 938
#   Items: 1,447
#
# [2/5] Loading co-occurrence graph...
#   Edges: 14,854
#
# [3/5] Creating dataloaders...
#   Train batches: 206
#   Val batches: 4
#   Test batches: 4
#
# [4/5] Creating model: sasrec
#   Parameters: 195,840
#   Experiment dir: results/sasrec_20260615_053321
#
# [5/5] Creating trainer...
#
# ============================================================
# TRAINING
# ============================================================
# ============================================================
# STARTING TRAINING
# ============================================================
# Device: cuda
# Model parameters: 195,840
# Training batches: 206
# Validation batches: 4
# ============================================================
# Epoch 1: 100%|██████████| 206/206 [00:03<00:00, 51.95it/s, loss=0.3339]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# [Epoch 1] Evaluating...
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 19.72it/s]
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 27.66it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# [Epoch 1/1] Time: 4.4s
#   Train Loss: 0.4081
#   Val Loss: 0.5017
#   Val HR@10: 0.0362
#   Val NDCG@10: 0.0190
#   Val MRR@10: 0.0137
#   Test NDCG@10: 0.0196
#   ΔNDCG@10: -0.0007
#   ✓ New best! (0.0000 → 0.0190)
#
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Total time: 0.1 minutes
# Best epoch: 1
# Best val NDCG@10: 0.0190
# Delta NDCG@10 at best epoch: -0.0007
# Generalization status: HEALTHY
# ============================================================
#
#
# ============================================================
# TESTING
# ============================================================
# Loading best model...
#
# ============================================================
# TESTING ON TEST SET
# ============================================================
#
# ============================================================
# Test Results
# ============================================================
#   HR@5        : 0.0213
#   NDCG@5      : 0.0132
#   MRR@5       : 0.0105
#   HR@10       : 0.0416
#   NDCG@10     : 0.0196
#   MRR@10      : 0.0131
#   HR@20       : 0.0789
#   NDCG@20     : 0.0290
#   MRR@20      : 0.0157
# ============================================================
#
#
# Computing metrics by user group...
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 26.71it/s]
# ============================================================
# Test Results by User Group
# ============================================================
#
# SHORT:
#   HR@10       : 0.0465
#   NDCG@10     : 0.0251
#   MRR@10      : 0.0187
#   HR@20       : 0.1047
#   NDCG@20     : 0.0402
#   MRR@20      : 0.0231
#   count       : 86
#
# MEDIUM:
#   HR@10       : 0.0411
#   NDCG@10     : 0.0191
#   MRR@10      : 0.0126
#   HR@20       : 0.0763
#   NDCG@20     : 0.0279
#   MRR@20      : 0.0149
#   count       : 852
#
# OVERALL:
#   HR@10       : 0.0416
#   NDCG@10     : 0.0196
#   MRR@10      : 0.0131
#   HR@20       : 0.0789
#   NDCG@20     : 0.0290
#   MRR@20      : 0.0157
#   count       : 938
# ============================================================
#
#
# ✅ Experiment complete! Results saved to: results/sasrec_20260615_053321
#
# ✓ SASRec complete
#
# [2/5] Training BERT4Rec (Bidirectional Transformer)...
# Using device: cuda
#
# [1/5] Loading preprocessed data...
#   Users: 938
#   Items: 1,447
#
# [2/5] Loading co-occurrence graph...
#   Edges: 14,854
#
# [3/5] Creating dataloaders...
#   Train batches: 206
#   Val batches: 4
#   Test batches: 4
#
# [4/5] Creating model: bert4rec
#   Parameters: 195,968
#   Experiment dir: results/bert4rec_20260615_053335
#
# [5/5] Creating trainer...
#
# ============================================================
# TRAINING
# ============================================================
# ============================================================
# STARTING TRAINING
# ============================================================
# Device: cuda
# Model parameters: 195,968
# Training batches: 206
# Validation batches: 4
# ============================================================
# Epoch 1: 100%|██████████| 206/206 [00:03<00:00, 52.26it/s, loss=0.3514]
# Evaluating:  25%|██▌       | 1/4 [00:00<00:00,  9.04it/s]
# [Epoch 1] Evaluating...
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 24.19it/s]
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 27.14it/s]
# [Epoch 1/1] Time: 4.3s
#   Train Loss: 0.4083
#   Val Loss: 0.4893
#   Val HR@10: 0.0373
#   Val NDCG@10: 0.0193
#   Val MRR@10: 0.0139
#   Test NDCG@10: 0.0216
#   ΔNDCG@10: -0.0023
#   ✓ New best! (0.0000 → 0.0193)
#
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Total time: 0.1 minutes
# Best epoch: 1
# Best val NDCG@10: 0.0193
# Delta NDCG@10 at best epoch: -0.0023
# Generalization status: HEALTHY
# ============================================================
#
#
# ============================================================
# TESTING
# ============================================================
# Loading best model...
#
# ============================================================
# TESTING ON TEST SET
# ============================================================
#
# ============================================================
# Test Results
# ============================================================
#   HR@5        : 0.0235
#   NDCG@5      : 0.0139
#   MRR@5       : 0.0108
#   HR@10       : 0.0480
#   NDCG@10     : 0.0216
#   MRR@10      : 0.0139
#   HR@20       : 0.0810
#   NDCG@20     : 0.0298
#   MRR@20      : 0.0160
# ============================================================
#
#
# Computing metrics by user group...
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 27.17it/s]
# ============================================================
# Test Results by User Group
# ============================================================
#
# SHORT:
#   HR@10       : 0.0698
#   NDCG@10     : 0.0333
#   MRR@10      : 0.0225
#   HR@20       : 0.1279
#   NDCG@20     : 0.0475
#   MRR@20      : 0.0261
#   count       : 86
#
# MEDIUM:
#   HR@10       : 0.0458
#   NDCG@10     : 0.0204
#   MRR@10      : 0.0130
#   HR@20       : 0.0763
#   NDCG@20     : 0.0280
#   MRR@20      : 0.0150
#   count       : 852
#
# OVERALL:
#   HR@10       : 0.0480
#   NDCG@10     : 0.0216
#   MRR@10      : 0.0139
#   HR@20       : 0.0810
#   NDCG@20     : 0.0298
#   MRR@20      : 0.0160
#   count       : 938
# ============================================================
#
#
# ✅ Experiment complete! Results saved to: results/bert4rec_20260615_053335
#
# ✓ BERT4Rec complete
#
# [3/5] Training GRU4Rec (RNN baseline)...
# Using device: cuda
#
# [1/5] Loading preprocessed data...
#   Users: 938
#   Items: 1,447
#
# [2/5] Loading co-occurrence graph...
#   Edges: 14,854
#
# [3/5] Creating dataloaders...
#   Train batches: 206
#   Val batches: 4
#   Test batches: 4
#
# [4/5] Creating model: gru4rec
#   Parameters: 117,632
#   Experiment dir: results/gru4rec_20260615_053349
#
# [5/5] Creating trainer...
#
# ============================================================
# TRAINING
# ============================================================
# ============================================================
# STARTING TRAINING
# ============================================================
# Device: cuda
# Model parameters: 117,632
# Training batches: 206
# Validation batches: 4
# ============================================================
# Epoch 1: 100%|██████████| 206/206 [00:04<00:00, 43.67it/s, loss=0.4236]
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 21.83it/s]
# [Epoch 1] Evaluating...
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 27.53it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# [Epoch 1/1] Time: 5.1s
#   Train Loss: 0.4190
#   Val Loss: 0.5599
#   Val HR@10: 0.0384
#   Val NDCG@10: 0.0197
#   Val MRR@10: 0.0140
#   Test NDCG@10: 0.0189
#   ΔNDCG@10: +0.0007
#   ✓ New best! (0.0000 → 0.0197)
#
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Total time: 0.1 minutes
# Best epoch: 1
# Best val NDCG@10: 0.0197
# Delta NDCG@10 at best epoch: +0.0007
# Generalization status: HEALTHY
# ============================================================
#
#
# ============================================================
# TESTING
# ============================================================
# Loading best model...
#
# ============================================================
# TESTING ON TEST SET
# ============================================================
#
# ============================================================
# Test Results
# ============================================================
#   HR@5        : 0.0181
#   NDCG@5      : 0.0123
#   MRR@5       : 0.0103
#   HR@10       : 0.0384
#   NDCG@10     : 0.0189
#   MRR@10      : 0.0131
#   HR@20       : 0.0832
#   NDCG@20     : 0.0299
#   MRR@20      : 0.0160
# ============================================================
#
#
# Computing metrics by user group...
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 27.28it/s]
# ============================================================
# Test Results by User Group
# ============================================================
#
# SHORT:
#   HR@10       : 0.0465
#   NDCG@10     : 0.0265
#   MRR@10      : 0.0205
#   HR@20       : 0.1047
#   NDCG@20     : 0.0404
#   MRR@20      : 0.0240
#   count       : 86
#
# MEDIUM:
#   HR@10       : 0.0376
#   NDCG@10     : 0.0182
#   MRR@10      : 0.0124
#   HR@20       : 0.0810
#   NDCG@20     : 0.0289
#   MRR@20      : 0.0152
#   count       : 852
#
# OVERALL:
#   HR@10       : 0.0384
#   NDCG@10     : 0.0189
#   MRR@10      : 0.0131
#   HR@20       : 0.0832
#   NDCG@20     : 0.0299
#   MRR@20      : 0.0160
#   count       : 938
# ============================================================
#
#
# ✅ Experiment complete! Results saved to: results/gru4rec_20260615_053349
#
# ✓ GRU4Rec complete
#
# [4/5] Training LightGCN (GNN baseline)...
# Using device: cuda
#
# [1/5] Loading preprocessed data...
#   Users: 938
#   Items: 1,447
#
# [2/5] Loading co-occurrence graph...
#   Edges: 14,854
#
# [3/5] Creating dataloaders...
#   Train batches: 206
#   Val batches: 4
#   Test batches: 4
#
# [4/5] Creating model: lightgcn
#   Parameters: 92,737
#   Experiment dir: results/lightgcn_20260615_053403
#
# [5/5] Creating trainer...
# Precomputing LightGCN graph embeddings...
#
# ============================================================
# TRAINING
# ============================================================
# ============================================================
# STARTING TRAINING
# ============================================================
# Device: cuda
# Model parameters: 92,737
# Training batches: 206
# Validation batches: 4
# ============================================================
# Epoch 1: 100%|██████████| 206/206 [00:02<00:00, 91.26it/s, loss=0.7688]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# [Epoch 1] Evaluating...
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 18.84it/s]
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 28.39it/s]
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 28.03it/s]
# [Epoch 1/1] Time: 2.7s
#   Train Loss: 0.5570
#   Val Loss: 0.5685
#   Val HR@10: 0.0512
#   Val NDCG@10: 0.0202
#   Val MRR@10: 0.0111
#   Test NDCG@10: 0.0285
#   ΔNDCG@10: -0.0083
#   ✓ New best! (0.0000 → 0.0202)
#
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Total time: 0.0 minutes
# Best epoch: 1
# Best val NDCG@10: 0.0202
# Delta NDCG@10 at best epoch: -0.0083
# Generalization status: HEALTHY
# ============================================================
#
#
# ============================================================
# TESTING
# ============================================================
# Loading best model...
#
# ============================================================
# TESTING ON TEST SET
# ============================================================
#
# ============================================================
# Test Results
# ============================================================
#   HR@5        : 0.0288
#   NDCG@5      : 0.0193
#   MRR@5       : 0.0162
#   HR@10       : 0.0576
#   NDCG@10     : 0.0285
#   MRR@10      : 0.0200
#   HR@20       : 0.1119
#   NDCG@20     : 0.0424
#   MRR@20      : 0.0239
# ============================================================
#
#
# Computing metrics by user group...
#
# ============================================================
# Test Results by User Group
# ============================================================
#
# SHORT:
#   HR@10       : 0.0930
#   NDCG@10     : 0.0448
#   MRR@10      : 0.0304
#   HR@20       : 0.1279
#   NDCG@20     : 0.0536
#   MRR@20      : 0.0327
#   count       : 86
#
# MEDIUM:
#   HR@10       : 0.0540
#   NDCG@10     : 0.0268
#   MRR@10      : 0.0189
#   HR@20       : 0.1103
#   NDCG@20     : 0.0413
#   MRR@20      : 0.0230
#   count       : 852
#
# OVERALL:
#   HR@10       : 0.0576
#   NDCG@10     : 0.0285
#   MRR@10      : 0.0200
#   HR@20       : 0.1119
#   NDCG@20     : 0.0424
#   MRR@20      : 0.0239
#   count       : 938
# ============================================================
#
#
# ✅ Experiment complete! Results saved to: results/lightgcn_20260615_053403
#
# ✓ LightGCN complete
#
# [5/5] Training Caser (CNN baseline)...
# Using device: cuda
#
# [1/5] Loading preprocessed data...
#   Users: 938
#   Items: 1,447
#
# [2/5] Loading co-occurrence graph...
#   Edges: 14,854
#
# [3/5] Creating dataloaders...
#   Train batches: 206
#   Val batches: 4
#   Test batches: 4
#
# [4/5] Creating model: caser
#   Parameters: 119,124
#   Experiment dir: results/caser_20260615_053416
#
# [5/5] Creating trainer...
#
# ============================================================
# TRAINING
# ============================================================
# ============================================================
# STARTING TRAINING
# ============================================================
# Device: cuda
# Model parameters: 119,124
# Training batches: 206
# Validation batches: 4
# ============================================================
# Epoch 1: 100%|██████████| 206/206 [00:03<00:00, 53.28it/s, loss=0.4462]
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 21.79it/s]
# [Epoch 1] Evaluating...
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 26.75it/s]
# Evaluating:   0%|          | 0/4 [00:00<?, ?it/s]
# [Epoch 1/1] Time: 4.2s
#   Train Loss: 0.5061
#   Val Loss: 0.4583
#   Val HR@10: 0.0522
#   Val NDCG@10: 0.0273
#   Val MRR@10: 0.0198
#   Test NDCG@10: 0.0296
#   ΔNDCG@10: -0.0024
#   ✓ New best! (0.0000 → 0.0273)
#
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Total time: 0.1 minutes
# Best epoch: 1
# Best val NDCG@10: 0.0273
# Delta NDCG@10 at best epoch: -0.0024
# Generalization status: HEALTHY
# ============================================================
#
#
# ============================================================
# TESTING
# ============================================================
# Loading best model...
#
# ============================================================
# TESTING ON TEST SET
# ============================================================
#
# ============================================================
# Test Results
# ============================================================
#   HR@5        : 0.0330
#   NDCG@5      : 0.0214
#   MRR@5       : 0.0176
#   HR@10       : 0.0586
#   NDCG@10     : 0.0296
#   MRR@10      : 0.0209
#   HR@20       : 0.1077
#   NDCG@20     : 0.0417
#   MRR@20      : 0.0241
# ============================================================
#
#
# Computing metrics by user group...
# Evaluating: 100%|██████████| 4/4 [00:00<00:00, 26.88it/s]
# ============================================================
# Test Results by User Group
# ============================================================
#
# SHORT:
#   HR@10       : 0.1047
#   NDCG@10     : 0.0749
#   MRR@10      : 0.0655
#   HR@20       : 0.1395
#   NDCG@20     : 0.0834
#   MRR@20      : 0.0677
#   count       : 86
#
# MEDIUM:
#   HR@10       : 0.0540
#   NDCG@10     : 0.0251
#   MRR@10      : 0.0164
#   HR@20       : 0.1045
#   NDCG@20     : 0.0375
#   MRR@20      : 0.0197
#   count       : 852
#
# OVERALL:
#   HR@10       : 0.0586
#   NDCG@10     : 0.0296
#   MRR@10      : 0.0209
#   HR@20       : 0.1077
#   NDCG@20     : 0.0417
#   MRR@20      : 0.0241
#   count       : 938
# ============================================================
#
#
# ✅ Experiment complete! Results saved to: results/caser_20260615_053416
#
# ✓ Caser complete
#
# ========================================
# ALL BASELINE EXPERIMENTS COMPLETE!
# ========================================
#
# Results saved in: results/
#
# Models trained:
#   ✓ SASRec (Transformer baseline)
#   ✓ BERT4Rec (Bidirectional Transformer)
#   ✓ GRU4Rec (RNN baseline)
#   ✓ LightGCN (GNN baseline)
#   ✓ Caser (CNN baseline)
#
# To analyze results, run:
#   python -m experiments.analyze_results
#
#
# ================================================================================
# ✅ All baseline experiments complete!
# ⏱️  Total time: 0.02 hours
# ================================================================================

# %% [markdown]
# ## Step 5: Collect Results - Performance Metrics
#
# Load all experimental results and create comprehensive comparison tables

# %%
import json
import pandas as pd
import numpy as np
from pathlib import Path

print("=" * 80)
print(" COLLECTING EXPERIMENTAL RESULTS")
print("=" * 80)

results_dir = Path(f'results/hybrid/{DATASET}')

# Baseline models only
all_models = [
    'bert4rec',
    'sasrec',
    'gru4rec',
    'caser',
    'lightgcn',
]

# Collect all results
all_results = []
histories = {}

for results_file in sorted(results_dir.rglob("*/results.json")):
    result_folder = results_file.parent
    config_file   = result_folder / "config.json"
    history_file  = result_folder / "history.json"

    if config_file.exists():
        with open(results_file) as f:
            results = json.load(f)
        with open(config_file) as f:
            config = json.load(f)

        # FIX: config may use 'model_name' or 'model_type' instead of 'model';
        # fall back to inferring from the folder name
        model_name = (
            config.get('model')
            or config.get('model_name')
            or config.get('model_type')
            or next((m for m in all_models if m in result_folder.name.lower()), None)
        )

        if model_name is None:
            print(f"⚠️  Skipping {result_folder.name} — could not determine model name")
            continue

        model_name = model_name.lower()

        # Only include baseline models
        if model_name in all_models:

            # Load training history
            if history_file.exists():
                with open(history_file) as f:
                    histories[model_name] = json.load(f)

            result_data = {
                'Model':      model_name,
                'Model_Type': 'Baseline',
                'Folder':     result_folder.name,

                # Overall metrics
                'HR@5':    results['test_metrics'].get('HR@5',    0),
                'HR@10':   results['test_metrics'].get('HR@10',   0),
                'HR@20':   results['test_metrics'].get('HR@20',   0),
                'NDCG@5':  results['test_metrics'].get('NDCG@5',  0),
                'NDCG@10': results['test_metrics'].get('NDCG@10', 0),
                'NDCG@20': results['test_metrics'].get('NDCG@20', 0),
                'MRR@5':   results['test_metrics'].get('MRR@5',   0),
                'MRR@10':  results['test_metrics'].get('MRR@10',  0),
                'MRR@20':  results['test_metrics'].get('MRR@20',  0),

                # Training info
                'Best_Epoch':       results.get('best_epoch', 0),
                'Best_Val_NDCG@10': results.get('best_val_metric', 0),

                # Config
                'd_model':    config.get('d_model',    64),
                'n_heads':    config.get('n_heads',     2),
                'n_blocks':   config.get('n_blocks',    2),
                'gnn_layers': config.get('gnn_layers',  2),
                'dropout':    config.get('dropout',    0.2),
                'batch_size': config.get('batch_size', 256),
                'lr':         config.get('lr',        0.001),
            }

            # Add group metrics if available
            grouped = results.get("grouped_metrics", {})
            for group in ["short", "medium", "long"]:
                if group in grouped:
                    for metric_k in ["HR@10", "NDCG@10", "MRR@10"]:
                        if metric_k in grouped[group]:
                            result_data[f'{group.capitalize()}_{metric_k}'] = grouped[group][metric_k]
                    if "count" in grouped[group]:
                        result_data[f'{group.capitalize()}_Count'] = grouped[group]['count']

            all_results.append(result_data)

if not all_results:
    print("❌ No results collected — check that results_dir exists and contains results.json files.")
    print(f"   Looking in: {results_dir.resolve()}")
else:
    # Create DataFrame
    df_results = pd.DataFrame(all_results)

    # Sort by NDCG@10 (descending)
    df_results = df_results.sort_values('NDCG@10', ascending=False).reset_index(drop=True)

    print(f"\nCollected results from {len(df_results)} experiments")
    print("\nModels found:")
    print("\nBASELINES:")
    for model in df_results['Model'].values:
        print(f"  - {model}")

    print("\n" + "=" * 80)
    print(" OVERALL PERFORMANCE RANKING (by NDCG@10)")
    print("=" * 80)
    print(df_results[['Model', 'Model_Type', 'NDCG@10', 'HR@10', 'MRR@10', 'Best_Epoch']].to_string(index=False))
    print("=" * 80)

    print(f"\nLoaded {len(histories)} training histories for plotting")
# Out:
# ================================================================================
#  COLLECTING EXPERIMENTAL RESULTS
# ================================================================================
# ⚠️  Skipping bert_hybrid_discrete — could not determine model name
# ⚠️  Skipping bert_hybrid_fixed — could not determine model name
#
# Collected results from 12 experiments
#
# Models found:
#
# BASELINES:
#   - bert4rec
#   - bert4rec
#   - caser
#   - bert4rec
#   - bert4rec
#   - bert4rec
#   - bert4rec
#   - bert4rec
#   - bert4rec
#   - sasrec
#   - lightgcn
#   - gru4rec
#
# ================================================================================
#  OVERALL PERFORMANCE RANKING (by NDCG@10)
# ================================================================================
#    Model Model_Type  NDCG@10    HR@10   MRR@10  Best_Epoch
# bert4rec   Baseline 0.056581 0.120469 0.037720         190
# bert4rec   Baseline 0.055091 0.119403 0.035783          89
#    caser   Baseline 0.053974 0.110874 0.037120          35
# bert4rec   Baseline 0.052895 0.113006 0.034888          70
# bert4rec   Baseline 0.049907 0.108742 0.032497         170
# bert4rec   Baseline 0.048963 0.098081 0.034455          52
# bert4rec   Baseline 0.045312 0.102345 0.028124         125
# bert4rec   Baseline 0.044909 0.094883 0.029922          82
# bert4rec   Baseline 0.042339 0.099147 0.025554          80
#   sasrec   Baseline 0.033913 0.068230 0.023532          19
# lightgcn   Baseline 0.031181 0.068230 0.020205          28
#  gru4rec   Baseline 0.030212 0.065032 0.019825          39
# ================================================================================
#
# Loaded 5 training histories for plotting

# %% [markdown]
# ## Step 5b: Training vs Validation Loss (Overfitting Check)
#
# Plot training and validation loss per epoch for each baseline model.
# A widening gap = overfitting, stable/declining val loss = healthy.

# %%
import matplotlib
matplotlib.use('Agg')  # Non-interactive backend
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_style("whitegrid")

if not histories:
    print("❌ No training histories found!")
else:
    n_models = len(histories)
    fig, axes = plt.subplots(n_models, 2, figsize=(16, 4 * n_models))
    if n_models == 1:
        axes = axes.reshape(1, -1)

    for idx, (model_name, history) in enumerate(sorted(histories.items())):
        ax1 = axes[idx, 0]
        ax2 = axes[idx, 1]

        epochs = list(range(1, len(history['train_loss']) + 1))

        # Plot train vs val loss
        ax1.plot(epochs, history['train_loss'], 'b-', label='Train Loss', linewidth=2, alpha=0.8)
        if history.get('val_loss') and len(history['val_loss']) > 0:
            val_epochs = list(range(1, len(history['val_loss']) + 1))
            ax1.plot(val_epochs, history['val_loss'], 'r-', label='Val Loss', linewidth=2, alpha=0.8)

        ax1.set_xlabel('Epoch', fontsize=11)
        ax1.set_ylabel('BPR Loss', fontsize=11)
        ax1.set_title(f'{model_name}: Train vs Validation Loss', fontsize=12, fontweight='bold')
        ax1.legend(fontsize=10)
        ax1.grid(True, alpha=0.3)

        # Compute overfitting gap
        if history.get('val_loss') and len(history['val_loss']) > 0:
            last_n = min(10, len(history['val_loss']))
            avg_train = np.mean(history['train_loss'][-last_n:])
            avg_val   = np.mean(history['val_loss'][-last_n:])
            gap = avg_val - avg_train
            if gap > 0.10:
                status = "⚠ OVERFITTING"
            elif gap < -0.05:
                status = "⚠ UNDERFITTING"
            else:
                status = "✅ HEALTHY"
            ax1.text(0.95, 0.05, f'{status}\nTrain-Val Gap: {gap:+.4f}',
                     transform=ax1.transAxes, fontsize=10, ha='right', va='bottom',
                     bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.7))

        # Plot val metrics
        val_metrics_list = history.get('val_metrics', [])
        if val_metrics_list:
            val_epochs = list(range(1, len(val_metrics_list) + 1))
            hr10   = [m.get('HR@10',   m.get('hr@10',   0)) for m in val_metrics_list]
            ndcg10 = [m.get('NDCG@10', m.get('ndcg@10', 0)) for m in val_metrics_list]

            ax2.plot(val_epochs, hr10,   'g-',      label='Val HR@10',   linewidth=2)
            ax2.plot(val_epochs, ndcg10, 'orange',  label='Val NDCG@10', linewidth=2)
            ax2.set_xlabel('Epoch', fontsize=11)
            ax2.set_ylabel('Metric Value', fontsize=11)
            ax2.set_title(f'{model_name}: Validation Metrics', fontsize=12, fontweight='bold')
            ax2.legend(fontsize=10)
            ax2.grid(True, alpha=0.3)

            best_idx = np.argmax(ndcg10)
            ax2.axvline(val_epochs[best_idx], color='red', linestyle='--', alpha=0.5,
                        label=f'Best Epoch {val_epochs[best_idx]}')
            ax2.legend(fontsize=10)

    plt.tight_layout()
    import os
    os.makedirs('results', exist_ok=True)
    plt.savefig('results/overfitting_check_baselines.png', dpi=300, bbox_inches='tight')
    plt.show()
    print("✅ Overfitting check plots saved to results/overfitting_check_baselines.png")
# Out:
# ✅ Overfitting check plots saved to results/overfitting_check_baselines.png

# %% [markdown]
# ## Step 5c: Test vs Validation Metrics Comparison
#
# Compare test metrics against best validation metrics to confirm generalization.

# %%
import matplotlib.pyplot as plt
import numpy as np

if not all_results:
    print("❌ No results to compare")
else:
    # Build val summary from histories
    val_summary = {}
    for model_name, history in histories.items():
        val_metrics_list = history.get('val_metrics', [])
        if val_metrics_list:
            ndcg10_vals = [m.get('NDCG@10', m.get('ndcg@10', 0)) for m in val_metrics_list]
            hr10_vals   = [m.get('HR@10',   m.get('hr@10',   0)) for m in val_metrics_list]
            mrr10_vals  = [m.get('MRR@10',  m.get('mrr@10',  0)) for m in val_metrics_list]
            best_idx = np.argmax(ndcg10_vals)
            val_summary[model_name] = {
                'Val HR@10':   hr10_vals[best_idx],
                'Val NDCG@10': ndcg10_vals[best_idx],
                'Val MRR@10':  mrr10_vals[best_idx],
            }

    comparison_data = []
    for _, row in df_results.iterrows():
        model = row['Model']
        entry = {
            'Model':       model,
            'Test HR@10':   row['HR@10'],
            'Test NDCG@10': row['NDCG@10'],
            'Test MRR@10':  row['MRR@10'],
        }
        if model in val_summary:
            entry['Val HR@10']   = val_summary[model]['Val HR@10']
            entry['Val NDCG@10'] = val_summary[model]['Val NDCG@10']
            entry['Val MRR@10']  = val_summary[model]['Val MRR@10']
            entry['Δ HR@10']   = entry['Test HR@10']   - entry['Val HR@10']
            entry['Δ NDCG@10'] = entry['Test NDCG@10'] - entry['Val NDCG@10']
            entry['Δ MRR@10']  = entry['Test MRR@10']  - entry['Val MRR@10']
        comparison_data.append(entry)

    df_comp = pd.DataFrame(comparison_data)

    print("=" * 80)
    print("📊 TEST vs VALIDATION COMPARISON")
    print("=" * 80)
    print(df_comp.to_string(index=False))

    print("\n" + "=" * 80)
    print("🔍 OVERFITTING DIAGNOSIS")
    print("=" * 80)
    for _, row in df_comp.iterrows():
        if 'Δ NDCG@10' in df_comp.columns and not np.isnan(row.get('Δ NDCG@10', float('nan'))):
            delta = row['Δ NDCG@10']
            if delta < -0.02:
                flag = "⚠️ OVERFITTING"
            elif delta < -0.005:
                flag = "⚡ MILD OVERFITTING"
            elif delta > 0.02:
                flag = "⚠️ ANOMALOUS (check eval)"
            else:
                flag = "✅ HEALTHY"
            print(f"  {row['Model']:15s}: ΔNDCG@10={delta:+.4f} — {flag}")
    print("=" * 80)

    # Bar chart
    if 'Δ NDCG@10' in df_comp.columns:
        models_plot = df_comp['Model'].tolist()
        x     = np.arange(len(models_plot))
        width = 0.25

        fig, axes = plt.subplots(1, 3, figsize=(16, 5))

        for ax_idx, metric in enumerate(['HR@10', 'NDCG@10', 'MRR@10']):
            ax       = axes[ax_idx]
            test_vals = df_comp[f'Test {metric}'].values
            val_col  = f'Val {metric}'
            if val_col in df_comp.columns:
                val_vals   = df_comp[val_col].values
                delta_vals = test_vals - val_vals

                ax.bar(x - width / 2, test_vals, width, label='Test', color='#2ecc71', alpha=0.8)
                ax.bar(x + width / 2, val_vals,  width, label='Val',  color='#3498db', alpha=0.8)

                for i, (tv, vv) in enumerate(zip(test_vals, val_vals)):
                    color = 'red' if delta_vals[i] < -0.01 else 'green'
                    ax.annotate(f'{delta_vals[i]:+.3f}', xy=(x[i], max(tv, vv) + 0.003),
                                ha='center', fontsize=8, color=color, fontweight='bold')

            ax.set_xticks(x)
            ax.set_xticklabels(models_plot, rotation=20, ha='right', fontsize=9)
            ax.set_title(f'Test vs Validation {metric}', fontsize=12, fontweight='bold')
            ax.legend(fontsize=9)
            ax.grid(True, alpha=0.3, axis='y')

        plt.tight_layout()
        plt.savefig('results/test_vs_val_comparison.png', dpi=300, bbox_inches='tight')
        plt.show()
        print("\n✅ Test vs Validation comparison saved!")
# Out:
# ================================================================================
# 📊 TEST vs VALIDATION COMPARISON
# ================================================================================
#    Model  Test HR@10  Test NDCG@10  Test MRR@10  Val HR@10  Val NDCG@10  Val MRR@10   Δ HR@10  Δ NDCG@10  Δ MRR@10
# bert4rec    0.120469      0.056581     0.037720   0.118337     0.058652    0.040572  0.002132  -0.002070 -0.002852
# bert4rec    0.119403      0.055091     0.035783   0.118337     0.058652    0.040572  0.001066  -0.003560 -0.004789
#    caser    0.110874      0.053974     0.037120   0.119403     0.055255    0.036256 -0.008529  -0.001281  0.000864
# bert4rec    0.113006      0.052895     0.034888   0.118337     0.058652    0.040572 -0.005330  -0.005757 -0.005684
# bert4rec    0.108742      0.049907     0.032497   0.118337     0.058652    0.040572 -0.009595  -0.008745 -0.008075
# bert4rec    0.098081      0.048963     0.034455   0.118337     0.058652    0.040572 -0.020256  -0.009689 -0.006117
# bert4rec    0.102345      0.045312     0.028124   0.118337     0.058652    0.040572 -0.015991  -0.013340 -0.012448
# bert4rec    0.094883      0.044909     0.029922   0.118337     0.058652    0.040572 -0.023454  -0.013742 -0.010650
# bert4rec    0.099147      0.042339     0.025554   0.118337     0.058652    0.040572 -0.019190  -0.016313 -0.015018
#   sasrec    0.068230      0.033913     0.023532   0.094883     0.046612    0.031981 -0.026652  -0.012699 -0.008449
# lightgcn    0.068230      0.031181     0.020205   0.050107     0.023181    0.015323  0.018124   0.008000  0.004882
#  gru4rec    0.065032      0.030212     0.019825   0.071429     0.032571    0.021282 -0.006397  -0.002359 -0.001457
#
# ================================================================================
# 🔍 OVERFITTING DIAGNOSIS
# ================================================================================
#   bert4rec       : ΔNDCG@10=-0.0021 — ✅ HEALTHY
#   bert4rec       : ΔNDCG@10=-0.0036 — ✅ HEALTHY
#   caser          : ΔNDCG@10=-0.0013 — ✅ HEALTHY
#   bert4rec       : ΔNDCG@10=-0.0058 — ⚡ MILD OVERFITTING
#   bert4rec       : ΔNDCG@10=-0.0087 — ⚡ MILD OVERFITTING
#   bert4rec       : ΔNDCG@10=-0.0097 — ⚡ MILD OVERFITTING
#   bert4rec       : ΔNDCG@10=-0.0133 — ⚡ MILD OVERFITTING
#   bert4rec       : ΔNDCG@10=-0.0137 — ⚡ MILD OVERFITTING
#   bert4rec       : ΔNDCG@10=-0.0163 — ⚡ MILD OVERFITTING
#   sasrec         : ΔNDCG@10=-0.0127 — ⚡ MILD OVERFITTING
#   lightgcn       : ΔNDCG@10=+0.0080 — ✅ HEALTHY
#   gru4rec        : ΔNDCG@10=-0.0024 — ✅ HEALTHY
# ================================================================================
#
# ✅ Test vs Validation comparison saved!

# %% [markdown]
# ## Step 6: Baseline Model Comparison
#
# Compare performance across all baseline models

# %%
import numpy as np

print("=" * 80)
print("📊 BASELINE MODEL COMPARISON")
print("=" * 80)

baselines = df_results[['Model', 'NDCG@10', 'HR@10', 'MRR@10']].copy()

print("\n" + "=" * 80)
print("BASELINE MODELS PERFORMANCE")
print("=" * 80)
print(baselines.to_string(index=False))
print("=" * 80)

# Find best and worst performers
best_model  = baselines.iloc[0]
worst_model = baselines.iloc[-1]

print(f"\n🏆 Best performing baseline: {best_model['Model']}")
print(f"   NDCG@10: {best_model['NDCG@10']:.6f}")
print(f"   HR@10:   {best_model['HR@10']:.6f}")
print(f"   MRR@10:  {best_model['MRR@10']:.6f}")

print(f"\n📊 Lowest performing baseline: {worst_model['Model']}")
print(f"   NDCG@10: {worst_model['NDCG@10']:.6f}")
print(f"   HR@10:   {worst_model['HR@10']:.6f}")
print(f"   MRR@10:  {worst_model['MRR@10']:.6f}")

# Calculate performance gap
gap_ndcg = ((best_model['NDCG@10'] - worst_model['NDCG@10']) / max(worst_model['NDCG@10'], 1e-10)) * 100
gap_hr   = ((best_model['HR@10']   - worst_model['HR@10'])   / max(worst_model['HR@10'],   1e-10)) * 100

print(f"\n📈 Performance gap (best vs worst):")
print(f"   NDCG@10: {gap_ndcg:+.2f}%")
print(f"   HR@10:   {gap_hr:+.2f}%")

# Compare each model to the best
print("\n" + "=" * 80)
print("COMPARISON TO BEST BASELINE")
print("=" * 80)
for _, row in baselines.iterrows():
    if row['Model'] == best_model['Model']:
        print(f"{row['Model']:15s}: BEST PERFORMER")
    else:
        ndcg_diff = ((row['NDCG@10'] - best_model['NDCG@10']) / max(best_model['NDCG@10'], 1e-10)) * 100
        hr_diff   = ((row['HR@10']   - best_model['HR@10'])   / max(best_model['HR@10'],   1e-10)) * 100
        print(f"{row['Model']:15s}: {ndcg_diff:+6.2f}% NDCG@10, {hr_diff:+6.2f}% HR@10")
print("=" * 80)

# Publication-ready table
print("\n📋 PUBLICATION TABLE FORMAT:")
print("-" * 100)
print("Model                          | Type     | NDCG@10      | HR@10        | MRR@10       | Epoch")
print("-" * 100)
for idx, row in df_results.iterrows():
    model      = row['Model']
    model_type = row['Model_Type']
    ndcg       = row['NDCG@10']
    hr         = row['HR@10']
    mrr        = row['MRR@10']
    epoch      = row['Best_Epoch']
    print(f"{model:30s} | {model_type:8s} | {ndcg:.6f}     | {hr:.6f}     | {mrr:.6f}     | {epoch:3d}")
print("-" * 100)
print("=" * 80)
# Out:
# ================================================================================
# 📊 BASELINE MODEL COMPARISON
# ================================================================================
#
# ================================================================================
# BASELINE MODELS PERFORMANCE
# ================================================================================
#    Model  NDCG@10    HR@10   MRR@10
# bert4rec 0.056581 0.120469 0.037720
# bert4rec 0.055091 0.119403 0.035783
#    caser 0.053974 0.110874 0.037120
# bert4rec 0.052895 0.113006 0.034888
# bert4rec 0.049907 0.108742 0.032497
# bert4rec 0.048963 0.098081 0.034455
# bert4rec 0.045312 0.102345 0.028124
# bert4rec 0.044909 0.094883 0.029922
# bert4rec 0.042339 0.099147 0.025554
#   sasrec 0.033913 0.068230 0.023532
# lightgcn 0.031181 0.068230 0.020205
#  gru4rec 0.030212 0.065032 0.019825
# ================================================================================
#
# 🏆 Best performing baseline: bert4rec
#    NDCG@10: 0.056581
#    HR@10:   0.120469
#    MRR@10:  0.037720
#
# 📊 Lowest performing baseline: gru4rec
#    NDCG@10: 0.030212
#    HR@10:   0.065032
#    MRR@10:  0.019825
#
# 📈 Performance gap (best vs worst):
#    NDCG@10: +87.28%
#    HR@10:   +85.25%
#
# ================================================================================
# COMPARISON TO BEST BASELINE
# ================================================================================
# bert4rec       : BEST PERFORMER
# bert4rec       : BEST PERFORMER
# caser          :  -4.61% NDCG@10,  -7.96% HR@10
# bert4rec       : BEST PERFORMER
# bert4rec       : BEST PERFORMER
# bert4rec       : BEST PERFORMER
# bert4rec       : BEST PERFORMER
# bert4rec       : BEST PERFORMER
# bert4rec       : BEST PERFORMER
# sasrec         : -40.06% NDCG@10, -43.36% HR@10
# lightgcn       : -44.89% NDCG@10, -43.36% HR@10
# gru4rec        : -46.60% NDCG@10, -46.02% HR@10
# ================================================================================
#
# 📋 PUBLICATION TABLE FORMAT:
# ----------------------------------------------------------------------------------------------------
# Model                          | Type     | NDCG@10      | HR@10        | MRR@10       | Epoch
# ----------------------------------------------------------------------------------------------------
# bert4rec                       | Baseline | 0.056581     | 0.120469     | 0.037720     | 190
# bert4rec                       | Baseline | 0.055091     | 0.119403     | 0.035783     |  89
# caser                          | Baseline | 0.053974     | 0.110874     | 0.037120     |  35
# bert4rec                       | Baseline | 0.052895     | 0.113006     | 0.034888     |  70
# bert4rec                       | Baseline | 0.049907     | 0.108742     | 0.032497     | 170
# bert4rec                       | Baseline | 0.048963     | 0.098081     | 0.034455     |  52
# bert4rec                       | Baseline | 0.045312     | 0.102345     | 0.028124     | 125
# bert4rec                       | Baseline | 0.044909     | 0.094883     | 0.029922     |  82
# bert4rec                       | Baseline | 0.042339     | 0.099147     | 0.025554     |  80
# sasrec                         | Baseline | 0.033913     | 0.068230     | 0.023532     |  19
# lightgcn                       | Baseline | 0.031181     | 0.068230     | 0.020205     |  28
# gru4rec                        | Baseline | 0.030212     | 0.065032     | 0.019825     |  39
# ----------------------------------------------------------------------------------------------------
# ================================================================================

# %% [markdown]
# ## Step 7: Performance by Sequence Length
#
# Detailed analysis of short vs medium sequence performance

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 6)
plt.rcParams['font.size'] = 11

print("=" * 80)
print("👥 PERFORMANCE BY SEQUENCE LENGTH")
print("=" * 80)

# Check if we have group metrics
has_groups = 'Short_NDCG@10' in df_results.columns or 'short_NDCG@10' in df_results.columns


def get_col(df, prefix, base):
    """Return the first matching column for (prefix, base) pair."""
    col = f'{prefix}_{base}'
    if col in df.columns:
        return col
    col_lower = f'{prefix.lower()}_{base}'
    if col_lower in df.columns:
        return col_lower
    return None


if has_groups:
    short_col  = get_col(df_results, 'Short',  'NDCG@10')  # FIX: separate short/medium lookups
    med_col    = get_col(df_results, 'Medium', 'NDCG@10')
    hr_short   = get_col(df_results, 'Short',  'HR@10')

    if short_col:
        print("\nSHORT SEQUENCES (<10 items):")
        print("-" * 80)
        short_cols = [c for c in [short_col, hr_short] if c]
        short_df   = df_results[['Model', 'Model_Type'] + short_cols].copy()
        print(short_df.sort_values(short_col, ascending=False).to_string(index=False))
    print("=" * 80)
else:
    print("\n⚠️ No grouped metrics found. Models may not have compute_by_group=True results.")
    print("   Will create overall-only visualizations.")
    short_col = None
    med_col   = None

# Visualization
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

models       = df_results['Model'].values.copy()
overall_ndcg = df_results['NDCG@10'].values.copy()

sort_idx     = np.argsort(overall_ndcg)[::-1]
models       = models[sort_idx]
overall_ndcg = overall_ndcg[sort_idx]

x     = np.arange(len(models))
width = 0.25

# Grouped bars if available; otherwise overall only
if has_groups and short_col and med_col:
    short_ndcg  = df_results[short_col].values[sort_idx]
    medium_ndcg = df_results[med_col].values[sort_idx]
    axes[0].bar(x - width, short_ndcg,  width, label='Short (<10)',    color='steelblue', alpha=0.7)
    axes[0].bar(x,         medium_ndcg, width, label='Medium (10-50)', color='navy',      alpha=0.7)
else:
    axes[0].bar(x, overall_ndcg, width * 2, label='Overall', color='steelblue', alpha=0.7)

axes[0].bar(x + width, overall_ndcg, width, label='Overall', color='gray', alpha=0.7)
axes[0].set_xlabel('Model')
axes[0].set_ylabel('NDCG@10')
axes[0].set_title('NDCG@10 Comparison (Baseline Models)')
axes[0].set_xticks(x)                                        # FIX: was missing set_xticks
axes[0].set_xticklabels(models, rotation=45, ha='right')
axes[0].legend()
axes[0].grid(axis='y', alpha=0.3)

# Convergence plot
epochs = df_results['Best_Epoch'].values[sort_idx]
colors = ['steelblue', 'navy', 'darkgreen', 'maroon', 'darkorange'][:len(models)]
axes[1].bar(np.arange(len(models)), epochs, alpha=0.7, color=colors)
axes[1].set_xlabel('Model')
axes[1].set_ylabel('Best Epoch')
axes[1].set_title('Convergence Speed (Lower = Faster)')
axes[1].set_xticks(np.arange(len(models)))                  # FIX: set_xticks before labels
axes[1].set_xticklabels(models, rotation=45, ha='right')
axes[1].grid(axis='y', alpha=0.3)
for i, e in enumerate(epochs):
    axes[1].text(i, e + 1, str(int(e)), ha='center', fontsize=9)

plt.tight_layout()
plt.savefig('results/baselines_overview.png', dpi=300, bbox_inches='tight')
print("\n✅ Figure saved: results/baselines_overview.png")
plt.show()
# Out:
# ================================================================================
# 👥 PERFORMANCE BY SEQUENCE LENGTH
# ================================================================================
#
# SHORT SEQUENCES (<10 items):
# --------------------------------------------------------------------------------
#    Model Model_Type  Short_NDCG@10  Short_HR@10
# bert4rec   Baseline       0.128149     0.220930
# bert4rec   Baseline       0.127697     0.220930
# bert4rec   Baseline       0.112151     0.232558
# bert4rec   Baseline       0.106146     0.186047
# bert4rec   Baseline       0.103835     0.209302
# bert4rec   Baseline       0.097746     0.186047
# bert4rec   Baseline       0.093656     0.197674
# bert4rec   Baseline       0.093023     0.197674
#    caser   Baseline       0.092148     0.174419
#   sasrec   Baseline       0.077581     0.151163
# lightgcn   Baseline       0.062375     0.127907
#  gru4rec   Baseline       0.043519     0.093023
# ================================================================================
#
# ✅ Figure saved: results/baselines_overview.png

# %% [markdown]
# ## Step 8: Training Dynamics Analysis
#
# Analyze convergence speed, best epochs, and validation performance

# %%
import matplotlib.pyplot as plt

print("=" * 80)
print("📈 TRAINING DYNAMICS ANALYSIS")
print("=" * 80)

training_stats = df_results[['Model', 'Best_Epoch', 'Best_Val_NDCG@10']].copy()
training_stats = training_stats.sort_values('Best_Epoch')

print("\nCONVERGENCE ANALYSIS (sorted by convergence speed):")
print("-" * 80)
print(training_stats.to_string(index=False))
print("-" * 80)

fastest = training_stats.iloc[0]
slowest = training_stats.iloc[-1]
print(f"\nFastest convergence: {fastest['Model']} (epoch {fastest['Best_Epoch']})")
print(f"Slowest convergence: {slowest['Model']} (epoch {slowest['Best_Epoch']})")
print(f"Average convergence: {training_stats['Best_Epoch'].mean():.1f} epochs")

best_val = df_results.sort_values('Best_Val_NDCG@10', ascending=False).iloc[0]
print(f"\nBest validation NDCG@10: {best_val['Model']} ({best_val['Best_Val_NDCG@10']:.6f})")

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

models_t = training_stats['Model'].values
epochs_t = training_stats['Best_Epoch'].values
axes[0].barh(models_t, epochs_t, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Best Epoch')
axes[0].set_ylabel('Model')
axes[0].set_title('Convergence Speed (Lower is Faster)')
axes[0].grid(axis='x', alpha=0.3)

val_perf  = df_results['Best_Val_NDCG@10'].values
test_perf = df_results['NDCG@10'].values
axes[1].scatter(val_perf, test_perf, s=100, alpha=0.7)
for i, model in enumerate(df_results['Model'].values):
    axes[1].annotate(model, (val_perf[i], test_perf[i]),
                     fontsize=8, ha='right', va='bottom')
axes[1].set_xlabel('Validation NDCG@10')
axes[1].set_ylabel('Test NDCG@10')
axes[1].set_title('Validation vs Test Performance')
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('results/training_dynamics.png', dpi=300, bbox_inches='tight')
print("\n✅ Figure saved: results/training_dynamics.png")
plt.show()
# Out:
# ================================================================================
# 📈 TRAINING DYNAMICS ANALYSIS
# ================================================================================
#
# CONVERGENCE ANALYSIS (sorted by convergence speed):
# --------------------------------------------------------------------------------
#    Model  Best_Epoch  Best_Val_NDCG@10
#   sasrec          19          0.046612
# lightgcn          28          0.023181
#    caser          35          0.055255
#  gru4rec          39          0.032571
# bert4rec          52          0.000000
# bert4rec          70          0.058642
# bert4rec          80          0.058652
# bert4rec          82          0.060912
# bert4rec          89          0.000000
# bert4rec         125          0.054466
# bert4rec         170          0.054652
# bert4rec         190          0.055475
# --------------------------------------------------------------------------------
#
# Fastest convergence: sasrec (epoch 19)
# Slowest convergence: bert4rec (epoch 190)
# Average convergence: 81.6 epochs
#
# Best validation NDCG@10: bert4rec (0.060912)
#
# ✅ Figure saved: results/training_dynamics.png

# %% [markdown]
# ## Step 9: Computational Cost Analysis
#
# Analyze parameters, memory usage, and training efficiency

# %%
import sys
import torch
import matplotlib.pyplot as plt
import numpy as np

sys.path.insert(0, '/kaggle/working/length-adaptive')

from src.models.bert4rec import BERT4Rec
from src.models.sasrec   import SASRec
from src.models.gru4rec  import GRU4Rec
from src.models.caser    import Caser
from src.models.lightgcn import LightGCN

print("=" * 80)
print("💻 COMPUTATIONAL COST ANALYSIS")
print("=" * 80)

num_items  = 3706   # MovieLens-1M item count
d_model    = 64
n_heads    = 2
n_blocks   = 2
gnn_layers = 2
max_len    = 50

computational_costs = []

def count_params(model):
    total     = sum(p.numel() for p in model.parameters())
    trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return total, trainable

print("\nAnalyzing BERT4Rec...")
m = BERT4Rec(num_items, d_model, n_heads, n_blocks, max_len=max_len)
total, trainable = count_params(m)
computational_costs.append({'Model': 'bert4rec', 'Model_Type': 'Baseline',
                             'Total_Params': total, 'Trainable_Params': trainable,
                             'Params_M': total / 1e6})

print("Analyzing SASRec...")
m = SASRec(num_items, d_model, n_heads, n_blocks, max_len=max_len)
total, trainable = count_params(m)
computational_costs.append({'Model': 'sasrec', 'Model_Type': 'Baseline',
                             'Total_Params': total, 'Trainable_Params': trainable,
                             'Params_M': total / 1e6})

print("Analyzing GRU4Rec...")
m = GRU4Rec(num_items, d_model, n_blocks)
total, trainable = count_params(m)
computational_costs.append({'Model': 'gru4rec', 'Model_Type': 'Baseline',
                             'Total_Params': total, 'Trainable_Params': trainable,
                             'Params_M': total / 1e6})

print("Analyzing Caser...")
m = Caser(num_items, d_model, max_len=max_len)
total, trainable = count_params(m)
computational_costs.append({'Model': 'caser', 'Model_Type': 'Baseline',
                             'Total_Params': total, 'Trainable_Params': trainable,
                             'Params_M': total / 1e6})

print("Analyzing LightGCN...")
m = LightGCN(num_items, d_model, gnn_layers)
total, trainable = count_params(m)
computational_costs.append({'Model': 'lightgcn', 'Model_Type': 'Baseline',
                             'Total_Params': total, 'Trainable_Params': trainable,
                             'Params_M': total / 1e6})

df_costs = pd.DataFrame(computational_costs)

# Aggregate df_results to one row per model to avoid cartesian explosion on merge
df_agg = df_results.groupby('Model', as_index=False).agg({
    'NDCG@10': 'mean',
    'Best_Epoch': 'max',
    'Model_Type': 'first',
})

# Merge epoch info
df_costs = df_costs.merge(df_agg[['Model', 'Best_Epoch']], on='Model', how='left')

print("\n" + "=" * 80)
print("MODEL SIZE COMPARISON")
print("=" * 80)
print("\nBASELINES:")
print(df_costs[['Model', 'Total_Params', 'Params_M']].to_string(index=False))

print("\n" + "=" * 80)
print("PARAMETER BREAKDOWN:")
print("-" * 80)
for _, row in df_costs.iterrows():
    print(f"{row['Model']:30s}: {int(row['Total_Params']):>10,} params")
print("=" * 80)

# Merge performance
df_costs = df_costs.merge(df_agg[['Model', 'NDCG@10', 'Model_Type']], on='Model', how='left')
df_costs['Efficiency'] = df_costs['NDCG@10'] / df_costs['Params_M']

print("\nEFFICIENCY ANALYSIS (NDCG@10 per million parameters):")
print("-" * 80)
df_eff = df_costs[['Model', 'Model_Type', 'NDCG@10', 'Params_M', 'Efficiency']].copy()
df_eff = df_eff.sort_values('Efficiency', ascending=False)
print(df_eff.to_string(index=False))
print("=" * 80)

# Visualization
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

models_c  = df_costs['Model'].values
params_m  = df_costs['Params_M'].values
sort_idx  = np.argsort(params_m)

axes[0].barh(range(len(models_c)), params_m[sort_idx], color='steelblue', alpha=0.7)
axes[0].set_yticks(range(len(models_c)))
axes[0].set_yticklabels(models_c[sort_idx])
axes[0].set_xlabel('Parameters (millions)')
axes[0].set_title('Model Size Comparison (Baseline Models)')
axes[0].grid(axis='x', alpha=0.3)

ndcg_c = df_costs['NDCG@10'].values
axes[1].scatter(params_m, ndcg_c, s=150, alpha=0.7, c='steelblue', marker='o')
for i, model in enumerate(models_c):
    axes[1].annotate(model, (params_m[i], ndcg_c[i]),
                     fontsize=9, ha='right', va='bottom')
axes[1].set_xlabel('Parameters (millions)')
axes[1].set_ylabel('NDCG@10')
axes[1].set_title('Performance vs Model Size (Baseline Models)')
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('results/computational_costs.png', dpi=300, bbox_inches='tight')
print("\n\u2705 Figure saved: results/computational_costs.png")
plt.show()
# Out:
# ================================================================================
# 💻 COMPUTATIONAL COST ANALYSIS
# ================================================================================
#
# Analyzing BERT4Rec...
# Analyzing SASRec...
# Analyzing GRU4Rec...
# Analyzing Caser...
# Analyzing LightGCN...
#
# ================================================================================
# MODEL SIZE COMPARISON
# ================================================================================
#
# BASELINES:
#    Model  Total_Params  Params_M
# bert4rec        340544  0.340544
# bert4rec        340544  0.340544
# bert4rec        340544  0.340544
# bert4rec        340544  0.340544
# bert4rec        340544  0.340544
# bert4rec        340544  0.340544
# bert4rec        340544  0.340544
# bert4rec        340544  0.340544
#   sasrec        340416  0.340416
#  gru4rec        287168  0.287168
#    caser        263700  0.263700
# lightgcn        237248  0.237248
#
# ================================================================================
# PARAMETER BREAKDOWN:
# --------------------------------------------------------------------------------
# bert4rec                      :    340,544 params
# bert4rec                      :    340,544 params
# bert4rec                      :    340,544 params
# bert4rec                      :    340,544 params
# bert4rec                      :    340,544 params
# bert4rec                      :    340,544 params
# bert4rec                      :    340,544 params
# bert4rec                      :    340,544 params
# sasrec                        :    340,416 params
# gru4rec                       :    287,168 params
# caser                         :    263,700 params
# lightgcn                      :    237,248 params
# ================================================================================
#
# EFFICIENCY ANALYSIS (NDCG@10 per million parameters):
# --------------------------------------------------------------------------------
#    Model Model_Type  NDCG@10  Params_M  Efficiency
#    caser   Baseline 0.053974  0.263700    0.204680
# bert4rec   Baseline 0.056581  0.340544    0.166150
# bert4rec   Baseline 0.056581  0.340544    0.166150
# bert4rec   Baseline 0.056581  0.340544    0.166150
# bert4rec   Baseline 0.056581  0.340544    0.166150
# bert4rec   Baseline 0.056581  0.340544    0.166150
# bert4rec   Baseline 0.056581  0.340544    0.166150
# bert4rec   Baseline 0.056581  0.340544    0.166150
# bert4rec   Baseline 0.056581  0.340544    0.166150
# bert4rec   Baseline 0.055091  0.340544    0.161774
# bert4rec   Baseline 0.055091  0.340544    0.161774
# bert4rec   Baseline 0.055091  0.340544    0.161774
# bert4rec   Baseline 0.055091  0.340544    0.161774
# bert4rec   Baseline 0.055091  0.340544    0.161774
# bert4rec   Baseline 0.055091  0.340544    0.161774
# bert4rec   Baseline 0.055091  0.340544    0.161774
# bert4rec   Baseline 0.055091  0.340544    0.161774
# bert4rec   Baseline 0.052895  0.340544    0.155324
# bert4rec   Baseline 0.052895  0.340544    0.155324
# bert4rec   Baseline 0.052895  0.340544    0.155324
# bert4rec   Baseline 0.052895  0.340544    0.155324
# bert4rec   Baseline 0.052895  0.340544    0.155324
# bert4rec   Baseline 0.052895  0.340544    0.155324
# bert4rec   Baseline 0.052895  0.340544    0.155324
# bert4rec   Baseline 0.052895  0.340544    0.155324
# bert4rec   Baseline 0.049907  0.340544    0.146550
# bert4rec   Baseline 0.049907  0.340544    0.146550
# bert4rec   Baseline 0.049907  0.340544    0.146550
# bert4rec   Baseline 0.049907  0.340544    0.146550
# bert4rec   Baseline 0.049907  0.340544    0.146550
# bert4rec   Baseline 0.049907  0.340544    0.146550
# bert4rec   Baseline 0.049907  0.340544    0.146550
# bert4rec   Baseline 0.049907  0.340544    0.146550
# bert4rec   Baseline 0.048963  0.340544    0.143779
# bert4rec   Baseline 0.048963  0.340544    0.143779
# bert4rec   Baseline 0.048963  0.340544    0.143779
# bert4rec   Baseline 0.048963  0.340544    0.143779
# bert4rec   Baseline 0.048963  0.340544    0.143779
# bert4rec   Baseline 0.048963  0.340544    0.143779
# bert4rec   Baseline 0.048963  0.340544    0.143779
# bert4rec   Baseline 0.048963  0.340544    0.143779
# bert4rec   Baseline 0.045312  0.340544    0.133057
# bert4rec   Baseline 0.045312  0.340544    0.133057
# bert4rec   Baseline 0.045312  0.340544    0.133057
# bert4rec   Baseline 0.045312  0.340544    0.133057
# bert4rec   Baseline 0.045312  0.340544    0.133057
# bert4rec   Baseline 0.045312  0.340544    0.133057
# bert4rec   Baseline 0.045312  0.340544    0.133057
# bert4rec   Baseline 0.045312  0.340544    0.133057
# bert4rec   Baseline 0.044909  0.340544    0.131875
# bert4rec   Baseline 0.044909  0.340544    0.131875
# bert4rec   Baseline 0.044909  0.340544    0.131875
# bert4rec   Baseline 0.044909  0.340544    0.131875
# bert4rec   Baseline 0.044909  0.340544    0.131875
# bert4rec   Baseline 0.044909  0.340544    0.131875
# bert4rec   Baseline 0.044909  0.340544    0.131875
# bert4rec   Baseline 0.044909  0.340544    0.131875
# lightgcn   Baseline 0.031181  0.237248    0.131428
# bert4rec   Baseline 0.042339  0.340544    0.124326
# bert4rec   Baseline 0.042339  0.340544    0.124326
# bert4rec   Baseline 0.042339  0.340544    0.124326
# bert4rec   Baseline 0.042339  0.340544    0.124326
# bert4rec   Baseline 0.042339  0.340544    0.124326
# bert4rec   Baseline 0.042339  0.340544    0.124326
# bert4rec   Baseline 0.042339  0.340544    0.124326
# bert4rec   Baseline 0.042339  0.340544    0.124326
#  gru4rec   Baseline 0.030212  0.287168    0.105208
#   sasrec   Baseline 0.033913  0.340416    0.099621
# ================================================================================
#
# ✅ Figure saved: results/computational_costs.png

# %% [markdown]
# ## Step 10: Export Results for Paper
#
# Generate publication-ready tables in multiple formats (CSV, LaTeX, Markdown)

# %%
import os

print("=" * 80)
print("📝 EXPORTING PUBLICATION-READY TABLES")
print("=" * 80)

os.makedirs('paper_results', exist_ok=True)

# 1. Main results table
main_results = df_results[['Model', 'Model_Type',
                            'HR@5',   'HR@10',   'HR@20',
                            'NDCG@5', 'NDCG@10', 'NDCG@20',
                            'MRR@5',  'MRR@10',  'MRR@20',
                            'Best_Epoch']].copy()

main_results.to_csv('paper_results/table1_main_results.csv', index=False, float_format='%.6f')
print("✅ Saved: paper_results/table1_main_results.csv")

latex_main = main_results.to_latex(index=False, float_format='%.4f',
                                   caption='Overall Performance Comparison (Baseline Models)',
                                   label='tab:main_results')
with open('paper_results/table1_main_results.tex', 'w') as f:
    f.write(latex_main)
print("✅ Saved: paper_results/table1_main_results.tex")

# 2. Sequence length analysis
# FIX: check whether grouped metric columns exist before accessing them
length_cols = {
    'Short_HR@10':    'Short_HR@10',
    'Short_NDCG@10':  'Short_NDCG@10',
    'Short_MRR@10':   'Short_MRR@10',
    'Medium_HR@10':   'Medium_HR@10',
    'Medium_NDCG@10': 'Medium_NDCG@10',
    'Medium_MRR@10':  'Medium_MRR@10',
}
available_len_cols = {k: v for k, v in length_cols.items() if v in df_results.columns}

if available_len_cols:
    length_analysis = df_results[['Model', 'Model_Type'] + list(available_len_cols.values())].copy()
    length_analysis.to_csv('paper_results/table2_length_analysis.csv', index=False, float_format='%.6f')
    print("✅ Saved: paper_results/table2_length_analysis.csv")

    latex_length = length_analysis.to_latex(index=False, float_format='%.4f',
                                            caption='Performance by Sequence Length (Baseline Models)',
                                            label='tab:length_analysis')
    with open('paper_results/table2_length_analysis.tex', 'w') as f:
        f.write(latex_length)
    print("✅ Saved: paper_results/table2_length_analysis.tex")
else:
    print("⚠️  Skipping table2_length_analysis — no grouped metrics available.")

# 3. Computational costs
comp_results = df_costs[['Model', 'Model_Type', 'Total_Params', 'Params_M',
                          'Best_Epoch', 'NDCG@10', 'Efficiency']].copy()
comp_results.to_csv('paper_results/table3_computational_costs.csv', index=False, float_format='%.6f')
print("✅ Saved: paper_results/table3_computational_costs.csv")

latex_costs = comp_results.to_latex(index=False, float_format='%.4f',
                                    caption='Computational Cost Analysis (Baseline Models)',
                                    label='tab:computational_costs')
with open('paper_results/table3_computational_costs.tex', 'w') as f:
    f.write(latex_costs)
print("✅ Saved: paper_results/table3_computational_costs.tex")

# 4. Summary markdown (FIX: removed duplicate table1 entry in file list)
best_model  = df_results.iloc[0]
worst_model = df_results.iloc[-1]

summary_md = f"""# Paper Results Summary - Baseline Models

## Dataset
- **Name:** MovieLens-{DATASET.upper()}
- **Users:** 6,040
- **Items:** 3,706
- **Interactions:** 1,000,209
- **Test Users:** 6,034
- **Short Sequences (<10):** 162 users (2.7%)
- **Medium Sequences (10-50):** 5,872 users (97.3%)

## Models Evaluated (5 baselines)
1. BERT4Rec (bidirectional transformer)
2. SASRec (unidirectional transformer)
3. GRU4Rec (RNN-based)
4. Caser (CNN-based)
5. LightGCN (pure GNN)

## Best Results

### Overall Performance (NDCG@10)
- **Best Baseline:**  {best_model['Model']} ({best_model['NDCG@10']:.6f})
- **Worst Baseline:** {worst_model['Model']} ({worst_model['NDCG@10']:.6f})

### Performance Gap
- **NDCG@10:** {((best_model['NDCG@10'] - worst_model['NDCG@10']) / max(worst_model['NDCG@10'], 1e-10) * 100):.2f}%
- **HR@10:**   {((best_model['HR@10']   - worst_model['HR@10'])   / max(worst_model['HR@10'],   1e-10) * 100):.2f}%
- **MRR@10:**  {((best_model['MRR@10']  - worst_model['MRR@10'])  / max(worst_model['MRR@10'],  1e-10) * 100):.2f}%

## Key Findings

1. **Best Performing Model:** {best_model['Model']}
   - NDCG@10: {best_model['NDCG@10']:.6f}
   - HR@10:   {best_model['HR@10']:.6f}
   - MRR@10:  {best_model['MRR@10']:.6f}

2. **Parameter Efficiency:**
   - Smallest model: {df_costs.loc[df_costs['Total_Params'].idxmin(), 'Model']} ({int(df_costs['Total_Params'].min()):,} parameters)
   - Largest model:  {df_costs.loc[df_costs['Total_Params'].idxmax(), 'Model']} ({int(df_costs['Total_Params'].max()):,} parameters)

3. **Convergence Speed:**
   - Average best epoch: {df_results['Best_Epoch'].mean():.1f}
   - Range: {df_results['Best_Epoch'].min()}–{df_results['Best_Epoch'].max()} epochs

## Files Generated

### Tables (CSV + LaTeX)
- `table1_main_results`        — Overall performance metrics (5 baseline models)
- `table2_length_analysis`     — Performance by sequence length
- `table3_computational_costs` — Model size and efficiency

### Figures (PNG, 300 DPI)
- `baselines_overview.png`          — NDCG@10 comparison by sequence length
- `training_dynamics.png`           — Convergence and validation analysis
- `computational_costs.png`         — Parameter and efficiency analysis
- `overfitting_check_baselines.png` — Train vs validation loss
- `test_vs_val_comparison.png`      — Test vs validation comparison

### Raw Data
- All experimental results in results/ directory
- Per-model config, history, and results JSON files
"""

with open('paper_results/README.md', 'w') as f:
    f.write(summary_md)
print("✅ Saved: paper_results/README.md")

print("\n" + "=" * 80)
print("✅ ALL TABLES AND FIGURES EXPORTED")
print("=" * 80)
print("\nGenerated files:")
print("  📊 3 CSV files (Excel-compatible)")
print("  📄 3 LaTeX files (ready for paper)")
print("  📈 5 PNG figures (300 DPI, publication quality)")
print("  📝 1 Summary README")
print("\nLocation: paper_results/")
print("=" * 80)
# Out:
# ================================================================================
# 📝 EXPORTING PUBLICATION-READY TABLES
# ================================================================================
# ✅ Saved: paper_results/table1_main_results.csv
# ✅ Saved: paper_results/table1_main_results.tex
# ✅ Saved: paper_results/table2_length_analysis.csv
# ✅ Saved: paper_results/table2_length_analysis.tex
# ✅ Saved: paper_results/table3_computational_costs.csv
# ✅ Saved: paper_results/table3_computational_costs.tex
# ✅ Saved: paper_results/README.md
#
# ================================================================================
# ✅ ALL TABLES AND FIGURES EXPORTED
# ================================================================================
#
# Generated files:
#   📊 3 CSV files (Excel-compatible)
#   📄 3 LaTeX files (ready for paper)
#   📈 5 PNG figures (300 DPI, publication quality)
#   📝 1 Summary README
#
# Location: paper_results/
# ================================================================================

# %% [markdown]
# ## Step 11: Create Downloadable Archive
#
# Package all results, figures, and tables for easy download

# %%
import os
import subprocess

os.makedirs('final_package', exist_ok=True)

# Copy all paper-ready materials
subprocess.run('cp -r paper_results final_package/',       shell=True)
subprocess.run('cp -r results/*.png final_package/ 2>/dev/null || true', shell=True)
subprocess.run('cp results/*_comparison_*.csv final_package/paper_results/ 2>/dev/null || true', shell=True)

# Copy experimental results (baseline models only)
os.makedirs('final_package/raw_results', exist_ok=True)
for model_prefix in ['bert4rec', 'sasrec', 'gru4rec', 'caser', 'lightgcn']:
    subprocess.run(f'cp -r results/{model_prefix}_* final_package/raw_results/ 2>/dev/null || true', shell=True)

# Create archive
subprocess.run(['zip', '-r', 'paper_results_package.zip', 'final_package/'], check=True)

print("=" * 80)
print("📦 FINAL PACKAGE CREATED")
print("=" * 80)
print("\n✅ File: paper_results_package.zip")
print("\nContents:")
print("  📁 paper_results/")
print("     ├── table1_main_results.csv + .tex (5 baseline models)")
print("     ├── table2_length_analysis.csv + .tex")
print("     ├── table3_computational_costs.csv + .tex")
print("     ├── baselines_overview.png")
print("     ├── training_dynamics.png")
print("     ├── computational_costs.png")
print("     ├── overfitting_check_baselines.png")
print("     ├── test_vs_val_comparison.png")
print("     └── README.md")
print("  📁 raw_results/")
print("     ├── bert4rec_*/")
print("     ├── sasrec_*/")
print("     ├── gru4rec_*/")
print("     ├── caser_*/")
print("     └── lightgcn_*/")
print()
print("📥 Download this file to use in your paper!")
print("=" * 80)

# FIX: was two print() calls on same line → SyntaxError
file_size = os.path.getsize('paper_results_package.zip') / 1024 / 1024
print(f"\nPackage size: {file_size:.2f} MB")
# Out:
#   adding: final_package/ (stored 0%)
#   adding: final_package/training_dynamics.png (deflated 20%)
#   adding: final_package/test_vs_val_comparison.png (deflated 21%)
#   adding: final_package/baselines_overview.png (deflated 24%)
#   adding: final_package/raw_results/ (stored 0%)
#   adding: final_package/raw_results/caser_20260615_053416/ (stored 0%)
#   adding: final_package/raw_results/caser_20260615_053416/history.json (deflated 57%)
#   adding: final_package/raw_results/caser_20260615_053416/results.json (deflated 64%)
#   adding: final_package/raw_results/caser_20260615_053416/best_model.pt (deflated 9%)
#   adding: final_package/raw_results/caser_20260615_053416/config.json (deflated 49%)
#   adding: final_package/raw_results/caser_20260615_053416/checkpoint.pt (deflated 9%)
#   adding: final_package/raw_results/gru4rec_20260615_053349/ (stored 0%)
#   adding: final_package/raw_results/gru4rec_20260615_053349/history.json (deflated 58%)
#   adding: final_package/raw_results/gru4rec_20260615_053349/results.json (deflated 65%)
#   adding: final_package/raw_results/gru4rec_20260615_053349/best_model.pt (deflated 8%)
#   adding: final_package/raw_results/gru4rec_20260615_053349/config.json (deflated 49%)
#   adding: final_package/raw_results/gru4rec_20260615_053349/checkpoint.pt (deflated 8%)
#   adding: final_package/raw_results/sasrec_20260615_053321/ (stored 0%)
#   adding: final_package/raw_results/sasrec_20260615_053321/history.json (deflated 57%)
#   adding: final_package/raw_results/sasrec_20260615_053321/results.json (deflated 65%)
#   adding: final_package/raw_results/sasrec_20260615_053321/best_model.pt (deflated 9%)
#   adding: final_package/raw_results/sasrec_20260615_053321/config.json (deflated 49%)
#   adding: final_package/raw_results/sasrec_20260615_053321/checkpoint.pt (deflated 9%)
#   adding: final_package/raw_results/lightgcn_20260615_053403/ (stored 0%)
#   adding: final_package/raw_results/lightgcn_20260615_053403/history.json (deflated 57%)
#   adding: final_package/raw_results/lightgcn_20260615_053403/results.json (deflated 64%)
#   adding: final_package/raw_results/lightgcn_20260615_053403/best_model.pt (deflated 8%)
#   adding: final_package/raw_results/lightgcn_20260615_053403/config.json (deflated 49%)
#   adding: final_package/raw_results/lightgcn_20260615_053403/checkpoint.pt (deflated 8%)
#   adding: final_package/raw_results/bert4rec_20260615_053335/ (stored 0%)
#   adding: final_package/raw_results/bert4rec_20260615_053335/history.json (deflated 57%)
#   adding: final_package/raw_results/bert4rec_20260615_053335/results.json (deflated 64%)
#   adding: final_package/raw_results/bert4rec_20260615_053335/best_model.pt (deflated 9%)
#   adding: final_package/raw_results/bert4rec_20260615_053335/config.json (deflated 49%)
#   adding: final_package/raw_results/bert4rec_20260615_053335/checkpoint.pt (deflated 9%)
#   adding: final_package/overfitting_check_baselines.png (deflated 13%)
#   adding: final_package/paper_results/ (stored 0%)
#   adding: final_package/paper_results/table1_main_results.csv (deflated 59%)
#   adding: final_package/paper_results/table3_computational_costs.tex (deflated 88%)
#   adding: final_package/paper_results/table2_length_analysis.csv (deflated 59%)
#   adding: final_package/paper_results/README.md (deflated 50%)
#   adding: final_package/paper_results/table3_computational_costs.csv (deflated 88%)
#   adding: final_package/paper_results/table2_length_analysis.tex (deflated 63%)
#   adding: final_package/paper_results/table1_main_results.tex (deflated 65%)
#   adding: final_package/computational_costs.png (deflated 26%)
# ================================================================================
# 📦 FINAL PACKAGE CREATED
# ================================================================================
#
# ✅ File: paper_results_package.zip
#
# Contents:
#   📁 paper_results/
#      ├── table1_main_results.csv + .tex (5 baseline models)
#      ├── table2_length_analysis.csv + .tex
#      ├── table3_computational_costs.csv + .tex
#      ├── baselines_overview.png
#      ├── training_dynamics.png
#      ├── computational_costs.png
#      ├── overfitting_check_baselines.png
#      ├── test_vs_val_comparison.png
#      └── README.md
#   📁 raw_results/
#      ├── bert4rec_*/
#      ├── sasrec_*/
#      ├── gru4rec_*/
#      ├── caser_*/
#      └── lightgcn_*/
#
# 📥 Download this file to use in your paper!
# ================================================================================
#
# Package size: 15.97 MB

# %% [markdown]
# ## 📋 Final Summary
#
# ### ✅ What Was Collected:
#
# 1. **Performance Metrics**
#    - Overall test performance (HR@5/10/20, NDCG@5/10/20, MRR@5/10/20)
#    - Performance by sequence length (short vs medium)
#    - Baseline model comparisons
#
# 2. **Training Analysis**
#    - Convergence speed (best epochs)
#    - Validation performance tracking
#    - Training vs validation loss (overfitting check)
#
# 3. **Computational Costs**
#    - Model parameters (total and trainable) for all 5 baseline models
#    - Parameter comparison analysis
#    - Efficiency metrics (performance per parameter)
#
# 4. **Publication Materials**
#    - CSV tables (Excel-compatible)
#    - LaTeX tables (ready for paper)
#    - High-resolution figures (300 DPI PNG)
#    - Summary documentation
#
# ### 📊 Models Compared:
#
# **Baselines (5):**
# - BERT4Rec
# - SASRec
# - GRU4Rec
# - Caser
# - LightGCN
#
# ### 📥 Next Steps:
#
# 1. Download `paper_results_package.zip`
# 2. Review all tables and figures
# 3. Use LaTeX tables directly in your paper
# 4. Include figures with captions
# 5. Use these baseline results to compare with hybrid models
#
# **Ready for paper submission!** 🎉

# %%
import os
import subprocess

if os.path.exists('/kaggle/working'):
    subprocess.run(['zip', '-r',
                    '/kaggle/working/length-adaptive.zip',
                    '/kaggle/working/length-adaptive'])
    print("✅ Full project archived for Kaggle download")
else:
    print("ℹ️ Not running on Kaggle, skipping full archive")
# Out:
#   adding: kaggle/working/length-adaptive/ (stored 0%)
#   adding: kaggle/working/length-adaptive/experiments/ (stored 0%)
#   adding: kaggle/working/length-adaptive/experiments/__pycache__/ (stored 0%)
#   adding: kaggle/working/length-adaptive/experiments/__pycache__/run_experiment.cpython-312.pyc (deflated 55%)
#   adding: kaggle/working/length-adaptive/experiments/run_experiment.py (deflated 74%)
#   adding: kaggle/working/length-adaptive/experiments/run_best_models.py (deflated 74%)
#   adding: kaggle/working/length-adaptive/src/ (stored 0%)
#   adding: kaggle/working/length-adaptive/src/models/ (stored 0%)
#   adding: kaggle/working/length-adaptive/src/models/bert4rec.py (deflated 73%)
#   adding: kaggle/working/length-adaptive/src/models/caser.py (deflated 70%)
#   adding: kaggle/working/length-adaptive/src/models/lightgcn.py (deflated 64%)
#   adding: kaggle/working/length-adaptive/src/models/__pycache__/ (stored 0%)
#   adding: kaggle/working/length-adaptive/src/models/__pycache__/lightgcn_seq.cpython-312.pyc (deflated 49%)
#   adding: kaggle/working/length-adaptive/src/models/__pycache__/tcn_bert4rec.cpython-312.pyc (deflated 54%)
#   adding: kaggle/working/length-adaptive/src/models/__pycache__/lightgcn.cpython-312.pyc (deflated 45%)
#   adding: kaggle/working/length-adaptive/src/models/__pycache__/bert4rec_hybrid.cpython-312.pyc (deflated 50%)
#   adding: kaggle/working/length-adaptive/src/models/__pycache__/bert4rec.cpython-312.pyc (deflated 57%)
#   adding: kaggle/working/length-adaptive/src/models/__pycache__/sasrec.cpython-312.pyc (deflated 57%)
#   adding: kaggle/working/length-adaptive/src/models/__pycache__/gru4rec.cpython-312.pyc (deflated 47%)
#   adding: kaggle/working/length-adaptive/src/models/__pycache__/caser.cpython-312.pyc (deflated 54%)
#   adding: kaggle/working/length-adaptive/src/models/__pycache__/tgt_bert4rec.cpython-312.pyc (deflated 60%)
#   adding: kaggle/working/length-adaptive/src/models/__pycache__/fusion.cpython-312.pyc (deflated 61%)
#   adding: kaggle/working/length-adaptive/src/models/__pycache__/__init__.cpython-312.pyc (deflated 34%)
#   adding: kaggle/working/length-adaptive/src/models/fusion.py (deflated 76%)
#   adding: kaggle/working/length-adaptive/src/models/bert4rec_hybrid.py (deflated 71%)
#   adding: kaggle/working/length-adaptive/src/models/tgt_bert4rec.py (deflated 77%)
#   adding: kaggle/working/length-adaptive/src/models/lightgcn_seq.py (deflated 70%)
#   adding: kaggle/working/length-adaptive/src/models/gru4rec.py (deflated 68%)
#   adding: kaggle/working/length-adaptive/src/models/__init__.py (deflated 63%)
#   adding: kaggle/working/length-adaptive/src/models/sasrec.py (deflated 73%)
#   adding: kaggle/working/length-adaptive/src/models/tcn_bert4rec.py (deflated 74%)
#   adding: kaggle/working/length-adaptive/src/__pycache__/ (stored 0%)
#   adding: kaggle/working/length-adaptive/src/__pycache__/__init__.cpython-312.pyc (deflated 20%)
#   adding: kaggle/working/length-adaptive/src/data/ (stored 0%)
#   adding: kaggle/working/length-adaptive/src/data/preprocess.py (deflated 69%)
#   adding: kaggle/working/length-adaptive/src/data/__pycache__/ (stored 0%)
#   adding: kaggle/working/length-adaptive/src/data/__pycache__/graph_builder.cpython-312.pyc (deflated 52%)
#   adding: kaggle/working/length-adaptive/src/data/__pycache__/preprocess_ml100k.cpython-312.pyc (deflated 49%)
#   adding: kaggle/working/length-adaptive/src/data/__pycache__/dataloader.cpython-312.pyc (deflated 50%)
#   adding: kaggle/working/length-adaptive/src/data/__pycache__/preprocess.cpython-312.pyc (deflated 50%)
#   adding: kaggle/working/length-adaptive/src/data/__pycache__/__init__.cpython-312.pyc (deflated 28%)
#   adding: kaggle/working/length-adaptive/src/data/graph_builder.py (deflated 69%)
#   adding: kaggle/working/length-adaptive/src/data/preprocess_ml100k.py (deflated 72%)
#   adding: kaggle/working/length-adaptive/src/data/__init__.py (deflated 56%)
#   adding: kaggle/working/length-adaptive/src/data/dataloader.py (deflated 72%)
#   adding: kaggle/working/length-adaptive/src/__init__.py (stored 0%)
#   adding: kaggle/working/length-adaptive/src/eval/ (stored 0%)
#   adding: kaggle/working/length-adaptive/src/eval/__pycache__/ (stored 0%)
#   adding: kaggle/working/length-adaptive/src/eval/__pycache__/evaluator.cpython-312.pyc (deflated 54%)
#   adding: kaggle/working/length-adaptive/src/eval/__pycache__/metrics.cpython-312.pyc (deflated 56%)
#   adding: kaggle/working/length-adaptive/src/eval/__pycache__/__init__.cpython-312.pyc (deflated 19%)
#   adding: kaggle/working/length-adaptive/src/eval/metrics.py (deflated 72%)
#   adding: kaggle/working/length-adaptive/src/eval/__init__.py (stored 0%)
#   adding: kaggle/working/length-adaptive/src/eval/evaluator.py (deflated 73%)
#   adding: kaggle/working/length-adaptive/src/train/ (stored 0%)
#   adding: kaggle/working/length-adaptive/src/train/__pycache__/ (stored 0%)
#   adding: kaggle/working/length-adaptive/src/train/__pycache__/trainer.cpython-312.pyc (deflated 57%)
#   adding: kaggle/working/length-adaptive/src/train/__pycache__/loss.cpython-312.pyc (deflated 56%)
#   adding: kaggle/working/length-adaptive/src/train/__pycache__/__init__.cpython-312.pyc (deflated 19%)
#   adding: kaggle/working/length-adaptive/src/train/trainer.py (deflated 77%)
#   adding: kaggle/working/length-adaptive/src/train/loss.py (deflated 70%)
#   adding: kaggle/working/length-adaptive/src/train/__init__.py (stored 0%)
#   adding: kaggle/working/length-adaptive/requirements.txt (deflated 3%)
#   adding: kaggle/working/length-adaptive/notebooks/ (stored 0%)
#   adding: kaggle/working/length-adaptive/notebooks/baselines.ipynb (deflated 78%)
#   adding: kaggle/working/length-adaptive/notebooks/hybrid_run_100k.ipynb (deflated 30%)
#   adding: kaggle/working/length-adaptive/notebooks/hybrid_run_1m.ipynb (deflated 29%)
#   adding: kaggle/working/length-adaptive/notebooks/compare_base_hybrid_100k.ipynb (deflated 31%)
#   adding: kaggle/working/length-adaptive/notebooks/compare_base_hybrid_1m.ipynb (deflated 31%)
#   adding: kaggle/working/length-adaptive/prompt_craft/ (stored 0%)
#   adding: kaggle/working/length-adaptive/prompt_craft/bar_beauty_metrics.png (deflated 16%)
#   adding: kaggle/working/length-adaptive/prompt_craft/promptcraft_seqrec_context.md (deflated 59%)
#   adding: kaggle/working/length-adaptive/prompt_craft/embedding_quality.json (deflated 67%)
#   adding: kaggle/working/length-adaptive/prompt_craft/promptcraft_beauty_summary.csv (deflated 45%)
#   adding: kaggle/working/length-adaptive/prompt_craft/claude_code_prompt_seqrec.md (deflated 67%)
#   adding: kaggle/working/length-adaptive/prompt_craft/promptcraft_beauty_results.json (deflated 74%)
#   adding: kaggle/working/length-adaptive/prompt_craft/promptcraft_seqrec_kaggle.ipynb (deflated 49%)
#   adding: kaggle/working/length-adaptive/paper_results/ (stored 0%)
#   adding: kaggle/working/length-adaptive/paper_results/table1_main_results.csv (deflated 59%)
#   adding: kaggle/working/length-adaptive/paper_results/table3_computational_costs.tex (deflated 88%)
#   adding: kaggle/working/length-adaptive/paper_results/table2_length_analysis.csv (deflated 59%)
#   adding: kaggle/working/length-adaptive/paper_results/README.md (deflated 50%)
#   adding: kaggle/working/length-adaptive/paper_results/table3_computational_costs.csv (deflated 88%)
#   adding: kaggle/working/length-adaptive/paper_results/table2_length_analysis.tex (deflated 63%)
#   adding: kaggle/working/length-adaptive/paper_results/table1_main_results.tex (deflated 65%)
#   adding: kaggle/working/length-adaptive/data/ (stored 0%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/ (stored 0%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/processed/ (stored 0%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/processed/sequences.pkl (deflated 44%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/graphs/ (stored 0%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/graphs/cooccurrence_graph.pkl (deflated 76%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ (stored 0%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/ (stored 0%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/ub.test (deflated 65%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/allbut.pl (deflated 50%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u1.test (deflated 69%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u2.test (deflated 68%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u5.test (deflated 67%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u.user (deflated 65%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/README (deflated 60%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u4.base (deflated 71%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u1.base (deflated 72%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u.info (deflated 6%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u2.base (deflated 71%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u.item (deflated 80%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/ua.base (deflated 72%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u3.test (deflated 67%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u.occupation (deflated 36%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u4.test (deflated 67%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u.data (deflated 58%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u5.base (deflated 71%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/ub.base (deflated 72%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/ua.test (deflated 65%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u3.base (deflated 71%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/mku.sh (deflated 63%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k/u.genre (deflated 19%)
#   adding: kaggle/working/length-adaptive/data/ml-100k/raw/ml-100k.zip (stored 0%)
#   adding: kaggle/working/length-adaptive/results/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/caser_20260615_053416/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/caser_20260615_053416/history.json (deflated 57%)
#   adding: kaggle/working/length-adaptive/results/caser_20260615_053416/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/caser_20260615_053416/best_model.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/results/caser_20260615_053416/config.json (deflated 49%)
#   adding: kaggle/working/length-adaptive/results/caser_20260615_053416/checkpoint.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/results/hybrid/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/bert4rec/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/bert4rec/history.json (deflated 75%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/bert4rec/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/bert4rec/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/caser/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/caser/history.json (deflated 74%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/caser/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/caser/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/bert_hybrid_discrete/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/bert_hybrid_discrete/history.json (deflated 75%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/bert_hybrid_discrete/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/bert_hybrid_discrete/config.json (deflated 52%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/tcn_bert4rec/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/tcn_bert4rec/history.json (deflated 75%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/tcn_bert4rec/results.json (deflated 62%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/tcn_bert4rec/config.json (deflated 51%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/bert_hybrid_fixed/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/bert_hybrid_fixed/history.json (deflated 74%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/bert_hybrid_fixed/results.json (deflated 62%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/bert_hybrid_fixed/config.json (deflated 52%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/gru4rec/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/gru4rec/history.json (deflated 75%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/gru4rec/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/gru4rec/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/lightgcn/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/lightgcn/history.json (deflated 81%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/lightgcn/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/lightgcn/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/sasrec/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/sasrec/history.json (deflated 73%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/sasrec/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/sasrec/checkpoint_epoch_20.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/sasrec/checkpoint_epoch_10.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/sasrec/checkpoint_epoch_30.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/sasrec/best_model.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/sasrec/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/sasrec/checkpoint.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/tgt_bert4rec/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/tgt_bert4rec/history.json (deflated 75%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/tgt_bert4rec/results.json (deflated 62%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/hybrid/tgt_bert4rec/config.json (deflated 51%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p3_user_centric/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p3_user_centric/history.json (deflated 70%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p3_user_centric/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p3_user_centric/config.json (deflated 59%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft/summary_20260407_120003.json (deflated 77%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft/summary_20260407_120003.csv (deflated 50%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_baseline/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_baseline/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_baseline/results.json (deflated 63%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_baseline/config.json (deflated 56%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p2_title_genre/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p2_title_genre/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p2_title_genre/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p2_title_genre/config.json (deflated 59%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p4_hybrid/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p4_hybrid/history.json (deflated 70%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p4_hybrid/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p4_hybrid/config.json (deflated 58%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p1_title_only/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p1_title_only/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p1_title_only/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/hybrid/100k/prompt/promptcraft_p1_title_only/config.json (deflated 58%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/hyperparameters.csv (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/group_HR10.png (deflated 18%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/group_metrics_short.csv (deflated 50%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/group_MRR20.png (deflated 20%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/group_metrics_overall.csv (deflated 50%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/training_summary.csv (deflated 27%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/group_metrics_medium.csv (deflated 49%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/group_NDCG20.png (deflated 19%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/group_MRR10.png (deflated 19%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/test_metrics_improvements.csv (deflated 49%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/test_metrics.csv (deflated 51%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/training_loss_curves.png (deflated 12%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/group_NDCG10.png (deflated 20%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/heatmap_all_test_metrics.png (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/group_HR20.png (deflated 19%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_100k/val_ndcg10_curves.png (deflated 5%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/hyperparameters.csv (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/group_HR10.png (deflated 19%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/group_metrics_short.csv (deflated 49%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/group_MRR20.png (deflated 19%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/group_metrics_overall.csv (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/training_summary.csv (deflated 28%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/group_metrics_medium.csv (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/group_NDCG20.png (deflated 19%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/group_MRR10.png (deflated 19%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/test_metrics_improvements.csv (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/test_metrics.csv (deflated 49%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/training_loss_curves.png (deflated 15%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/group_NDCG10.png (deflated 19%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/heatmap_all_test_metrics.png (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/group_HR20.png (deflated 19%)
#   adding: kaggle/working/length-adaptive/results/hybrid/comparison_output_1m/val_ndcg10_curves.png (deflated 6%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert4rec/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert4rec/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert4rec/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert4rec/checkpoint_epoch_60.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert4rec/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/caser/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/caser/history.json (deflated 72%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/caser/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/caser/checkpoint_epoch_80.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/caser/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert_hybrid_discrete/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert_hybrid_discrete/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert_hybrid_discrete/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert_hybrid_discrete/checkpoint_epoch_80.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert_hybrid_discrete/config.json (deflated 52%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/tcn_bert4rec/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/tcn_bert4rec/history.json (deflated 72%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/tcn_bert4rec/results.json (deflated 62%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/tcn_bert4rec/config.json (deflated 51%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/tcn_bert4rec/checkpoint_epoch_100.pt (deflated 11%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert_hybrid_fixed/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert_hybrid_fixed/history.json (deflated 72%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert_hybrid_fixed/results.json (deflated 62%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert_hybrid_fixed/config.json (deflated 52%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/bert_hybrid_fixed/checkpoint_epoch_100.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/gru4rec/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/gru4rec/history.json (deflated 72%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/gru4rec/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/gru4rec/checkpoint_epoch_40.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/gru4rec/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/lightgcn/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/lightgcn/history.json (deflated 76%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/lightgcn/results.json (deflated 65%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/lightgcn/checkpoint_epoch_20.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/lightgcn/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/sasrec/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/sasrec/history.json (deflated 73%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/sasrec/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/sasrec/checkpoint_epoch_130.pt (deflated 12%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/sasrec/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/tgt_bert4rec/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/tgt_bert4rec/history.json (deflated 73%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/tgt_bert4rec/results.json (deflated 62%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/tgt_bert4rec/config.json (deflated 51%)
#   adding: kaggle/working/length-adaptive/results/hybrid/1m/tgt_bert4rec/checkpoint_epoch_160.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/training_dynamics.png (deflated 20%)
#   adding: kaggle/working/length-adaptive/results/test_vs_val_comparison.png (deflated 21%)
#   adding: kaggle/working/length-adaptive/results/baselines_overview.png (deflated 24%)
#   adding: kaggle/working/length-adaptive/results/prompt/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p3_user_centric/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p3_user_centric/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p3_user_centric/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p3_user_centric/config.json (deflated 59%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft/summary_20260407_133042.csv (deflated 51%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft/summary_20260407_133042.json (deflated 77%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p2_title_genre/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p2_title_genre/history.json (deflated 70%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p2_title_genre/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p2_title_genre/config.json (deflated 59%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p4_hybrid/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p4_hybrid/history.json (deflated 70%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p4_hybrid/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p4_hybrid/config.json (deflated 58%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p1_title_only/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p1_title_only/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p1_title_only/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_p1_title_only/config.json (deflated 58%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_baseline_random_init/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_baseline_random_init/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_baseline_random_init/results.json (deflated 63%)
#   adding: kaggle/working/length-adaptive/results/prompt/promptcraft_baseline_random_init/config.json (deflated 56%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260615_053349/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260615_053349/history.json (deflated 58%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260615_053349/results.json (deflated 65%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260615_053349/best_model.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260615_053349/config.json (deflated 49%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260615_053349/checkpoint.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/overfitting_check_baselines.png (deflated 13%)
#   adding: kaggle/working/length-adaptive/results/bert_hybrid_discrete/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/bert_hybrid_discrete/history.json (deflated 72%)
#   adding: kaggle/working/length-adaptive/results/bert_hybrid_discrete/results.json (deflated 62%)
#   adding: kaggle/working/length-adaptive/results/bert_hybrid_discrete/config.json (deflated 51%)
#   adding: kaggle/working/length-adaptive/results/tcn_bert4rec/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/tcn_bert4rec/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/tcn_bert4rec/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/tcn_bert4rec/config.json (deflated 51%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260615_053321/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260615_053321/history.json (deflated 57%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260615_053321/results.json (deflated 65%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260615_053321/best_model.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260615_053321/config.json (deflated 49%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260615_053321/checkpoint.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/results/bert_hybrid_fixed/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/bert_hybrid_fixed/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/bert_hybrid_fixed/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/bert_hybrid_fixed/config.json (deflated 51%)
#   adding: kaggle/working/length-adaptive/results/computational_costs.png (deflated 26%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260615_053403/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260615_053403/history.json (deflated 57%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260615_053403/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260615_053403/best_model.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260615_053403/config.json (deflated 49%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260615_053403/checkpoint.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260615_053335/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260615_053335/history.json (deflated 57%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260615_053335/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260615_053335/best_model.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260615_053335/config.json (deflated 49%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260615_053335/checkpoint.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/results/tgt_bert4rec/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/tgt_bert4rec/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/tgt_bert4rec/results.json (deflated 61%)
#   adding: kaggle/working/length-adaptive/results/tgt_bert4rec/config.json (deflated 51%)
#   adding: kaggle/working/length-adaptive/scripts/ (stored 0%)
#   adding: kaggle/working/length-adaptive/scripts/run_baselines.sh (deflated 71%)
#   adding: kaggle/working/length-adaptive/.gitignore (deflated 35%)
#   adding: kaggle/working/length-adaptive/paper_results_package.zip (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/index (deflated 63%)
#   adding: kaggle/working/length-adaptive/.git/branches/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/packed-refs (deflated 9%)
#   adding: kaggle/working/length-adaptive/.git/logs/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/logs/HEAD (deflated 28%)
#   adding: kaggle/working/length-adaptive/.git/logs/refs/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/logs/refs/remotes/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/logs/refs/remotes/origin/HEAD (deflated 28%)
#   adding: kaggle/working/length-adaptive/.git/logs/refs/heads/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/logs/refs/heads/main (deflated 28%)
#   adding: kaggle/working/length-adaptive/.git/config (deflated 34%)
#   adding: kaggle/working/length-adaptive/.git/description (deflated 14%)
#   adding: kaggle/working/length-adaptive/.git/HEAD (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/info/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/info/exclude (deflated 28%)
#   adding: kaggle/working/length-adaptive/.git/refs/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/refs/tags/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/refs/remotes/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/refs/remotes/origin/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/refs/heads/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/refs/heads/main (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/objects/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/objects/pack/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/objects/pack/pack-d0bf2fa44a4097b5cd8bae38bfed0bcda880f560.idx (deflated 2%)
#   adding: kaggle/working/length-adaptive/.git/objects/pack/pack-d0bf2fa44a4097b5cd8bae38bfed0bcda880f560.pack (deflated 0%)
#   adding: kaggle/working/length-adaptive/.git/objects/info/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/hooks/ (stored 0%)
#   adding: kaggle/working/length-adaptive/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: kaggle/working/length-adaptive/.git/hooks/pre-commit.sample (deflated 45%)
#   adding: kaggle/working/length-adaptive/.git/hooks/post-update.sample (deflated 27%)
#   adding: kaggle/working/length-adaptive/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: kaggle/working/length-adaptive/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: kaggle/working/length-adaptive/.git/hooks/fsmonitor-watchman.sample (deflated 62%)
#   adding: kaggle/working/length-adaptive/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: kaggle/working/length-adaptive/.git/hooks/pre-push.sample (deflated 49%)
#   adding: kaggle/working/length-adaptive/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: kaggle/working/length-adaptive/.git/hooks/update.sample (deflated 68%)
#   adding: kaggle/working/length-adaptive/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: kaggle/working/length-adaptive/.git/hooks/pre-merge-commit.sample (deflated 39%)
#   adding: kaggle/working/length-adaptive/.git/hooks/push-to-checkout.sample (deflated 55%)
#   adding: kaggle/working/length-adaptive/final_package/ (stored 0%)
#   adding: kaggle/working/length-adaptive/final_package/training_dynamics.png (deflated 20%)
#   adding: kaggle/working/length-adaptive/final_package/test_vs_val_comparison.png (deflated 21%)
#   adding: kaggle/working/length-adaptive/final_package/baselines_overview.png (deflated 24%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/ (stored 0%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/caser_20260615_053416/ (stored 0%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/caser_20260615_053416/history.json (deflated 57%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/caser_20260615_053416/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/caser_20260615_053416/best_model.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/caser_20260615_053416/config.json (deflated 49%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/caser_20260615_053416/checkpoint.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/gru4rec_20260615_053349/ (stored 0%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/gru4rec_20260615_053349/history.json (deflated 58%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/gru4rec_20260615_053349/results.json (deflated 65%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/gru4rec_20260615_053349/best_model.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/gru4rec_20260615_053349/config.json (deflated 49%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/gru4rec_20260615_053349/checkpoint.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/sasrec_20260615_053321/ (stored 0%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/sasrec_20260615_053321/history.json (deflated 57%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/sasrec_20260615_053321/results.json (deflated 65%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/sasrec_20260615_053321/best_model.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/sasrec_20260615_053321/config.json (deflated 49%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/sasrec_20260615_053321/checkpoint.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/lightgcn_20260615_053403/ (stored 0%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/lightgcn_20260615_053403/history.json (deflated 57%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/lightgcn_20260615_053403/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/lightgcn_20260615_053403/best_model.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/lightgcn_20260615_053403/config.json (deflated 49%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/lightgcn_20260615_053403/checkpoint.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/bert4rec_20260615_053335/ (stored 0%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/bert4rec_20260615_053335/history.json (deflated 57%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/bert4rec_20260615_053335/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/bert4rec_20260615_053335/best_model.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/bert4rec_20260615_053335/config.json (deflated 49%)
#   adding: kaggle/working/length-adaptive/final_package/raw_results/bert4rec_20260615_053335/checkpoint.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/final_package/overfitting_check_baselines.png (deflated 13%)
#   adding: kaggle/working/length-adaptive/final_package/paper_results/ (stored 0%)
#   adding: kaggle/working/length-adaptive/final_package/paper_results/table1_main_results.csv (deflated 59%)
#   adding: kaggle/working/length-adaptive/final_package/paper_results/table3_computational_costs.tex (deflated 88%)
#   adding: kaggle/working/length-adaptive/final_package/paper_results/table2_length_analysis.csv (deflated 59%)
#   adding: kaggle/working/length-adaptive/final_package/paper_results/README.md (deflated 50%)
#   adding: kaggle/working/length-adaptive/final_package/paper_results/table3_computational_costs.csv (deflated 88%)
#   adding: kaggle/working/length-adaptive/final_package/paper_results/table2_length_analysis.tex (deflated 63%)
#   adding: kaggle/working/length-adaptive/final_package/paper_results/table1_main_results.tex (deflated 65%)
#   adding: kaggle/working/length-adaptive/final_package/computational_costs.png (deflated 26%)
# ✅ Full project archived for Kaggle download
