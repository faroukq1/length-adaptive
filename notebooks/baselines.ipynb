# %% [markdown]
# # Paper Results Collection: Baseline Models Only
#
# **Publication-Ready Results for MovieLens-1M**
#
# ---
#
# ## 📋 Notebook Purpose
#
# This notebook collects **baseline model results** for comparison:
# - **5 Baseline Models:** BERT4Rec, SASRec, GRU4Rec, Caser, LightGCN
#
# **What this notebook generates:**
# 1. ✅ Comprehensive performance comparison tables (5 baseline models)
# 2. ✅ Training dynamics analysis (convergence, epochs)
# 3. ✅ Performance by sequence length (short vs medium)
# 4. ✅ Computational cost analysis (time, memory, parameters)
# 5. ✅ Hyperparameter details
# 6. ✅ Publication-ready figures and tables
# 7. ✅ LaTeX-formatted tables for paper
#
# **Models Evaluated (5 total):**
#
# **Baselines:**
# 1. BERT4Rec (bidirectional transformer)
# 2. SASRec (unidirectional transformer)
# 3. GRU4Rec (RNN-based)
# 4. Caser (CNN-based)
# 5. LightGCN (pure GNN)
#
# **Time: ~7-10 hours on GPU T4**
#
# ---
#
# ## 🎯 Quick Start
#
# 1. **Enable GPU T4** (Runtime → Change runtime type)
# 2. **Enable Internet**
# 3. **Run all cells** sequentially
# 4. **Download paper_results.zip** at the end

# %% [markdown]
# ## Step 1: Setup Environment

# %%
# Clone repository
# !git clone https://github.com/faroukq1/length-adaptive.git
# %cd length-adaptive

# Verify repository structure
# !ls -lh scripts/

print("\n✅ Repository cloned successfully!")
# Out:
# Cloning into 'length-adaptive'...
# remote: Enumerating objects: 538, done.
# remote: Counting objects: 100% (380/380), done.
# remote: Compressing objects: 100% (298/298), done.
# remote: Total 538 (delta 187), reused 259 (delta 77), pack-reused 158 (from 1)
# Receiving objects: 100% (538/538), 164.26 MiB | 36.65 MiB/s, done.
# Resolving deltas: 100% (231/231), done.
# /kaggle/working/length-adaptive
# total 32K
# -rwxr-xr-x 1 root root 2.0K Feb 24 20:53 merge_kaggle_results.sh
# -rwxr-xr-x 1 root root 2.9K Feb 24 20:53 run_all_experiments.sh
# -rw-r--r-- 1 root root 3.6K Feb 24 20:53 run_baselines.sh
# -rwxr-xr-x 1 root root 4.7K Feb 24 20:53 run_bert_hybrid_experiments.sh
# -rw-r--r-- 1 root root 5.5K Feb 24 20:53 run_paper_experiments.sh
# -rw-r--r-- 1 root root 2.0K Feb 24 20:53 setup_kaggle.sh
#
# ✅ Repository cloned successfully!

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
# Install required packages
# !pip install -q torch-geometric tqdm scikit-learn pandas matplotlib seaborn scipy

# Verify GPU availability
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.2f} GB")

print("\n✅ All dependencies installed!")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.8 MB/s eta 0:00:0000:01
# PyTorch version: 2.9.0+cu126
# CUDA available: True
# GPU: Tesla P100-PCIE-16GB
# GPU Memory: 15.89 GB
#
# ✅ All dependencies installed!

# %% [markdown]
# ## Step 3: Prepare Data

# %%
import os

# Check if preprocessed data exists
data_file = 'data/ml-1m/processed/sequences.pkl'
graph_file = 'data/graphs/cooccurrence_graph.pkl'

print("="*70)
print("🔍 Checking Data Files")
print("="*70)

if os.path.exists(data_file):
    print(f"✅ Sequential data found: {data_file}")
    print(f"   Size: {os.path.getsize(data_file) / 1024 / 1024:.2f} MB")
else:
    print(f"❌ Sequential data NOT found: {data_file}")

if os.path.exists(graph_file):
    print(f"✅ Graph data found: {graph_file}")
    print(f"   Size: {os.path.getsize(graph_file) / 1024 / 1024:.2f} MB")
else:
    print(f"❌ Graph data NOT found: {graph_file}")

print("="*70)

# If data is missing, download and preprocess
if not os.path.exists(data_file) or not os.path.exists(graph_file):
    print("\n🔧 Downloading and preprocessing MovieLens-1M...")
    print("This will take 2-3 minutes.\n")
    
    # Download MovieLens-1M
    raw_file = 'data/ml-1m/raw/ml-1m/ratings.dat'
    if not os.path.exists(raw_file):
        print("📥 Downloading MovieLens-1M dataset...")
        # !mkdir -p data/ml-1m/raw
        # !wget -q http://files.grouplens.org/datasets/movielens/ml-1m.zip
        # !unzip -q ml-1m.zip
        # !mv ml-1m data/ml-1m/raw/
        # !rm -f ml-1m.zip
        print("✅ Download complete!\n")
    
    # Preprocess sequences
    print("🔄 Preprocessing sequential data...")
    # !python -m src.data.preprocess
    
    # Build graph
    print("\n🔄 Building co-occurrence graph...")
    # !python -m src.data.graph_builder
    
    print("\n✅ Data preprocessing complete!")
else:
    print("\n✅ All data files ready!")

print("="*70)
# Out:
# ======================================================================
# 🔍 Checking Data Files
# ======================================================================
# ✅ Sequential data found: data/ml-1m/processed/sequences.pkl
#    Size: 5.24 MB
# ✅ Graph data found: data/graphs/cooccurrence_graph.pkl
#    Size: 3.60 MB
# ======================================================================
#
# ✅ All data files ready!
# ======================================================================

# %% [markdown]
# ## Step 4: Run Baseline Experiments
#
# **Training 5 baseline models with 200 epochs, early stopping (patience=20)**
#
# This is the longest step (~7-10 hours total with GPU T4)

# %%
import time
import os

print("="*80)
print("🎓 TRAINING BASELINE MODELS")
print("="*80)
print("")
print("Training 5 baseline models:")
print("")
print("BASELINES:")
print("  1. BERT4Rec (bidirectional transformer)")
print("  2. SASRec (unidirectional transformer)")
print("  3. GRU4Rec (RNN-based)")
print("  4. Caser (CNN-based)")
print("  5. LightGCN (pure GNN)")
print("")
print("Configuration:")
print("  - Max epochs: 200")
print("  - Early stopping patience: 20")
print("  - Batch size: 256")
print("  - Learning rate: 0.001")
print("  - d_model: 64, n_heads: 2, n_blocks: 2, gnn_layers: 2")
print("")
print("⏱️  Estimated time: 7-10 hours with GPU T4")
print("="*80)

# Record start time
start_time = time.time()

# Run baseline experiments only
# !bash scripts/run_baselines.sh

# Record end time
total_time = time.time() - start_time
print("\n" + "="*80)
print(f"✅ All baseline experiments complete!")
print(f"⏱️  Total time: {total_time/3600:.2f} hours")
print("="*80)
# Out:
# ================================================================================
# 🎓 TRAINING BASELINE MODELS
# ================================================================================
#
# Training 5 baseline models:
#
# BASELINES:
#   1. BERT4Rec (bidirectional transformer)
#   2. SASRec (unidirectional transformer)
#   3. GRU4Rec (RNN-based)
#   4. Caser (CNN-based)
#   5. LightGCN (pure GNN)
#
# Configuration:
#   - Max epochs: 200
#   - Early stopping patience: 20
#   - Batch size: 256
#   - Learning rate: 0.001
#   - d_model: 64, n_heads: 2, n_blocks: 2, gnn_layers: 2
#
# ⏱️  Estimated time: 7-10 hours with GPU T4
# ================================================================================
# ========================================
# PAPER-LEVEL EXPERIMENTS - BASELINES
# ========================================
#
# Working directory: /kaggle/working/length-adaptive
#
# Training with 200 epochs, early stopping patience=20
# Expected to converge at epoch 30-50
#
# Models:
#   Baselines: SASRec, BERT4Rec, GRU4Rec, LightGCN, Caser
#
# ⚠️  Time estimate:
#    GPU: ~5-6 hours total
#    CPU: ~25-30 hours total
#
# Starting experiments...
#
#
# [1/5] Training SASRec (Transformer baseline)...
# Using device: cuda
#
# [1/5] Loading preprocessed data...
#   Users: 6,034
#   Items: 3,533
#
# [2/5] Loading co-occurrence graph...
#   Edges: 151,874
#
# [3/5] Creating dataloaders...
#   Train batches: 2177
#   Val batches: 24
#   Test batches: 24
#
# [4/5] Creating model: sasrec
#   Parameters: 329,344
#   Experiment dir: results/sasrec_20260224_205408
#
# [5/5] Creating trainer...
#
# ============================================================
# TRAINING
# ============================================================
# ============================================================
# STARTING TRAINING
# ============================================================
# Device: cuda
# Model parameters: 329,344
# Training batches: 2177
# Validation batches: 24
# ============================================================
#
# Epoch 1: 100%|█████████████████| 2177/2177 [00:28<00:00, 76.18it/s, loss=0.2397]
#
# [Epoch 1] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 33.07it/s]
#
# [Epoch 1/200] Time: 29.4s
#   Train Loss: 0.3047
#   Val HR@10: 0.0322
#   Val NDCG@10: 0.0143
#   Val MRR@10: 0.0090
#   ✓ New best! (0.0000 → 0.0143)
# Epoch 2: 100%|█████████████████| 2177/2177 [00:27<00:00, 78.14it/s, loss=0.1982]
#
# [Epoch 2] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.02it/s]
#
# [Epoch 2/200] Time: 28.5s
#   Train Loss: 0.2247
#   Val HR@10: 0.0436
#   Val NDCG@10: 0.0202
#   Val MRR@10: 0.0132
#   ✓ New best! (0.0143 → 0.0202)
# Epoch 3: 100%|█████████████████| 2177/2177 [00:27<00:00, 80.42it/s, loss=0.1772]
#
# [Epoch 3] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.79it/s]
#
# [Epoch 3/200] Time: 27.7s
#   Train Loss: 0.1942
#   Val HR@10: 0.0496
#   Val NDCG@10: 0.0217
#   Val MRR@10: 0.0135
#   ✓ New best! (0.0202 → 0.0217)
# Epoch 4: 100%|█████████████████| 2177/2177 [00:27<00:00, 79.84it/s, loss=0.1315]
#
# [Epoch 4] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.06it/s]
#
# [Epoch 4/200] Time: 27.9s
#   Train Loss: 0.1742
#   Val HR@10: 0.0472
#   Val NDCG@10: 0.0210
#   Val MRR@10: 0.0133
#   No improvement (1/20)
# Epoch 5: 100%|█████████████████| 2177/2177 [00:27<00:00, 80.21it/s, loss=0.1186]
#
# [Epoch 5] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.72it/s]
#
# [Epoch 5/200] Time: 27.7s
#   Train Loss: 0.1620
#   Val HR@10: 0.0550
#   Val NDCG@10: 0.0251
#   Val MRR@10: 0.0162
#   ✓ New best! (0.0217 → 0.0251)
# Epoch 6: 100%|█████████████████| 2177/2177 [00:26<00:00, 80.80it/s, loss=0.1203]
#
# [Epoch 6] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.65it/s]
#
# [Epoch 6/200] Time: 27.6s
#   Train Loss: 0.1532
#   Val HR@10: 0.0590
#   Val NDCG@10: 0.0268
#   Val MRR@10: 0.0172
#   ✓ New best! (0.0251 → 0.0268)
# Epoch 7: 100%|█████████████████| 2177/2177 [00:26<00:00, 80.75it/s, loss=0.1438]
#
# [Epoch 7] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.84it/s]
#
# [Epoch 7/200] Time: 27.6s
#   Train Loss: 0.1455
#   Val HR@10: 0.0590
#   Val NDCG@10: 0.0272
#   Val MRR@10: 0.0179
#   ✓ New best! (0.0268 → 0.0272)
# Epoch 8: 100%|█████████████████| 2177/2177 [00:27<00:00, 80.53it/s, loss=0.1308]
#
# [Epoch 8] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.84it/s]
#
# [Epoch 8/200] Time: 27.7s
#   Train Loss: 0.1387
#   Val HR@10: 0.0628
#   Val NDCG@10: 0.0274
#   Val MRR@10: 0.0170
#   ✓ New best! (0.0272 → 0.0274)
# Epoch 9: 100%|█████████████████| 2177/2177 [00:27<00:00, 80.31it/s, loss=0.0613]
#
# [Epoch 9] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.36it/s]
#
# [Epoch 9/200] Time: 27.7s
#   Train Loss: 0.1358
#   Val HR@10: 0.0655
#   Val NDCG@10: 0.0287
#   Val MRR@10: 0.0179
#   ✓ New best! (0.0274 → 0.0287)
# Epoch 10: 100%|████████████████| 2177/2177 [00:27<00:00, 80.38it/s, loss=0.1404]
#
# [Epoch 10] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.78it/s]
#
# [Epoch 10/200] Time: 27.7s
#   Train Loss: 0.1321
#   Val HR@10: 0.0701
#   Val NDCG@10: 0.0310
#   Val MRR@10: 0.0194
#   ✓ New best! (0.0287 → 0.0310)
# Epoch 11: 100%|████████████████| 2177/2177 [00:27<00:00, 79.89it/s, loss=0.2626]
#
# [Epoch 11] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.52it/s]
#
# [Epoch 11/200] Time: 27.9s
#   Train Loss: 0.1301
#   Val HR@10: 0.0716
#   Val NDCG@10: 0.0332
#   Val MRR@10: 0.0218
#   ✓ New best! (0.0310 → 0.0332)
# Epoch 12: 100%|████████████████| 2177/2177 [00:27<00:00, 79.56it/s, loss=0.1231]
#
# [Epoch 12] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.47it/s]
#
# [Epoch 12/200] Time: 28.0s
#   Train Loss: 0.1279
#   Val HR@10: 0.0721
#   Val NDCG@10: 0.0322
#   Val MRR@10: 0.0204
#   No improvement (1/20)
# Epoch 13: 100%|████████████████| 2177/2177 [00:27<00:00, 80.17it/s, loss=0.0752]
#
# [Epoch 13] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.42it/s]
#
# [Epoch 13/200] Time: 27.8s
#   Train Loss: 0.1264
#   Val HR@10: 0.0737
#   Val NDCG@10: 0.0333
#   Val MRR@10: 0.0213
#   ✓ New best! (0.0332 → 0.0333)
# Epoch 14: 100%|████████████████| 2177/2177 [00:27<00:00, 79.66it/s, loss=0.0732]
#
# [Epoch 14] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.70it/s]
#
# [Epoch 14/200] Time: 28.0s
#   Train Loss: 0.1238
#   Val HR@10: 0.0791
#   Val NDCG@10: 0.0367
#   Val MRR@10: 0.0241
#   ✓ New best! (0.0333 → 0.0367)
# Epoch 15: 100%|████████████████| 2177/2177 [00:27<00:00, 79.84it/s, loss=0.1148]
#
# [Epoch 15] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.16it/s]
#
# [Epoch 15/200] Time: 27.9s
#   Train Loss: 0.1221
#   Val HR@10: 0.0792
#   Val NDCG@10: 0.0363
#   Val MRR@10: 0.0235
#   No improvement (1/20)
# Epoch 16: 100%|████████████████| 2177/2177 [00:27<00:00, 78.60it/s, loss=0.1175]
#
# [Epoch 16] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.12it/s]
#
# [Epoch 16/200] Time: 28.3s
#   Train Loss: 0.1208
#   Val HR@10: 0.0726
#   Val NDCG@10: 0.0329
#   Val MRR@10: 0.0210
#   No improvement (2/20)
# Epoch 17: 100%|████████████████| 2177/2177 [00:27<00:00, 79.34it/s, loss=0.1039]
#
# [Epoch 17] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.99it/s]
#
# [Epoch 17/200] Time: 28.1s
#   Train Loss: 0.1187
#   Val HR@10: 0.0709
#   Val NDCG@10: 0.0322
#   Val MRR@10: 0.0206
#   No improvement (3/20)
# Epoch 18: 100%|████████████████| 2177/2177 [00:27<00:00, 79.41it/s, loss=0.1529]
#
# [Epoch 18] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.29it/s]
#
# [Epoch 18/200] Time: 28.0s
#   Train Loss: 0.1177
#   Val HR@10: 0.0772
#   Val NDCG@10: 0.0341
#   Val MRR@10: 0.0213
#   No improvement (4/20)
# Epoch 19: 100%|████████████████| 2177/2177 [00:27<00:00, 80.04it/s, loss=0.1520]
#
# [Epoch 19] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.62it/s]
#
# [Epoch 19/200] Time: 27.8s
#   Train Loss: 0.1164
#   Val HR@10: 0.0830
#   Val NDCG@10: 0.0379
#   Val MRR@10: 0.0245
#   ✓ New best! (0.0367 → 0.0379)
# Epoch 20: 100%|████████████████| 2177/2177 [00:27<00:00, 79.60it/s, loss=0.1189]
#
# [Epoch 20] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.40it/s]
#
# [Epoch 20/200] Time: 28.0s
#   Train Loss: 0.1164
#   Val HR@10: 0.0812
#   Val NDCG@10: 0.0365
#   Val MRR@10: 0.0232
#   No improvement (1/20)
# Epoch 21: 100%|████████████████| 2177/2177 [00:27<00:00, 79.49it/s, loss=0.1411]
#
# [Epoch 21] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.31it/s]
#
# [Epoch 21/200] Time: 28.0s
#   Train Loss: 0.1149
#   Val HR@10: 0.0872
#   Val NDCG@10: 0.0407
#   Val MRR@10: 0.0270
#   ✓ New best! (0.0379 → 0.0407)
# Epoch 22: 100%|████████████████| 2177/2177 [00:27<00:00, 79.76it/s, loss=0.0799]
#
# [Epoch 22] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.36it/s]
#
# [Epoch 22/200] Time: 27.9s
#   Train Loss: 0.1147
#   Val HR@10: 0.0853
#   Val NDCG@10: 0.0388
#   Val MRR@10: 0.0250
#   No improvement (1/20)
# Epoch 23: 100%|████████████████| 2177/2177 [00:27<00:00, 78.65it/s, loss=0.0873]
#
# [Epoch 23] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.37it/s]
#
# [Epoch 23/200] Time: 28.3s
#   Train Loss: 0.1131
#   Val HR@10: 0.0870
#   Val NDCG@10: 0.0394
#   Val MRR@10: 0.0252
#   No improvement (2/20)
# Epoch 24: 100%|████████████████| 2177/2177 [00:27<00:00, 79.37it/s, loss=0.1320]
#
# [Epoch 24] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.87it/s]
#
# [Epoch 24/200] Time: 28.1s
#   Train Loss: 0.1117
#   Val HR@10: 0.0824
#   Val NDCG@10: 0.0371
#   Val MRR@10: 0.0237
#   No improvement (3/20)
# Epoch 25: 100%|████████████████| 2177/2177 [00:27<00:00, 79.34it/s, loss=0.1370]
#
# [Epoch 25] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.81it/s]
#
# [Epoch 25/200] Time: 28.1s
#   Train Loss: 0.1112
#   Val HR@10: 0.0822
#   Val NDCG@10: 0.0384
#   Val MRR@10: 0.0254
#   No improvement (4/20)
# Epoch 26: 100%|████████████████| 2177/2177 [00:27<00:00, 79.08it/s, loss=0.0819]
#
# [Epoch 26] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.04it/s]
#
# [Epoch 26/200] Time: 28.2s
#   Train Loss: 0.1114
#   Val HR@10: 0.0845
#   Val NDCG@10: 0.0401
#   Val MRR@10: 0.0268
#   No improvement (5/20)
# Epoch 27: 100%|████████████████| 2177/2177 [00:27<00:00, 79.62it/s, loss=0.1058]
#
# [Epoch 27] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.40it/s]
#
# [Epoch 27/200] Time: 28.0s
#   Train Loss: 0.1106
#   Val HR@10: 0.0867
#   Val NDCG@10: 0.0412
#   Val MRR@10: 0.0276
#   ✓ New best! (0.0407 → 0.0412)
# Epoch 28: 100%|████████████████| 2177/2177 [00:27<00:00, 79.68it/s, loss=0.1204]
#
# [Epoch 28] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.73it/s]
#
# [Epoch 28/200] Time: 27.9s
#   Train Loss: 0.1102
#   Val HR@10: 0.0819
#   Val NDCG@10: 0.0384
#   Val MRR@10: 0.0254
#   No improvement (1/20)
# Epoch 29: 100%|████████████████| 2177/2177 [00:27<00:00, 79.89it/s, loss=0.1550]
#
# [Epoch 29] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.62it/s]
#
# [Epoch 29/200] Time: 27.9s
#   Train Loss: 0.1090
#   Val HR@10: 0.0824
#   Val NDCG@10: 0.0378
#   Val MRR@10: 0.0245
#   No improvement (2/20)
# Epoch 30: 100%|████████████████| 2177/2177 [00:27<00:00, 78.71it/s, loss=0.0496]
#
# [Epoch 30] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.01it/s]
#
# [Epoch 30/200] Time: 28.3s
#   Train Loss: 0.1079
#   Val HR@10: 0.0867
#   Val NDCG@10: 0.0376
#   Val MRR@10: 0.0231
#   No improvement (3/20)
# Epoch 31: 100%|████████████████| 2177/2177 [00:27<00:00, 77.82it/s, loss=0.1088]
#
# [Epoch 31] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.41it/s]
#
# [Epoch 31/200] Time: 28.6s
#   Train Loss: 0.1080
#   Val HR@10: 0.0882
#   Val NDCG@10: 0.0404
#   Val MRR@10: 0.0262
#   No improvement (4/20)
# Epoch 32: 100%|████████████████| 2177/2177 [00:28<00:00, 77.43it/s, loss=0.0990]
#
# [Epoch 32] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.06it/s]
#
# [Epoch 32/200] Time: 28.7s
#   Train Loss: 0.1080
#   Val HR@10: 0.0847
#   Val NDCG@10: 0.0379
#   Val MRR@10: 0.0241
#   No improvement (5/20)
# Epoch 33: 100%|████████████████| 2177/2177 [00:27<00:00, 79.32it/s, loss=0.0790]
#
# [Epoch 33] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.28it/s]
#
# [Epoch 33/200] Time: 28.1s
#   Train Loss: 0.1073
#   Val HR@10: 0.0903
#   Val NDCG@10: 0.0416
#   Val MRR@10: 0.0271
#   ✓ New best! (0.0412 → 0.0416)
# Epoch 34: 100%|████████████████| 2177/2177 [00:28<00:00, 77.63it/s, loss=0.0921]
#
# [Epoch 34] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.39it/s]
#
# [Epoch 34/200] Time: 28.7s
#   Train Loss: 0.1063
#   Val HR@10: 0.0931
#   Val NDCG@10: 0.0424
#   Val MRR@10: 0.0273
#   ✓ New best! (0.0416 → 0.0424)
# Epoch 35: 100%|████████████████| 2177/2177 [00:27<00:00, 78.75it/s, loss=0.1188]
#
# [Epoch 35] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.97it/s]
#
# [Epoch 35/200] Time: 28.3s
#   Train Loss: 0.1056
#   Val HR@10: 0.0868
#   Val NDCG@10: 0.0413
#   Val MRR@10: 0.0277
#   No improvement (1/20)
# Epoch 36: 100%|████████████████| 2177/2177 [00:27<00:00, 79.08it/s, loss=0.1830]
#
# [Epoch 36] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.57it/s]
#
# [Epoch 36/200] Time: 28.2s
#   Train Loss: 0.1061
#   Val HR@10: 0.0948
#   Val NDCG@10: 0.0458
#   Val MRR@10: 0.0310
#   ✓ New best! (0.0424 → 0.0458)
# Epoch 37: 100%|████████████████| 2177/2177 [00:27<00:00, 77.88it/s, loss=0.1096]
#
# [Epoch 37] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.24it/s]
#
# [Epoch 37/200] Time: 28.6s
#   Train Loss: 0.1057
#   Val HR@10: 0.0961
#   Val NDCG@10: 0.0446
#   Val MRR@10: 0.0293
#   No improvement (1/20)
# Epoch 38: 100%|████████████████| 2177/2177 [00:27<00:00, 78.33it/s, loss=0.0984]
#
# [Epoch 38] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.53it/s]
#
# [Epoch 38/200] Time: 28.4s
#   Train Loss: 0.1052
#   Val HR@10: 0.0913
#   Val NDCG@10: 0.0423
#   Val MRR@10: 0.0276
#   No improvement (2/20)
# Epoch 39: 100%|████████████████| 2177/2177 [00:27<00:00, 79.06it/s, loss=0.0915]
#
# [Epoch 39] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.81it/s]
#
# [Epoch 39/200] Time: 28.2s
#   Train Loss: 0.1035
#   Val HR@10: 0.1003
#   Val NDCG@10: 0.0459
#   Val MRR@10: 0.0298
#   ✓ New best! (0.0458 → 0.0459)
# Epoch 40: 100%|████████████████| 2177/2177 [00:27<00:00, 78.65it/s, loss=0.0880]
#
# [Epoch 40] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.83it/s]
#
# [Epoch 40/200] Time: 28.3s
#   Train Loss: 0.1037
#   Val HR@10: 0.0943
#   Val NDCG@10: 0.0426
#   Val MRR@10: 0.0271
#   No improvement (1/20)
# Epoch 41: 100%|████████████████| 2177/2177 [00:27<00:00, 78.44it/s, loss=0.1123]
#
# [Epoch 41] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.86it/s]
#
# [Epoch 41/200] Time: 28.4s
#   Train Loss: 0.1038
#   Val HR@10: 0.0988
#   Val NDCG@10: 0.0450
#   Val MRR@10: 0.0291
#   No improvement (2/20)
# Epoch 42: 100%|████████████████| 2177/2177 [00:27<00:00, 78.19it/s, loss=0.1476]
#
# [Epoch 42] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.69it/s]
#
# [Epoch 42/200] Time: 28.5s
#   Train Loss: 0.1040
#   Val HR@10: 0.0971
#   Val NDCG@10: 0.0448
#   Val MRR@10: 0.0292
#   No improvement (3/20)
# Epoch 43: 100%|████████████████| 2177/2177 [00:27<00:00, 78.30it/s, loss=0.1466]
#
# [Epoch 43] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.34it/s]
#
# [Epoch 43/200] Time: 28.4s
#   Train Loss: 0.1029
#   Val HR@10: 0.0960
#   Val NDCG@10: 0.0468
#   Val MRR@10: 0.0321
#   ✓ New best! (0.0459 → 0.0468)
# Epoch 44: 100%|████████████████| 2177/2177 [00:28<00:00, 77.64it/s, loss=0.1164]
#
# [Epoch 44] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.03it/s]
#
# [Epoch 44/200] Time: 28.7s
#   Train Loss: 0.1031
#   Val HR@10: 0.0991
#   Val NDCG@10: 0.0470
#   Val MRR@10: 0.0315
#   ✓ New best! (0.0468 → 0.0470)
# Epoch 45: 100%|████████████████| 2177/2177 [00:27<00:00, 78.11it/s, loss=0.1102]
#
# [Epoch 45] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.64it/s]
#
# [Epoch 45/200] Time: 28.5s
#   Train Loss: 0.1026
#   Val HR@10: 0.0981
#   Val NDCG@10: 0.0468
#   Val MRR@10: 0.0315
#   No improvement (1/20)
# Epoch 46: 100%|████████████████| 2177/2177 [00:27<00:00, 78.20it/s, loss=0.1556]
#
# [Epoch 46] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.52it/s]
#
# [Epoch 46/200] Time: 28.5s
#   Train Loss: 0.1024
#   Val HR@10: 0.0903
#   Val NDCG@10: 0.0427
#   Val MRR@10: 0.0286
#   No improvement (2/20)
# Epoch 47: 100%|████████████████| 2177/2177 [00:27<00:00, 77.86it/s, loss=0.1139]
#
# [Epoch 47] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.25it/s]
#
# [Epoch 47/200] Time: 28.6s
#   Train Loss: 0.1019
#   Val HR@10: 0.0941
#   Val NDCG@10: 0.0455
#   Val MRR@10: 0.0311
#   No improvement (3/20)
# Epoch 48: 100%|████████████████| 2177/2177 [00:28<00:00, 76.60it/s, loss=0.1066]
#
# [Epoch 48] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.21it/s]
#
# [Epoch 48/200] Time: 29.1s
#   Train Loss: 0.1015
#   Val HR@10: 0.0989
#   Val NDCG@10: 0.0477
#   Val MRR@10: 0.0324
#   ✓ New best! (0.0470 → 0.0477)
# Epoch 49: 100%|████████████████| 2177/2177 [00:27<00:00, 78.35it/s, loss=0.1049]
#
# [Epoch 49] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.90it/s]
#
# [Epoch 49/200] Time: 28.4s
#   Train Loss: 0.1015
#   Val HR@10: 0.0993
#   Val NDCG@10: 0.0481
#   Val MRR@10: 0.0328
#   ✓ New best! (0.0477 → 0.0481)
# Epoch 50: 100%|████████████████| 2177/2177 [00:27<00:00, 77.95it/s, loss=0.0589]
#
# [Epoch 50] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 36.18it/s]
#
# [Epoch 50/200] Time: 28.6s
#   Train Loss: 0.0999
#   Val HR@10: 0.0978
#   Val NDCG@10: 0.0458
#   Val MRR@10: 0.0304
#   No improvement (1/20)
# Epoch 51: 100%|████████████████| 2177/2177 [00:28<00:00, 77.32it/s, loss=0.1363]
#
# [Epoch 51] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.66it/s]
#
# [Epoch 51/200] Time: 28.8s
#   Train Loss: 0.1004
#   Val HR@10: 0.0960
#   Val NDCG@10: 0.0465
#   Val MRR@10: 0.0318
#   No improvement (2/20)
# Epoch 52: 100%|████████████████| 2177/2177 [00:28<00:00, 77.59it/s, loss=0.1353]
#
# [Epoch 52] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.31it/s]
#
# [Epoch 52/200] Time: 28.7s
#   Train Loss: 0.1005
#   Val HR@10: 0.1023
#   Val NDCG@10: 0.0478
#   Val MRR@10: 0.0316
#   No improvement (3/20)
# Epoch 53: 100%|████████████████| 2177/2177 [00:27<00:00, 77.86it/s, loss=0.0800]
#
# [Epoch 53] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.18it/s]
#
# [Epoch 53/200] Time: 28.6s
#   Train Loss: 0.0994
#   Val HR@10: 0.0978
#   Val NDCG@10: 0.0477
#   Val MRR@10: 0.0327
#   No improvement (4/20)
# Epoch 54: 100%|████████████████| 2177/2177 [00:28<00:00, 77.56it/s, loss=0.1436]
#
# [Epoch 54] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.96it/s]
#
# [Epoch 54/200] Time: 28.7s
#   Train Loss: 0.1000
#   Val HR@10: 0.1028
#   Val NDCG@10: 0.0481
#   Val MRR@10: 0.0318
#   ✓ New best! (0.0481 → 0.0481)
# Epoch 55: 100%|████████████████| 2177/2177 [00:28<00:00, 77.55it/s, loss=0.0569]
#
# [Epoch 55] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.94it/s]
#
# [Epoch 55/200] Time: 28.7s
#   Train Loss: 0.1000
#   Val HR@10: 0.1006
#   Val NDCG@10: 0.0464
#   Val MRR@10: 0.0302
#   No improvement (1/20)
# Epoch 56: 100%|████████████████| 2177/2177 [00:28<00:00, 77.42it/s, loss=0.1435]
#
# [Epoch 56] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.45it/s]
#
# [Epoch 56/200] Time: 28.7s
#   Train Loss: 0.0992
#   Val HR@10: 0.1018
#   Val NDCG@10: 0.0472
#   Val MRR@10: 0.0310
#   No improvement (2/20)
# Epoch 57: 100%|████████████████| 2177/2177 [00:28<00:00, 77.67it/s, loss=0.1239]
#
# [Epoch 57] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.09it/s]
#
# [Epoch 57/200] Time: 28.6s
#   Train Loss: 0.0985
#   Val HR@10: 0.0978
#   Val NDCG@10: 0.0458
#   Val MRR@10: 0.0303
#   No improvement (3/20)
# Epoch 58: 100%|████████████████| 2177/2177 [00:28<00:00, 77.53it/s, loss=0.1392]
#
# [Epoch 58] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.03it/s]
#
# [Epoch 58/200] Time: 28.7s
#   Train Loss: 0.0981
#   Val HR@10: 0.1049
#   Val NDCG@10: 0.0478
#   Val MRR@10: 0.0308
#   No improvement (4/20)
# Epoch 59: 100%|████████████████| 2177/2177 [00:28<00:00, 77.22it/s, loss=0.1206]
#
# [Epoch 59] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.49it/s]
#
# [Epoch 59/200] Time: 28.8s
#   Train Loss: 0.0993
#   Val HR@10: 0.0926
#   Val NDCG@10: 0.0429
#   Val MRR@10: 0.0281
#   No improvement (5/20)
# Epoch 60: 100%|████████████████| 2177/2177 [00:28<00:00, 77.40it/s, loss=0.1302]
#
# [Epoch 60] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.30it/s]
#
# [Epoch 60/200] Time: 28.8s
#   Train Loss: 0.0990
#   Val HR@10: 0.0993
#   Val NDCG@10: 0.0462
#   Val MRR@10: 0.0305
#   No improvement (6/20)
# Epoch 61: 100%|████████████████| 2177/2177 [00:28<00:00, 76.06it/s, loss=0.0840]
#
# [Epoch 61] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.02it/s]
#
# [Epoch 61/200] Time: 29.3s
#   Train Loss: 0.0987
#   Val HR@10: 0.0988
#   Val NDCG@10: 0.0458
#   Val MRR@10: 0.0299
#   No improvement (7/20)
# Epoch 62: 100%|████████████████| 2177/2177 [00:28<00:00, 77.19it/s, loss=0.0966]
#
# [Epoch 62] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.19it/s]
#
# [Epoch 62/200] Time: 28.8s
#   Train Loss: 0.0974
#   Val HR@10: 0.1013
#   Val NDCG@10: 0.0489
#   Val MRR@10: 0.0333
#   ✓ New best! (0.0481 → 0.0489)
# Epoch 63: 100%|████████████████| 2177/2177 [00:28<00:00, 76.85it/s, loss=0.0705]
#
# [Epoch 63] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 36.07it/s]
#
# [Epoch 63/200] Time: 29.0s
#   Train Loss: 0.0980
#   Val HR@10: 0.1047
#   Val NDCG@10: 0.0491
#   Val MRR@10: 0.0326
#   ✓ New best! (0.0489 → 0.0491)
# Epoch 64: 100%|████████████████| 2177/2177 [00:28<00:00, 77.07it/s, loss=0.1284]
#
# [Epoch 64] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.44it/s]
#
# [Epoch 64/200] Time: 28.9s
#   Train Loss: 0.0977
#   Val HR@10: 0.1084
#   Val NDCG@10: 0.0500
#   Val MRR@10: 0.0326
#   ✓ New best! (0.0491 → 0.0500)
# Epoch 65: 100%|████████████████| 2177/2177 [00:28<00:00, 77.24it/s, loss=0.1543]
#
# [Epoch 65] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.67it/s]
#
# [Epoch 65/200] Time: 28.8s
#   Train Loss: 0.0972
#   Val HR@10: 0.1008
#   Val NDCG@10: 0.0466
#   Val MRR@10: 0.0305
#   No improvement (1/20)
# Epoch 66: 100%|████████████████| 2177/2177 [00:28<00:00, 77.03it/s, loss=0.0967]
#
# [Epoch 66] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.97it/s]
#
# [Epoch 66/200] Time: 28.9s
#   Train Loss: 0.0966
#   Val HR@10: 0.1047
#   Val NDCG@10: 0.0497
#   Val MRR@10: 0.0333
#   No improvement (2/20)
# Epoch 67: 100%|████████████████| 2177/2177 [00:28<00:00, 77.08it/s, loss=0.1281]
#
# [Epoch 67] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.88it/s]
#
# [Epoch 67/200] Time: 28.9s
#   Train Loss: 0.0967
#   Val HR@10: 0.1024
#   Val NDCG@10: 0.0476
#   Val MRR@10: 0.0313
#   No improvement (3/20)
# Epoch 68: 100%|████████████████| 2177/2177 [00:28<00:00, 76.81it/s, loss=0.0523]
#
# [Epoch 68] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.03it/s]
#
# [Epoch 68/200] Time: 29.0s
#   Train Loss: 0.0970
#   Val HR@10: 0.1032
#   Val NDCG@10: 0.0476
#   Val MRR@10: 0.0311
#   No improvement (4/20)
# Epoch 69: 100%|████████████████| 2177/2177 [00:28<00:00, 76.93it/s, loss=0.1034]
#
# [Epoch 69] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.48it/s]
#
# [Epoch 69/200] Time: 28.9s
#   Train Loss: 0.0966
#   Val HR@10: 0.1044
#   Val NDCG@10: 0.0483
#   Val MRR@10: 0.0315
#   No improvement (5/20)
# Epoch 70: 100%|████████████████| 2177/2177 [00:28<00:00, 76.89it/s, loss=0.0614]
#
# [Epoch 70] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.76it/s]
#
# [Epoch 70/200] Time: 28.9s
#   Train Loss: 0.0958
#   Val HR@10: 0.0988
#   Val NDCG@10: 0.0457
#   Val MRR@10: 0.0299
#   No improvement (6/20)
# Epoch 71: 100%|████████████████| 2177/2177 [00:28<00:00, 77.20it/s, loss=0.1612]
#
# [Epoch 71] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.13it/s]
#
# [Epoch 71/200] Time: 28.8s
#   Train Loss: 0.0969
#   Val HR@10: 0.1036
#   Val NDCG@10: 0.0487
#   Val MRR@10: 0.0324
#   No improvement (7/20)
# Epoch 72: 100%|████████████████| 2177/2177 [00:28<00:00, 76.59it/s, loss=0.1157]
#
# [Epoch 72] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 36.42it/s]
#
# [Epoch 72/200] Time: 29.1s
#   Train Loss: 0.0965
#   Val HR@10: 0.1042
#   Val NDCG@10: 0.0492
#   Val MRR@10: 0.0328
#   No improvement (8/20)
# Epoch 73: 100%|████████████████| 2177/2177 [00:28<00:00, 76.74it/s, loss=0.1094]
#
# [Epoch 73] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.27it/s]
#
# [Epoch 73/200] Time: 29.0s
#   Train Loss: 0.0959
#   Val HR@10: 0.1092
#   Val NDCG@10: 0.0511
#   Val MRR@10: 0.0338
#   ✓ New best! (0.0500 → 0.0511)
# Epoch 74: 100%|████████████████| 2177/2177 [00:28<00:00, 76.28it/s, loss=0.0499]
#
# [Epoch 74] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.31it/s]
#
# [Epoch 74/200] Time: 29.2s
#   Train Loss: 0.0958
#   Val HR@10: 0.0984
#   Val NDCG@10: 0.0477
#   Val MRR@10: 0.0325
#   No improvement (1/20)
# Epoch 75: 100%|████████████████| 2177/2177 [00:28<00:00, 76.87it/s, loss=0.0460]
#
# [Epoch 75] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.19it/s]
#
# [Epoch 75/200] Time: 29.0s
#   Train Loss: 0.0952
#   Val HR@10: 0.1066
#   Val NDCG@10: 0.0496
#   Val MRR@10: 0.0327
#   No improvement (2/20)
# Epoch 76: 100%|████████████████| 2177/2177 [00:28<00:00, 76.50it/s, loss=0.0678]
#
# [Epoch 76] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.96it/s]
#
# [Epoch 76/200] Time: 29.1s
#   Train Loss: 0.0952
#   Val HR@10: 0.1023
#   Val NDCG@10: 0.0489
#   Val MRR@10: 0.0330
#   No improvement (3/20)
# Epoch 77: 100%|████████████████| 2177/2177 [00:28<00:00, 76.96it/s, loss=0.0610]
#
# [Epoch 77] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.64it/s]
#
# [Epoch 77/200] Time: 28.9s
#   Train Loss: 0.0957
#   Val HR@10: 0.1032
#   Val NDCG@10: 0.0485
#   Val MRR@10: 0.0323
#   No improvement (4/20)
# Epoch 78: 100%|████████████████| 2177/2177 [00:28<00:00, 76.95it/s, loss=0.0430]
#
# [Epoch 78] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.04it/s]
#
# [Epoch 78/200] Time: 28.9s
#   Train Loss: 0.0955
#   Val HR@10: 0.1084
#   Val NDCG@10: 0.0514
#   Val MRR@10: 0.0344
#   ✓ New best! (0.0511 → 0.0514)
# Epoch 79: 100%|████████████████| 2177/2177 [00:28<00:00, 77.09it/s, loss=0.0738]
#
# [Epoch 79] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.07it/s]
#
# [Epoch 79/200] Time: 28.9s
#   Train Loss: 0.0948
#   Val HR@10: 0.1047
#   Val NDCG@10: 0.0486
#   Val MRR@10: 0.0320
#   No improvement (1/20)
# Epoch 80: 100%|████████████████| 2177/2177 [00:28<00:00, 75.84it/s, loss=0.0555]
#
# [Epoch 80] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.96it/s]
#
# [Epoch 80/200] Time: 29.3s
#   Train Loss: 0.0952
#   Val HR@10: 0.1047
#   Val NDCG@10: 0.0500
#   Val MRR@10: 0.0338
#   No improvement (2/20)
# Epoch 81: 100%|████████████████| 2177/2177 [00:28<00:00, 76.45it/s, loss=0.0733]
#
# [Epoch 81] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.65it/s]
#
# [Epoch 81/200] Time: 29.1s
#   Train Loss: 0.0955
#   Val HR@10: 0.1001
#   Val NDCG@10: 0.0483
#   Val MRR@10: 0.0329
#   No improvement (3/20)
# Epoch 82: 100%|████████████████| 2177/2177 [00:28<00:00, 76.19it/s, loss=0.1554]
#
# [Epoch 82] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.53it/s]
#
# [Epoch 82/200] Time: 29.2s
#   Train Loss: 0.0947
#   Val HR@10: 0.1029
#   Val NDCG@10: 0.0491
#   Val MRR@10: 0.0330
#   No improvement (4/20)
# Epoch 83: 100%|████████████████| 2177/2177 [00:28<00:00, 76.57it/s, loss=0.1296]
#
# [Epoch 83] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 36.61it/s]
#
# [Epoch 83/200] Time: 29.1s
#   Train Loss: 0.0941
#   Val HR@10: 0.1008
#   Val NDCG@10: 0.0470
#   Val MRR@10: 0.0310
#   No improvement (5/20)
# Epoch 84: 100%|████████████████| 2177/2177 [00:28<00:00, 76.71it/s, loss=0.0767]
#
# [Epoch 84] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.55it/s]
#
# [Epoch 84/200] Time: 29.0s
#   Train Loss: 0.0948
#   Val HR@10: 0.0993
#   Val NDCG@10: 0.0478
#   Val MRR@10: 0.0325
#   No improvement (6/20)
# Epoch 85: 100%|████████████████| 2177/2177 [00:28<00:00, 76.38it/s, loss=0.0910]
#
# [Epoch 85] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.62it/s]
#
# [Epoch 85/200] Time: 29.1s
#   Train Loss: 0.0941
#   Val HR@10: 0.1019
#   Val NDCG@10: 0.0478
#   Val MRR@10: 0.0316
#   No improvement (7/20)
# Epoch 86: 100%|████████████████| 2177/2177 [00:28<00:00, 76.21it/s, loss=0.1157]
#
# [Epoch 86] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.58it/s]
#
# [Epoch 86/200] Time: 29.2s
#   Train Loss: 0.0943
#   Val HR@10: 0.1013
#   Val NDCG@10: 0.0469
#   Val MRR@10: 0.0308
#   No improvement (8/20)
# Epoch 87: 100%|████████████████| 2177/2177 [00:28<00:00, 76.41it/s, loss=0.1157]
#
# [Epoch 87] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.57it/s]
#
# [Epoch 87/200] Time: 29.1s
#   Train Loss: 0.0943
#   Val HR@10: 0.1013
#   Val NDCG@10: 0.0468
#   Val MRR@10: 0.0305
#   No improvement (9/20)
# Epoch 88: 100%|████████████████| 2177/2177 [00:28<00:00, 75.54it/s, loss=0.0863]
#
# [Epoch 88] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.72it/s]
#
# [Epoch 88/200] Time: 29.4s
#   Train Loss: 0.0942
#   Val HR@10: 0.1074
#   Val NDCG@10: 0.0502
#   Val MRR@10: 0.0332
#   No improvement (10/20)
# Epoch 89: 100%|████████████████| 2177/2177 [00:28<00:00, 76.38it/s, loss=0.0456]
#
# [Epoch 89] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.08it/s]
#
# [Epoch 89/200] Time: 29.1s
#   Train Loss: 0.0940
#   Val HR@10: 0.1024
#   Val NDCG@10: 0.0490
#   Val MRR@10: 0.0330
#   No improvement (11/20)
# Epoch 90: 100%|████████████████| 2177/2177 [00:28<00:00, 76.25it/s, loss=0.1422]
#
# [Epoch 90] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.32it/s]
#
# [Epoch 90/200] Time: 29.2s
#   Train Loss: 0.0929
#   Val HR@10: 0.1069
#   Val NDCG@10: 0.0499
#   Val MRR@10: 0.0329
#   No improvement (12/20)
# Epoch 91: 100%|████████████████| 2177/2177 [00:28<00:00, 75.90it/s, loss=0.1295]
#
# [Epoch 91] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.50it/s]
#
# [Epoch 91/200] Time: 29.3s
#   Train Loss: 0.0935
#   Val HR@10: 0.1052
#   Val NDCG@10: 0.0495
#   Val MRR@10: 0.0329
#   No improvement (13/20)
# Epoch 92: 100%|████████████████| 2177/2177 [00:28<00:00, 76.39it/s, loss=0.0616]
#
# [Epoch 92] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.25it/s]
#
# [Epoch 92/200] Time: 29.1s
#   Train Loss: 0.0931
#   Val HR@10: 0.1087
#   Val NDCG@10: 0.0513
#   Val MRR@10: 0.0342
#   No improvement (14/20)
# Epoch 93: 100%|████████████████| 2177/2177 [00:28<00:00, 76.14it/s, loss=0.0459]
#
# [Epoch 93] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.30it/s]
#
# [Epoch 93/200] Time: 29.2s
#   Train Loss: 0.0939
#   Val HR@10: 0.1067
#   Val NDCG@10: 0.0503
#   Val MRR@10: 0.0335
#   No improvement (15/20)
# Epoch 94: 100%|████████████████| 2177/2177 [00:28<00:00, 75.76it/s, loss=0.0868]
#
# [Epoch 94] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.48it/s]
#
# [Epoch 94/200] Time: 29.4s
#   Train Loss: 0.0931
#   Val HR@10: 0.1032
#   Val NDCG@10: 0.0482
#   Val MRR@10: 0.0318
#   No improvement (16/20)
# Epoch 95: 100%|████████████████| 2177/2177 [00:28<00:00, 76.37it/s, loss=0.1069]
#
# [Epoch 95] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.61it/s]
#
# [Epoch 95/200] Time: 29.1s
#   Train Loss: 0.0923
#   Val HR@10: 0.1069
#   Val NDCG@10: 0.0512
#   Val MRR@10: 0.0345
#   No improvement (17/20)
# Epoch 96: 100%|████████████████| 2177/2177 [00:28<00:00, 75.98it/s, loss=0.0979]
#
# [Epoch 96] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.16it/s]
#
# [Epoch 96/200] Time: 29.3s
#   Train Loss: 0.0927
#   Val HR@10: 0.1115
#   Val NDCG@10: 0.0524
#   Val MRR@10: 0.0348
#   ✓ New best! (0.0514 → 0.0524)
# Epoch 97: 100%|████████████████| 2177/2177 [00:28<00:00, 75.87it/s, loss=0.1045]
#
# [Epoch 97] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.25it/s]
#
# [Epoch 97/200] Time: 29.3s
#   Train Loss: 0.0930
#   Val HR@10: 0.1021
#   Val NDCG@10: 0.0480
#   Val MRR@10: 0.0319
#   No improvement (1/20)
# Epoch 98: 100%|████████████████| 2177/2177 [00:28<00:00, 75.85it/s, loss=0.0823]
#
# [Epoch 98] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.83it/s]
#
# [Epoch 98/200] Time: 29.3s
#   Train Loss: 0.0924
#   Val HR@10: 0.1066
#   Val NDCG@10: 0.0516
#   Val MRR@10: 0.0351
#   No improvement (2/20)
# Epoch 99: 100%|████████████████| 2177/2177 [00:28<00:00, 75.48it/s, loss=0.1450]
#
# [Epoch 99] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.86it/s]
#
# [Epoch 99/200] Time: 29.5s
#   Train Loss: 0.0926
#   Val HR@10: 0.1004
#   Val NDCG@10: 0.0482
#   Val MRR@10: 0.0327
#   No improvement (3/20)
# Epoch 100: 100%|███████████████| 2177/2177 [00:28<00:00, 75.66it/s, loss=0.0545]
#
# [Epoch 100] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.20it/s]
#
# [Epoch 100/200] Time: 29.4s
#   Train Loss: 0.0921
#   Val HR@10: 0.1037
#   Val NDCG@10: 0.0473
#   Val MRR@10: 0.0305
#   No improvement (4/20)
# Epoch 101: 100%|███████████████| 2177/2177 [00:29<00:00, 74.75it/s, loss=0.0352]
#
# [Epoch 101] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.86it/s]
#
# [Epoch 101/200] Time: 29.8s
#   Train Loss: 0.0928
#   Val HR@10: 0.1001
#   Val NDCG@10: 0.0467
#   Val MRR@10: 0.0306
#   No improvement (5/20)
# Epoch 102: 100%|███████████████| 2177/2177 [00:28<00:00, 75.23it/s, loss=0.1322]
#
# [Epoch 102] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.06it/s]
#
# [Epoch 102/200] Time: 29.6s
#   Train Loss: 0.0925
#   Val HR@10: 0.1019
#   Val NDCG@10: 0.0485
#   Val MRR@10: 0.0325
#   No improvement (6/20)
# Epoch 103: 100%|███████████████| 2177/2177 [00:28<00:00, 75.45it/s, loss=0.0969]
#
# [Epoch 103] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.92it/s]
#
# [Epoch 103/200] Time: 29.5s
#   Train Loss: 0.0920
#   Val HR@10: 0.1051
#   Val NDCG@10: 0.0490
#   Val MRR@10: 0.0323
#   No improvement (7/20)
# Epoch 104: 100%|███████████████| 2177/2177 [00:28<00:00, 75.07it/s, loss=0.1127]
#
# [Epoch 104] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.98it/s]
#
# [Epoch 104/200] Time: 29.6s
#   Train Loss: 0.0918
#   Val HR@10: 0.0996
#   Val NDCG@10: 0.0456
#   Val MRR@10: 0.0296
#   No improvement (8/20)
# Epoch 105: 100%|███████████████| 2177/2177 [00:28<00:00, 75.26it/s, loss=0.1487]
#
# [Epoch 105] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.94it/s]
#
# [Epoch 105/200] Time: 29.5s
#   Train Loss: 0.0918
#   Val HR@10: 0.1029
#   Val NDCG@10: 0.0484
#   Val MRR@10: 0.0321
#   No improvement (9/20)
# Epoch 106: 100%|███████████████| 2177/2177 [00:28<00:00, 75.23it/s, loss=0.0860]
#
# [Epoch 106] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.86it/s]
#
# [Epoch 106/200] Time: 29.6s
#   Train Loss: 0.0920
#   Val HR@10: 0.1052
#   Val NDCG@10: 0.0481
#   Val MRR@10: 0.0310
#   No improvement (10/20)
# Epoch 107: 100%|███████████████| 2177/2177 [00:29<00:00, 74.74it/s, loss=0.0527]
#
# [Epoch 107] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.92it/s]
#
# [Epoch 107/200] Time: 29.7s
#   Train Loss: 0.0927
#   Val HR@10: 0.1059
#   Val NDCG@10: 0.0497
#   Val MRR@10: 0.0329
#   No improvement (11/20)
# Epoch 108: 100%|███████████████| 2177/2177 [00:29<00:00, 74.93it/s, loss=0.1798]
#
# [Epoch 108] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.38it/s]
#
# [Epoch 108/200] Time: 29.7s
#   Train Loss: 0.0932
#   Val HR@10: 0.1057
#   Val NDCG@10: 0.0495
#   Val MRR@10: 0.0327
#   No improvement (12/20)
# Epoch 109: 100%|███████████████| 2177/2177 [00:28<00:00, 75.40it/s, loss=0.1510]
#
# [Epoch 109] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.43it/s]
#
# [Epoch 109/200] Time: 29.5s
#   Train Loss: 0.0917
#   Val HR@10: 0.1026
#   Val NDCG@10: 0.0469
#   Val MRR@10: 0.0304
#   No improvement (13/20)
# Epoch 110: 100%|███████████████| 2177/2177 [00:28<00:00, 75.12it/s, loss=0.0779]
#
# [Epoch 110] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 36.28it/s]
#
# [Epoch 110/200] Time: 29.6s
#   Train Loss: 0.0920
#   Val HR@10: 0.1072
#   Val NDCG@10: 0.0492
#   Val MRR@10: 0.0319
#   No improvement (14/20)
# Epoch 111: 100%|███████████████| 2177/2177 [00:29<00:00, 74.53it/s, loss=0.1306]
#
# [Epoch 111] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.97it/s]
#
# [Epoch 111/200] Time: 29.8s
#   Train Loss: 0.0904
#   Val HR@10: 0.0983
#   Val NDCG@10: 0.0476
#   Val MRR@10: 0.0324
#   No improvement (15/20)
# Epoch 112: 100%|███████████████| 2177/2177 [00:29<00:00, 74.12it/s, loss=0.1115]
#
# [Epoch 112] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.10it/s]
#
# [Epoch 112/200] Time: 30.0s
#   Train Loss: 0.0918
#   Val HR@10: 0.1087
#   Val NDCG@10: 0.0506
#   Val MRR@10: 0.0334
#   No improvement (16/20)
# Epoch 113: 100%|███████████████| 2177/2177 [00:30<00:00, 72.46it/s, loss=0.1005]
#
# [Epoch 113] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.95it/s]
#
# [Epoch 113/200] Time: 30.7s
#   Train Loss: 0.0919
#   Val HR@10: 0.1132
#   Val NDCG@10: 0.0531
#   Val MRR@10: 0.0352
#   ✓ New best! (0.0524 → 0.0531)
# Epoch 114: 100%|███████████████| 2177/2177 [00:30<00:00, 71.45it/s, loss=0.0721]
#
# [Epoch 114] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.71it/s]
#
# [Epoch 114/200] Time: 31.1s
#   Train Loss: 0.0909
#   Val HR@10: 0.1082
#   Val NDCG@10: 0.0501
#   Val MRR@10: 0.0328
#   No improvement (1/20)
# Epoch 115: 100%|███████████████| 2177/2177 [00:30<00:00, 71.82it/s, loss=0.0576]
#
# [Epoch 115] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.14it/s]
#
# [Epoch 115/200] Time: 30.9s
#   Train Loss: 0.0907
#   Val HR@10: 0.1092
#   Val NDCG@10: 0.0502
#   Val MRR@10: 0.0327
#   No improvement (2/20)
# Epoch 116: 100%|███████████████| 2177/2177 [00:29<00:00, 73.08it/s, loss=0.0939]
#
# [Epoch 116] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.64it/s]
#
# [Epoch 116/200] Time: 30.4s
#   Train Loss: 0.0909
#   Val HR@10: 0.1130
#   Val NDCG@10: 0.0514
#   Val MRR@10: 0.0330
#   No improvement (3/20)
# Epoch 117: 100%|███████████████| 2177/2177 [00:29<00:00, 74.52it/s, loss=0.0335]
#
# [Epoch 117] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.08it/s]
#
# [Epoch 117/200] Time: 29.9s
#   Train Loss: 0.0916
#   Val HR@10: 0.1074
#   Val NDCG@10: 0.0490
#   Val MRR@10: 0.0317
#   No improvement (4/20)
# Epoch 118: 100%|███████████████| 2177/2177 [00:29<00:00, 74.80it/s, loss=0.1540]
#
# [Epoch 118] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.83it/s]
#
# [Epoch 118/200] Time: 29.7s
#   Train Loss: 0.0915
#   Val HR@10: 0.1067
#   Val NDCG@10: 0.0496
#   Val MRR@10: 0.0326
#   No improvement (5/20)
# Epoch 119: 100%|███████████████| 2177/2177 [00:29<00:00, 74.75it/s, loss=0.1135]
#
# [Epoch 119] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.21it/s]
#
# [Epoch 119/200] Time: 29.8s
#   Train Loss: 0.0908
#   Val HR@10: 0.1095
#   Val NDCG@10: 0.0501
#   Val MRR@10: 0.0325
#   No improvement (6/20)
# Epoch 120: 100%|███████████████| 2177/2177 [00:29<00:00, 74.44it/s, loss=0.0880]
#
# [Epoch 120] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.87it/s]
#
# [Epoch 120/200] Time: 29.9s
#   Train Loss: 0.0910
#   Val HR@10: 0.1057
#   Val NDCG@10: 0.0480
#   Val MRR@10: 0.0307
#   No improvement (7/20)
# Epoch 121: 100%|███████████████| 2177/2177 [00:29<00:00, 74.53it/s, loss=0.1014]
#
# [Epoch 121] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.50it/s]
#
# [Epoch 121/200] Time: 29.8s
#   Train Loss: 0.0916
#   Val HR@10: 0.1107
#   Val NDCG@10: 0.0507
#   Val MRR@10: 0.0328
#   No improvement (8/20)
# Epoch 122: 100%|███████████████| 2177/2177 [00:29<00:00, 74.06it/s, loss=0.0910]
#
# [Epoch 122] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.51it/s]
#
# [Epoch 122/200] Time: 30.0s
#   Train Loss: 0.0900
#   Val HR@10: 0.1034
#   Val NDCG@10: 0.0480
#   Val MRR@10: 0.0314
#   No improvement (9/20)
# Epoch 123: 100%|███████████████| 2177/2177 [00:29<00:00, 74.22it/s, loss=0.1049]
#
# [Epoch 123] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 36.82it/s]
#
# [Epoch 123/200] Time: 30.0s
#   Train Loss: 0.0907
#   Val HR@10: 0.1099
#   Val NDCG@10: 0.0514
#   Val MRR@10: 0.0340
#   No improvement (10/20)
# Epoch 124: 100%|███████████████| 2177/2177 [00:29<00:00, 74.36it/s, loss=0.1122]
#
# [Epoch 124] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.06it/s]
#
# [Epoch 124/200] Time: 29.9s
#   Train Loss: 0.0915
#   Val HR@10: 0.1087
#   Val NDCG@10: 0.0499
#   Val MRR@10: 0.0324
#   No improvement (11/20)
# Epoch 125: 100%|███████████████| 2177/2177 [00:29<00:00, 74.22it/s, loss=0.0741]
#
# [Epoch 125] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.23it/s]
#
# [Epoch 125/200] Time: 30.0s
#   Train Loss: 0.0913
#   Val HR@10: 0.1057
#   Val NDCG@10: 0.0495
#   Val MRR@10: 0.0327
#   No improvement (12/20)
# Epoch 126: 100%|███████████████| 2177/2177 [00:29<00:00, 74.30it/s, loss=0.0468]
#
# [Epoch 126] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.83it/s]
#
# [Epoch 126/200] Time: 29.9s
#   Train Loss: 0.0898
#   Val HR@10: 0.1013
#   Val NDCG@10: 0.0475
#   Val MRR@10: 0.0314
#   No improvement (13/20)
# Epoch 127: 100%|███████████████| 2177/2177 [00:29<00:00, 74.43it/s, loss=0.1373]
#
# [Epoch 127] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.41it/s]
#
# [Epoch 127/200] Time: 29.9s
#   Train Loss: 0.0901
#   Val HR@10: 0.0961
#   Val NDCG@10: 0.0455
#   Val MRR@10: 0.0305
#   No improvement (14/20)
# Epoch 128: 100%|███████████████| 2177/2177 [00:29<00:00, 74.50it/s, loss=0.0590]
#
# [Epoch 128] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.22it/s]
#
# [Epoch 128/200] Time: 29.9s
#   Train Loss: 0.0906
#   Val HR@10: 0.1064
#   Val NDCG@10: 0.0495
#   Val MRR@10: 0.0326
#   No improvement (15/20)
# Epoch 129: 100%|███████████████| 2177/2177 [00:29<00:00, 74.49it/s, loss=0.1200]
#
# [Epoch 129] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.26it/s]
#
# [Epoch 129/200] Time: 29.9s
#   Train Loss: 0.0907
#   Val HR@10: 0.1092
#   Val NDCG@10: 0.0506
#   Val MRR@10: 0.0332
#   No improvement (16/20)
# Epoch 130: 100%|███████████████| 2177/2177 [00:29<00:00, 74.19it/s, loss=0.1047]
#
# [Epoch 130] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.78it/s]
#
# [Epoch 130/200] Time: 30.0s
#   Train Loss: 0.0902
#   Val HR@10: 0.0986
#   Val NDCG@10: 0.0451
#   Val MRR@10: 0.0292
#   No improvement (17/20)
# Epoch 131: 100%|███████████████| 2177/2177 [00:29<00:00, 73.95it/s, loss=0.0591]
#
# [Epoch 131] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.62it/s]
#
# [Epoch 131/200] Time: 30.1s
#   Train Loss: 0.0912
#   Val HR@10: 0.1069
#   Val NDCG@10: 0.0504
#   Val MRR@10: 0.0336
#   No improvement (18/20)
# Epoch 132: 100%|███████████████| 2177/2177 [00:29<00:00, 74.07it/s, loss=0.0636]
#
# [Epoch 132] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 38.74it/s]
#
# [Epoch 132/200] Time: 30.0s
#   Train Loss: 0.0905
#   Val HR@10: 0.1066
#   Val NDCG@10: 0.0484
#   Val MRR@10: 0.0313
#   No improvement (19/20)
# Epoch 133: 100%|███████████████| 2177/2177 [00:29<00:00, 73.74it/s, loss=0.0484]
#
# [Epoch 133] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 39.01it/s]
#
# [Epoch 133/200] Time: 30.1s
#   Train Loss: 0.0903
#   Val HR@10: 0.1094
#   Val NDCG@10: 0.0518
#   Val MRR@10: 0.0347
#   No improvement (20/20)
#
# ⚠ Early stopping triggered after 133 epochs
#
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Total time: 64.2 minutes
# Best epoch: 113
# Best val NDCG@10: 0.0531
# ============================================================
#
#
# ============================================================
# TESTING
# ============================================================
# Loading best model...
#
# ============================================================
# TESTING ON TEST SET
# ============================================================
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 37.65it/s]
#
# ============================================================
# Test Results
# ============================================================
#   HR@5        : 0.0515
#   NDCG@5      : 0.0298
#   MRR@5       : 0.0228
#   HR@10       : 0.0979
#   NDCG@10     : 0.0446
#   MRR@10      : 0.0287
#   HR@20       : 0.1767
#   NDCG@20     : 0.0643
#   MRR@20      : 0.0340
# ============================================================
#
#
# Computing metrics by user group...
#
# ============================================================
# Test Results by User Group
# ============================================================
#
# SHORT:
#   HR@10       : 0.1420
#   NDCG@10     : 0.0776
#   MRR@10      : 0.0583
#   HR@20       : 0.2593
#   NDCG@20     : 0.1064
#   MRR@20      : 0.0656
#   count       : 162
#
# MEDIUM:
#   HR@10       : 0.0967
#   NDCG@10     : 0.0437
#   MRR@10      : 0.0279
#   HR@20       : 0.1744
#   NDCG@20     : 0.0631
#   MRR@20      : 0.0331
#   count       : 5872
#
# OVERALL:
#   HR@10       : 0.0979
#   NDCG@10     : 0.0446
#   MRR@10      : 0.0287
#   HR@20       : 0.1767
#   NDCG@20     : 0.0643
#   MRR@20      : 0.0340
#   count       : 6034
# ============================================================
#
#
# ✅ Experiment complete! Results saved to: results/sasrec_20260224_205408
#
# ✓ SASRec complete
#
# [2/5] Training BERT4Rec (Bidirectional Transformer)...
# Using device: cuda
#
# [1/5] Loading preprocessed data...
#   Users: 6,034
#   Items: 3,533
#
# [2/5] Loading co-occurrence graph...
#   Edges: 151,874
#
# [3/5] Creating dataloaders...
#   Train batches: 2177
#   Val batches: 24
#   Test batches: 24
#
# [4/5] Creating model: bert4rec
#   Parameters: 329,472
#   Experiment dir: results/bert4rec_20260224_215849
#
# [5/5] Creating trainer...
#
# ============================================================
# TRAINING
# ============================================================
# ============================================================
# STARTING TRAINING
# ============================================================
# Device: cuda
# ...
#   Train Loss: 0.0981
#   Val HR@10: 0.1220
#   Val NDCG@10: 0.0575
#   Val MRR@10: 0.0382
#   No improvement (1/20)
# Epoch 43: 100%|████████████████| 2177/2177 [00:25<00:00, 86.58it/s, loss=0.0811]
#
# [Epoch 43] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.90it/s]
#
# [Epoch 43/200] Time: 26.0s
#   Train Loss: 0.0994
#   Val HR@10: 0.1266
#   Val NDCG@10: 0.0593
#   Val MRR@10: 0.0393
#   No improvement (2/20)
# Epoch 44: 100%|████████████████| 2177/2177 [00:25<00:00, 85.75it/s, loss=0.0944]
#
# [Epoch 44] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.47it/s]
#
# [Epoch 44/200] Time: 26.2s
#   Train Loss: 0.0975
#   Val HR@10: 0.1210
#   Val NDCG@10: 0.0562
#   Val MRR@10: 0.0369
#   No improvement (3/20)
# Epoch 45: 100%|████████████████| 2177/2177 [00:25<00:00, 86.40it/s, loss=0.0886]
#
# [Epoch 45] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.47it/s]
#
# [Epoch 45/200] Time: 26.0s
#   Train Loss: 0.0984
#   Val HR@10: 0.1299
#   Val NDCG@10: 0.0607
#   Val MRR@10: 0.0401
#   ✓ New best! (0.0599 → 0.0607)
# Epoch 46: 100%|████████████████| 2177/2177 [00:25<00:00, 86.09it/s, loss=0.0579]
#
# [Epoch 46] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.03it/s]
#
# [Epoch 46/200] Time: 26.1s
#   Train Loss: 0.0975
#   Val HR@10: 0.1326
#   Val NDCG@10: 0.0612
#   Val MRR@10: 0.0399
#   ✓ New best! (0.0607 → 0.0612)
# Epoch 47: 100%|████████████████| 2177/2177 [00:25<00:00, 86.14it/s, loss=0.1321]
#
# [Epoch 47] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 26.41it/s]
#
# [Epoch 47/200] Time: 26.2s
#   Train Loss: 0.0970
#   Val HR@10: 0.1260
#   Val NDCG@10: 0.0586
#   Val MRR@10: 0.0386
#   No improvement (1/20)
# Epoch 48: 100%|████████████████| 2177/2177 [00:25<00:00, 86.25it/s, loss=0.0620]
#
# [Epoch 48] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.71it/s]
#
# [Epoch 48/200] Time: 26.1s
#   Train Loss: 0.0973
#   Val HR@10: 0.1304
#   Val NDCG@10: 0.0601
#   Val MRR@10: 0.0391
#   No improvement (2/20)
# Epoch 49: 100%|████████████████| 2177/2177 [00:25<00:00, 85.91it/s, loss=0.1079]
#
# [Epoch 49] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.22it/s]
#
# [Epoch 49/200] Time: 26.2s
#   Train Loss: 0.0968
#   Val HR@10: 0.1309
#   Val NDCG@10: 0.0612
#   Val MRR@10: 0.0404
#   No improvement (3/20)
# Epoch 50: 100%|████████████████| 2177/2177 [00:25<00:00, 83.92it/s, loss=0.1168]
#
# [Epoch 50] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.58it/s]
#
# [Epoch 50/200] Time: 26.8s
#   Train Loss: 0.0968
#   Val HR@10: 0.1311
#   Val NDCG@10: 0.0628
#   Val MRR@10: 0.0424
#   ✓ New best! (0.0612 → 0.0628)
# Epoch 51: 100%|████████████████| 2177/2177 [00:25<00:00, 85.75it/s, loss=0.1472]
#
# [Epoch 51] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.81it/s]
#
# [Epoch 51/200] Time: 26.2s
#   Train Loss: 0.0971
#   Val HR@10: 0.1319
#   Val NDCG@10: 0.0626
#   Val MRR@10: 0.0419
#   No improvement (1/20)
# Epoch 52: 100%|████████████████| 2177/2177 [00:25<00:00, 85.77it/s, loss=0.0740]
#
# [Epoch 52] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 27.02it/s]
#
# [Epoch 52/200] Time: 26.3s
#   Train Loss: 0.0957
#   Val HR@10: 0.1306
#   Val NDCG@10: 0.0614
#   Val MRR@10: 0.0407
#   No improvement (2/20)
# Epoch 53: 100%|████████████████| 2177/2177 [00:25<00:00, 85.65it/s, loss=0.0977]
#
# [Epoch 53] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.94it/s]
#
# [Epoch 53/200] Time: 26.2s
#   Train Loss: 0.0959
#   Val HR@10: 0.1334
#   Val NDCG@10: 0.0616
#   Val MRR@10: 0.0402
#   No improvement (3/20)
# Epoch 54: 100%|████████████████| 2177/2177 [00:25<00:00, 86.05it/s, loss=0.0844]
#
# [Epoch 54] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.07it/s]
#
# [Epoch 54/200] Time: 26.2s
#   Train Loss: 0.0957
#   Val HR@10: 0.1294
#   Val NDCG@10: 0.0591
#   Val MRR@10: 0.0381
#   No improvement (4/20)
# Epoch 55: 100%|████████████████| 2177/2177 [00:25<00:00, 85.48it/s, loss=0.1011]
#
# [Epoch 55] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 26.95it/s]
#
# [Epoch 55/200] Time: 26.4s
#   Train Loss: 0.0949
#   Val HR@10: 0.1326
#   Val NDCG@10: 0.0608
#   Val MRR@10: 0.0395
#   No improvement (5/20)
# Epoch 56: 100%|████████████████| 2177/2177 [00:25<00:00, 86.55it/s, loss=0.0898]
#
# [Epoch 56] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.27it/s]
#
# [Epoch 56/200] Time: 26.0s
#   Train Loss: 0.0954
#   Val HR@10: 0.1289
#   Val NDCG@10: 0.0612
#   Val MRR@10: 0.0408
#   No improvement (6/20)
# Epoch 57: 100%|████████████████| 2177/2177 [00:25<00:00, 86.66it/s, loss=0.0861]
#
# [Epoch 57] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 27.52it/s]
#
# [Epoch 57/200] Time: 26.0s
#   Train Loss: 0.0952
#   Val HR@10: 0.1351
#   Val NDCG@10: 0.0622
#   Val MRR@10: 0.0404
#   No improvement (7/20)
# Epoch 58: 100%|████████████████| 2177/2177 [00:25<00:00, 85.82it/s, loss=0.0993]
#
# [Epoch 58] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.57it/s]
#
# [Epoch 58/200] Time: 26.2s
#   Train Loss: 0.0953
#   Val HR@10: 0.1308
#   Val NDCG@10: 0.0614
#   Val MRR@10: 0.0407
#   No improvement (8/20)
# Epoch 59: 100%|████████████████| 2177/2177 [00:25<00:00, 86.35it/s, loss=0.1584]
#
# [Epoch 59] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 27.84it/s]
#
# [Epoch 59/200] Time: 26.1s
#   Train Loss: 0.0948
#   Val HR@10: 0.1377
#   Val NDCG@10: 0.0640
#   Val MRR@10: 0.0421
#   ✓ New best! (0.0628 → 0.0640)
# Epoch 60: 100%|████████████████| 2177/2177 [00:25<00:00, 86.89it/s, loss=0.0660]
#
# [Epoch 60] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.77it/s]
#
# [Epoch 60/200] Time: 25.9s
#   Train Loss: 0.0948
#   Val HR@10: 0.1371
#   Val NDCG@10: 0.0621
#   Val MRR@10: 0.0399
#   No improvement (1/20)
# Epoch 61: 100%|████████████████| 2177/2177 [00:25<00:00, 86.69it/s, loss=0.0864]
#
# [Epoch 61] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.28it/s]
#
# [Epoch 61/200] Time: 26.0s
#   Train Loss: 0.0945
#   Val HR@10: 0.1354
#   Val NDCG@10: 0.0629
#   Val MRR@10: 0.0412
#   No improvement (2/20)
# Epoch 62: 100%|████████████████| 2177/2177 [00:25<00:00, 86.65it/s, loss=0.1435]
#
# [Epoch 62] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.23it/s]
#
# [Epoch 62/200] Time: 26.0s
#   Train Loss: 0.0953
#   Val HR@10: 0.1381
#   Val NDCG@10: 0.0629
#   Val MRR@10: 0.0405
#   No improvement (3/20)
# Epoch 63: 100%|████████████████| 2177/2177 [00:25<00:00, 86.76it/s, loss=0.1013]
#
# [Epoch 63] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.44it/s]
#
# [Epoch 63/200] Time: 25.9s
#   Train Loss: 0.0951
#   Val HR@10: 0.1377
#   Val NDCG@10: 0.0657
#   Val MRR@10: 0.0441
#   ✓ New best! (0.0640 → 0.0657)
# Epoch 64: 100%|████████████████| 2177/2177 [00:25<00:00, 86.44it/s, loss=0.0939]
#
# [Epoch 64] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.68it/s]
#
# [Epoch 64/200] Time: 26.0s
#   Train Loss: 0.0940
#   Val HR@10: 0.1324
#   Val NDCG@10: 0.0636
#   Val MRR@10: 0.0430
#   No improvement (1/20)
# Epoch 65: 100%|████████████████| 2177/2177 [00:25<00:00, 86.62it/s, loss=0.0561]
#
# [Epoch 65] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 27.95it/s]
#
# [Epoch 65/200] Time: 26.0s
#   Train Loss: 0.0938
#   Val HR@10: 0.1371
#   Val NDCG@10: 0.0643
#   Val MRR@10: 0.0426
#   No improvement (2/20)
# Epoch 66: 100%|████████████████| 2177/2177 [00:25<00:00, 84.94it/s, loss=0.0986]
#
# [Epoch 66] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.69it/s]
#
# [Epoch 66/200] Time: 26.5s
#   Train Loss: 0.0942
#   Val HR@10: 0.1329
#   Val NDCG@10: 0.0622
#   Val MRR@10: 0.0410
#   No improvement (3/20)
# Epoch 67: 100%|████████████████| 2177/2177 [00:25<00:00, 86.64it/s, loss=0.1019]
#
# [Epoch 67] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.45it/s]
#
# [Epoch 67/200] Time: 26.0s
#   Train Loss: 0.0938
#   Val HR@10: 0.1352
#   Val NDCG@10: 0.0625
#   Val MRR@10: 0.0408
#   No improvement (4/20)
# Epoch 68: 100%|████████████████| 2177/2177 [00:25<00:00, 86.53it/s, loss=0.0730]
#
# [Epoch 68] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 27.87it/s]
#
# [Epoch 68/200] Time: 26.0s
#   Train Loss: 0.0937
#   Val HR@10: 0.1329
#   Val NDCG@10: 0.0627
#   Val MRR@10: 0.0416
#   No improvement (5/20)
# Epoch 69: 100%|████████████████| 2177/2177 [00:25<00:00, 84.83it/s, loss=0.0898]
#
# [Epoch 69] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 29.04it/s]
#
# [Epoch 69/200] Time: 26.5s
#   Train Loss: 0.0930
#   Val HR@10: 0.1326
#   Val NDCG@10: 0.0622
#   Val MRR@10: 0.0413
#   No improvement (6/20)
# Epoch 70: 100%|████████████████| 2177/2177 [00:25<00:00, 85.56it/s, loss=0.0674]
#
# [Epoch 70] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.67it/s]
#
# [Epoch 70/200] Time: 26.3s
#   Train Loss: 0.0930
#   Val HR@10: 0.1319
#   Val NDCG@10: 0.0607
#   Val MRR@10: 0.0394
#   No improvement (7/20)
# Epoch 71: 100%|████████████████| 2177/2177 [00:25<00:00, 85.85it/s, loss=0.0560]
#
# [Epoch 71] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.97it/s]
#
# [Epoch 71/200] Time: 26.2s
#   Train Loss: 0.0928
#   Val HR@10: 0.1334
#   Val NDCG@10: 0.0636
#   Val MRR@10: 0.0427
#   No improvement (8/20)
# Epoch 72: 100%|████████████████| 2177/2177 [00:25<00:00, 86.20it/s, loss=0.1771]
#
# [Epoch 72] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.20it/s]
#
# [Epoch 72/200] Time: 26.1s
#   Train Loss: 0.0925
#   Val HR@10: 0.1336
#   Val NDCG@10: 0.0618
#   Val MRR@10: 0.0403
#   No improvement (9/20)
# Epoch 73: 100%|████████████████| 2177/2177 [00:25<00:00, 86.44it/s, loss=0.1246]
#
# [Epoch 73] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 27.75it/s]
#
# [Epoch 73/200] Time: 26.1s
#   Train Loss: 0.0918
#   Val HR@10: 0.1347
#   Val NDCG@10: 0.0619
#   Val MRR@10: 0.0402
#   No improvement (10/20)
# Epoch 74: 100%|████████████████| 2177/2177 [00:25<00:00, 86.20it/s, loss=0.1145]
#
# [Epoch 74] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 27.62it/s]
#
# [Epoch 74/200] Time: 26.1s
#   Train Loss: 0.0934
#   Val HR@10: 0.1356
#   Val NDCG@10: 0.0623
#   Val MRR@10: 0.0406
#   No improvement (11/20)
# Epoch 75: 100%|████████████████| 2177/2177 [00:24<00:00, 87.47it/s, loss=0.0824]
#
# [Epoch 75] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.45it/s]
#
# [Epoch 75/200] Time: 25.7s
#   Train Loss: 0.0922
#   Val HR@10: 0.1336
#   Val NDCG@10: 0.0625
#   Val MRR@10: 0.0413
#   No improvement (12/20)
# Epoch 76: 100%|████████████████| 2177/2177 [00:25<00:00, 86.84it/s, loss=0.0876]
#
# [Epoch 76] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 27.50it/s]
#
# [Epoch 76/200] Time: 25.9s
#   Train Loss: 0.0919
#   Val HR@10: 0.1389
#   Val NDCG@10: 0.0633
#   Val MRR@10: 0.0409
#   No improvement (13/20)
# Epoch 77: 100%|████████████████| 2177/2177 [00:24<00:00, 87.36it/s, loss=0.1739]
#
# [Epoch 77] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 26.37it/s]
#
# [Epoch 77/200] Time: 25.8s
#   Train Loss: 0.0923
#   Val HR@10: 0.1367
#   Val NDCG@10: 0.0634
#   Val MRR@10: 0.0415
#   No improvement (14/20)
# Epoch 78: 100%|████████████████| 2177/2177 [00:25<00:00, 85.64it/s, loss=0.0786]
#
# [Epoch 78] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.09it/s]
#
# [Epoch 78/200] Time: 26.3s
#   Train Loss: 0.0925
#   Val HR@10: 0.1371
#   Val NDCG@10: 0.0634
#   Val MRR@10: 0.0414
#   No improvement (15/20)
# Epoch 79: 100%|████████████████| 2177/2177 [00:25<00:00, 86.90it/s, loss=0.0799]
#
# [Epoch 79] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.08it/s]
#
# [Epoch 79/200] Time: 25.9s
#   Train Loss: 0.0917
#   Val HR@10: 0.1379
#   Val NDCG@10: 0.0619
#   Val MRR@10: 0.0393
#   No improvement (16/20)
# Epoch 80: 100%|████████████████| 2177/2177 [00:25<00:00, 87.08it/s, loss=0.0725]
#
# [Epoch 80] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 27.89it/s]
#
# [Epoch 80/200] Time: 25.9s
#   Train Loss: 0.0916
#   Val HR@10: 0.1319
#   Val NDCG@10: 0.0604
#   Val MRR@10: 0.0391
#   No improvement (17/20)
# Epoch 81: 100%|████████████████| 2177/2177 [00:25<00:00, 86.38it/s, loss=0.0297]
#
# [Epoch 81] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.78it/s]
#
# [Epoch 81/200] Time: 26.0s
#   Train Loss: 0.0922
#   Val HR@10: 0.1327
#   Val NDCG@10: 0.0630
#   Val MRR@10: 0.0423
#   No improvement (18/20)
# Epoch 82: 100%|████████████████| 2177/2177 [00:25<00:00, 86.39it/s, loss=0.0378]
#
# [Epoch 82] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 27.63it/s]
#
# [Epoch 82/200] Time: 26.1s
#   Train Loss: 0.0918
#   Val HR@10: 0.1323
#   Val NDCG@10: 0.0621
#   Val MRR@10: 0.0412
#   No improvement (19/20)
# Epoch 83: 100%|████████████████| 2177/2177 [00:25<00:00, 85.91it/s, loss=0.0852]
#
# [Epoch 83] Evaluating...
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.44it/s]
#
# [Epoch 83/200] Time: 26.2s
#   Train Loss: 0.0911
#   Val HR@10: 0.1342
#   Val NDCG@10: 0.0614
#   Val MRR@10: 0.0398
#   No improvement (20/20)
#
# ⚠ Early stopping triggered after 83 epochs
#
# ============================================================
# TRAINING COMPLETE
# ============================================================
# Total time: 36.2 minutes
# Best epoch: 63
# Best val NDCG@10: 0.0657
# ============================================================
#
#
# ============================================================
# TESTING
# ============================================================
# Loading best model...
#
# ============================================================
# TESTING ON TEST SET
# ============================================================
# Evaluating: 100%|███████████████████████████████| 24/24 [00:00<00:00, 28.15it/s]
#
# ============================================================
# Test Results
# ============================================================
#   HR@5        : 0.0684
#   NDCG@5      : 0.0397
#   MRR@5       : 0.0303
#   HR@10       : 0.1260
#   NDCG@10     : 0.0581
#   MRR@10      : 0.0379
#   HR@20       : 0.2135
#   NDCG@20     : 0.0801
#   MRR@20      : 0.0438
# ============================================================
#
#
# Computing metrics by user group...
#
# ============================================================
# Test Results by User Group
# ============================================================
#
# SHORT:
#   HR@10       : 0.2284
#   NDCG@10     : 0.0964
#   MRR@10      : 0.0580
#   HR@20       : 0.3395
#   NDCG@20     : 0.1246
#   MRR@20      : 0.0657
#   count       : 162
#
# MEDIUM:
#   HR@10       : 0.1231
#   NDCG@10     : 0.0571
#   MRR@10      : 0.0373
#   HR@20       : 0.2100
#   NDCG@20     : 0.0789
#   MRR@20      : 0.0432
#   count       : 5872
#
# OVERALL:
#   HR@10       : 0.1260
#   NDCG@10     : 0.0581
#   MRR@10      : 0.0379
#   HR@20       : 0.2135
#   NDCG@20     : 0.0801
#   MRR@20      : 0.0438
#   count       : 6034
# ============================================================
#
#
# ✅ Experiment complete! Results saved to: results/caser_20260224_231751
#
# ✓ Caser complete
#
# ========================================
# ALL BASELINE EXPERIMENTS COMPLETE!
# ========================================
#
# Results saved in: results/
#
# Models trained:
#   ✓ SASRec (Transformer baseline)
#   ✓ BERT4Rec (Bidirectional Transformer)
#   ✓ GRU4Rec (RNN baseline)
#   ✓ LightGCN (GNN baseline)
#   ✓ Caser (CNN baseline)
#
# To analyze results, run:
#   python -m experiments.analyze_results
#
#
# ================================================================================
# ✅ All baseline experiments complete!
# ⏱️  Total time: 3.01 hours
# ================================================================================

# %% [markdown]
# ## Step 5: Collect Results - Performance Metrics
#
# Load all experimental results and create comprehensive comparison tables

# %%
# !zip -r /kaggle/working/.virtual_documents/results.zip /kaggle/working/length-adaptive/results
# Out:
#   adding: kaggle/working/length-adaptive/results/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/tcn_bert4rec_20260224_040933/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/tcn_bert4rec_20260224_040933/checkpoint_epoch_100.pt (deflated 11%)
#   adding: kaggle/working/length-adaptive/results/tcn_bert4rec_20260224_040933/config.json (deflated 51%)
#   adding: kaggle/working/length-adaptive/results/tcn_bert4rec_20260224_040933/results.json (deflated 62%)
#   adding: kaggle/working/length-adaptive/results/tcn_bert4rec_20260224_040933/history.json (deflated 72%)
#   adding: kaggle/working/length-adaptive/results/hybrid_fixed_20260217_090038/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid_fixed_20260217_090038/config.json (deflated 46%)
#   adding: kaggle/working/length-adaptive/results/hybrid_fixed_20260217_090038/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid_fixed_20260217_090038/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/bert_hybrid_discrete_20260224_154246/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/bert_hybrid_discrete_20260224_154246/config.json (deflated 51%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_100.pt (deflated 12%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint.pt (deflated 12%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_10.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_70.pt (deflated 12%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_130.pt (deflated 12%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_80.pt (deflated 12%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/history.json (deflated 73%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_30.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_90.pt (deflated 12%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_110.pt (deflated 12%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_120.pt (deflated 12%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_60.pt (deflated 11%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_20.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/best_model.pt (deflated 12%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_40.pt (deflated 9%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260224_205408/checkpoint_epoch_50.pt (deflated 10%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/checkpoint.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/checkpoint_epoch_10.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/checkpoint_epoch_70.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/checkpoint_epoch_80.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/history.json (deflated 72%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/checkpoint_epoch_30.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/checkpoint_epoch_60.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/checkpoint_epoch_20.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/best_model.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/checkpoint_epoch_40.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/caser_20260224_231751/checkpoint_epoch_50.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/hybrid_learnable_20260217_095648/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid_learnable_20260217_095648/config.json (deflated 46%)
#   adding: kaggle/working/length-adaptive/results/hybrid_learnable_20260217_095648/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid_learnable_20260217_095648/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260224_223622/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260224_223622/checkpoint.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260224_223622/checkpoint_epoch_10.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260224_223622/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260224_223622/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260224_223622/history.json (deflated 72%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260224_223622/checkpoint_epoch_30.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260224_223622/checkpoint_epoch_20.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260224_223622/best_model.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/gru4rec_20260224_223622/checkpoint_epoch_40.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260224_215849/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260224_215849/checkpoint.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260224_215849/checkpoint_epoch_10.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260224_215849/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260224_215849/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260224_215849/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260224_215849/checkpoint_epoch_30.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260224_215849/checkpoint_epoch_60.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260224_215849/checkpoint_epoch_20.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260224_215849/best_model.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260224_215849/checkpoint_epoch_40.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/bert4rec_20260224_215849/checkpoint_epoch_50.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260224_231025/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260224_231025/checkpoint.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260224_231025/checkpoint_epoch_10.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260224_231025/config.json (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260224_231025/results.json (deflated 65%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260224_231025/history.json (deflated 76%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260224_231025/checkpoint_epoch_20.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/lightgcn_20260224_231025/best_model.pt (deflated 7%)
#   adding: kaggle/working/length-adaptive/results/tgt_bert4rec_20260224_074322/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/tgt_bert4rec_20260224_074322/config.json (deflated 51%)
#   adding: kaggle/working/length-adaptive/results/tgt_bert4rec_20260224_074322/checkpoint_epoch_140.pt (deflated 8%)
#   adding: kaggle/working/length-adaptive/results/best_models_summary.csv (deflated 48%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260217_083601/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260217_083601/config.json (deflated 47%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260217_083601/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/sasrec_20260217_083601/history.json (deflated 71%)
#   adding: kaggle/working/length-adaptive/results/hybrid_discrete_20260217_093549/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid_discrete_20260217_093549/config.json (deflated 46%)
#   adding: kaggle/working/length-adaptive/results/hybrid_discrete_20260217_093549/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid_discrete_20260217_093549/history.json (deflated 70%)
#   adding: kaggle/working/length-adaptive/results/hybrid_continuous_20260217_104150/ (stored 0%)
#   adding: kaggle/working/length-adaptive/results/hybrid_continuous_20260217_104150/config.json (deflated 46%)
#   adding: kaggle/working/length-adaptive/results/hybrid_continuous_20260217_104150/results.json (deflated 64%)
#   adding: kaggle/working/length-adaptive/results/hybrid_continuous_20260217_104150/history.json (deflated 71%)

# %%
import json
import pandas as pd
import numpy as np
from pathlib import Path

print("="*80)
print("📊 COLLECTING EXPERIMENTAL RESULTS")
print("="*80)

results_dir = Path('')

# Baseline models only
all_models = [
    'bert4rec',
    'sasrec',
    'gru4rec',
    'caser',
    'lightgcn'
]

# Collect all results
all_results = []
per_user_metrics = {}

for result_folder in sorted(results_dir.glob('*')):
    if result_folder.is_dir():
        results_file = result_folder / 'results.json'
        config_file = result_folder / 'config.json'
        history_file = result_folder / 'history.json'
        
        if results_file.exists() and config_file.exists():
            with open(results_file) as f:
                results = json.load(f)
            with open(config_file) as f:
                config = json.load(f)
            
            model_name = config['model']
            
            # Only include baseline models with 200 epochs
            if model_name in all_models and config.get('epochs') == 200:
                
                # Load training history if available
                best_val_history = []
                if history_file.exists():
                    with open(history_file) as f:
                        history = json.load(f)
                        best_val_history = history.get('val_metrics', [])
                
                result_data = {
                    'Model': model_name,
                    'Model_Type': 'Baseline',
                    'Folder': result_folder.name,
                    
                    # Overall metrics
                    'HR@5': results['test_metrics']['HR@5'],
                    'HR@10': results['test_metrics']['HR@10'],
                    'HR@20': results['test_metrics']['HR@20'],
                    'NDCG@5': results['test_metrics']['NDCG@5'],
                    'NDCG@10': results['test_metrics']['NDCG@10'],
                    'NDCG@20': results['test_metrics']['NDCG@20'],
                    'MRR@5': results['test_metrics']['MRR@5'],
                    'MRR@10': results['test_metrics']['MRR@10'],
                    'MRR@20': results['test_metrics']['MRR@20'],
                    
                    # Short sequence metrics
                    'Short_HR@10': results['grouped_metrics']['short']['HR@10'],
                    'Short_NDCG@10': results['grouped_metrics']['short']['NDCG@10'],
                    'Short_MRR@10': results['grouped_metrics']['short']['MRR@10'],
                    'Short_Count': results['grouped_metrics']['short']['count'],
                    
                    # Medium sequence metrics
                    'Medium_HR@10': results['grouped_metrics']['medium']['HR@10'],
                    'Medium_NDCG@10': results['grouped_metrics']['medium']['NDCG@10'],
                    'Medium_MRR@10': results['grouped_metrics']['medium']['MRR@10'],
                    'Medium_Count': results['grouped_metrics']['medium']['count'],
                    
                    # Training info
                    'Best_Epoch': results['best_epoch'],
                    'Best_Val_NDCG@10': results['best_val_metric'],
                    
                    # Config
                    'd_model': config.get('d_model', 64),
                    'n_heads': config.get('n_heads', 2),
                    'n_blocks': config.get('n_blocks', 2),
                    'gnn_layers': config.get('gnn_layers', 2),
                    'dropout': config.get('dropout', 0.2),
                    'batch_size': config.get('batch_size', 256),
                    'lr': config.get('lr', 0.001),
                }
                
                all_results.append(result_data)
                
                # Store model name for later reference
                per_user_metrics[model_name] = result_folder

# Create DataFrame
df_results = pd.DataFrame(all_results)

# Sort by NDCG@10 (descending)
df_results = df_results.sort_values('NDCG@10', ascending=False).reset_index(drop=True)

print(f"\n✅ Collected results from {len(df_results)} experiments")
print("\nModels found:")
print("\nBASELINES:")
for model in df_results['Model'].values:
    print(f"  - {model}")

print("\n" + "="*80)
print("📈 OVERALL PERFORMANCE RANKING (by NDCG@10)")
print("="*80)
print(df_results[['Model', 'Model_Type', 'NDCG@10', 'HR@10', 'MRR@10', 'Best_Epoch']].to_string(index=False))
print("="*80)
# Out:
# ================================================================================
# 📊 COLLECTING EXPERIMENTAL RESULTS
# ================================================================================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_55/2331777610.py in <cell line: 0>()
#      35                 config = json.load(f)
#      36
# ---> 37             model_name = config['model']
#      38
#      39             # Only include baseline models with 200 epochs
#
# KeyError: 'model'

# %% [markdown]
# ## Step 6: Baseline Model Comparison
#
# Compare performance across all baseline models

# %%
import numpy as np

print("="*80)
print("📊 BASELINE MODEL COMPARISON")
print("="*80)

# Get baselines
baselines = df_results[['Model', 'NDCG@10', 'HR@10', 'MRR@10']].copy()

print("\n" + "="*80)
print("BASELINE MODELS PERFORMANCE")
print("="*80)
print(baselines.to_string(index=False))
print("="*80)

# Find best and worst performers
best_model = baselines.iloc[0]
worst_model = baselines.iloc[-1]

print(f"\n🏆 Best performing baseline: {best_model['Model']}")
print(f"   NDCG@10: {best_model['NDCG@10']:.6f}")
print(f"   HR@10: {best_model['HR@10']:.6f}")
print(f"   MRR@10: {best_model['MRR@10']:.6f}")

print(f"\n📊 Lowest performing baseline: {worst_model['Model']}")
print(f"   NDCG@10: {worst_model['NDCG@10']:.6f}")
print(f"   HR@10: {worst_model['HR@10']:.6f}")
print(f"   MRR@10: {worst_model['MRR@10']:.6f}")

# Calculate performance gap
gap_ndcg = ((best_model['NDCG@10'] - worst_model['NDCG@10']) / worst_model['NDCG@10']) * 100
gap_hr = ((best_model['HR@10'] - worst_model['HR@10']) / worst_model['HR@10']) * 100

print(f"\n📈 Performance gap (best vs worst):")
print(f"   NDCG@10: {gap_ndcg:+.2f}%")
print(f"   HR@10: {gap_hr:+.2f}%")

# Compare each model to the best
print("\n" + "="*80)
print("COMPARISON TO BEST BASELINE")
print("="*80)
for _, row in baselines.iterrows():
    if row['Model'] == best_model['Model']:
        print(f"{row['Model']:15s}: BEST PERFORMER")
    else:
        ndcg_diff = ((row['NDCG@10'] - best_model['NDCG@10']) / best_model['NDCG@10']) * 100
        hr_diff = ((row['HR@10'] - best_model['HR@10']) / best_model['HR@10']) * 100
        print(f"{row['Model']:15s}: {ndcg_diff:+6.2f}% NDCG@10, {hr_diff:+6.2f}% HR@10")

print("="*80)

# Create publication-ready table
print("\n📋 PUBLICATION TABLE FORMAT:")
print("-"*100)
print("Model                          | Type     | NDCG@10      | HR@10        | MRR@10       | Epoch")
print("-"*100)
for idx, row in df_results.iterrows():
    model = row['Model']
    model_type = row['Model_Type']
    ndcg = row['NDCG@10']
    hr = row['HR@10']
    mrr = row['MRR@10']
    epoch = row['Best_Epoch']
    
    print(f"{model:30s} | {model_type:8s} | {ndcg:.6f}     | {hr:.6f}     | {mrr:.6f}     | {epoch:3d}")

print("-"*100)
print("="*80)
# Out:
# ================================================================================
# 📊 BASELINE MODEL COMPARISON
# ================================================================================
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_55/264801007.py in <cell line: 0>()
#       6
#       7 # Get baselines
# ----> 8 baselines = df_results[['Model', 'NDCG@10', 'HR@10', 'MRR@10']].copy()
#       9
#      10 print("\n" + "="*80)
#
# NameError: name 'df_results' is not defined

# %% [markdown]
# ## Step 7: Performance by Sequence Length
#
# Detailed analysis of short vs medium sequence performance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set publication-quality style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 6)
plt.rcParams['font.size'] = 11

print("="*80)
print("👥 PERFORMANCE BY SEQUENCE LENGTH")
print("="*80)

# Short sequences
print("\nSHORT SEQUENCES (<10 items, n=162 users):")
print("-"*80)
df_short = df_results[['Model', 'Model_Type', 'Short_NDCG@10', 'Short_HR@10', 'Short_MRR@10']].copy()
df_short.columns = ['Model', 'Type', 'NDCG@10', 'HR@10', 'MRR@10']
print(df_short.sort_values('NDCG@10', ascending=False).to_string(index=False))

# Get best baseline for short
best_baseline_short = df_results.sort_values('Short_NDCG@10', ascending=False).iloc[0]
worst_baseline_short = df_results.sort_values('Short_NDCG@10', ascending=True).iloc[0]
baseline_short_ndcg = best_baseline_short['Short_NDCG@10']
print(f"\nBest Baseline Short NDCG@10: {best_baseline_short['Model']} ({baseline_short_ndcg:.6f})")
print(f"Worst Baseline Short NDCG@10: {worst_baseline_short['Model']} ({worst_baseline_short['Short_NDCG@10']:.6f})")

# Medium sequences
print("\n" + "="*80)
print("MEDIUM SEQUENCES (10-50 items, n=5,872 users):")
print("-"*80)
df_medium = df_results[['Model', 'Model_Type', 'Medium_NDCG@10', 'Medium_HR@10', 'Medium_MRR@10']].copy()
df_medium.columns = ['Model', 'Type', 'NDCG@10', 'HR@10', 'MRR@10']
print(df_medium.sort_values('NDCG@10', ascending=False).to_string(index=False))

# Get best baseline for medium
best_baseline_medium = df_results.sort_values('Medium_NDCG@10', ascending=False).iloc[0]
worst_baseline_medium = df_results.sort_values('Medium_NDCG@10', ascending=True).iloc[0]
baseline_medium_ndcg = best_baseline_medium['Medium_NDCG@10']
print(f"\nBest Baseline Medium NDCG@10: {best_baseline_medium['Model']} ({baseline_medium_ndcg:.6f})")
print(f"Worst Baseline Medium NDCG@10: {worst_baseline_medium['Model']} ({worst_baseline_medium['Medium_NDCG@10']:.6f})")

print("="*80)

# Visualization
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Plot 1: NDCG@10 by sequence length
models = df_results['Model'].values
short_ndcg = df_results['Short_NDCG@10'].values
medium_ndcg = df_results['Medium_NDCG@10'].values
overall_ndcg = df_results['NDCG@10'].values

# Sort by overall NDCG
sort_idx = np.argsort(overall_ndcg)[::-1]
models = models[sort_idx]
short_ndcg = short_ndcg[sort_idx]
medium_ndcg = medium_ndcg[sort_idx]
overall_ndcg = overall_ndcg[sort_idx]

x = np.arange(len(models))
width = 0.25

axes[0].bar(x - width, short_ndcg, width, label='Short (<10)', color='steelblue', alpha=0.7)
axes[0].bar(x, medium_ndcg, width, label='Medium (10-50)', color='navy', alpha=0.7)
axes[0].bar(x + width, overall_ndcg, width, label='Overall', color='gray', alpha=0.7)
axes[0].set_xlabel('Model')
axes[0].set_ylabel('NDCG@10')
axes[0].set_title('NDCG@10 by Sequence Length (Baseline Models)')
axes[0].set_xticks(x)
axes[0].set_xticklabels(models, rotation=45, ha='right')
axes[0].legend()
axes[0].grid(axis='y', alpha=0.3)

# Plot 2: Performance gap analysis (short vs medium)
performance_gaps = []
for idx, row in df_results.iterrows():
    gap = ((row['Medium_NDCG@10'] - row['Short_NDCG@10']) / row['Short_NDCG@10']) * 100
    performance_gaps.append(gap)

x2 = np.arange(len(models))
colors = ['green' if g > 0 else 'red' for g in performance_gaps]
axes[1].bar(x2, performance_gaps, alpha=0.7, color=colors)
axes[1].axhline(y=0, color='black', linestyle='-', linewidth=0.8)
axes[1].set_xlabel('Model')
axes[1].set_ylabel('Performance Gap (%)')
axes[1].set_title('Medium vs Short Sequence Performance Gap (positive = better on medium)')
axes[1].set_xticks(x2)
axes[1].set_xticklabels(models, rotation=45, ha='right')
axes[1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('results/performance_by_length.png', dpi=300, bbox_inches='tight')
print("\n✅ Figure saved: results/performance_by_length.png")
plt.show()

# %% [markdown]
# ## Step 8: Training Dynamics Analysis
#
# Analyze convergence speed, best epochs, and validation performance

# %%
print("="*80)
print("📈 TRAINING DYNAMICS ANALYSIS")
print("="*80)

# Training statistics
training_stats = df_results[['Model', 'Best_Epoch', 'Best_Val_NDCG@10']].copy()
training_stats = training_stats.sort_values('Best_Epoch')

print("\nCONVERGENCE ANALYSIS (sorted by convergence speed):")
print("-"*80)
print(training_stats.to_string(index=False))
print("-"*80)

# Analyze convergence patterns
fastest = training_stats.iloc[0]
slowest = training_stats.iloc[-1]
print(f"\nFastest convergence: {fastest['Model']} (epoch {fastest['Best_Epoch']})")
print(f"Slowest convergence: {slowest['Model']} (epoch {slowest['Best_Epoch']})")
print(f"Average convergence: {training_stats['Best_Epoch'].mean():.1f} epochs")

# Best validation performance
best_val = df_results.sort_values('Best_Val_NDCG@10', ascending=False).iloc[0]
print(f"\nBest validation NDCG@10: {best_val['Model']} ({best_val['Best_Val_NDCG@10']:.6f})")

print("\n" + "="*80)
print("TRAINING CONFIGURATION (consistent across all models):")
print("-"*80)
config_info = df_results.iloc[0]
print(f"  Max epochs: 200")
print(f"  Early stopping patience: 20")
print(f"  Batch size: {config_info['batch_size']}")
print(f"  Learning rate: {config_info['lr']}")
print(f"  Embedding dimension (d_model): {config_info['d_model']}")
print(f"  Attention heads (n_heads): {config_info['n_heads']}")
print(f"  Transformer blocks (n_blocks): {config_info['n_blocks']}")
print(f"  GNN layers: {config_info['gnn_layers']} (for hybrid models)")
print(f"  Dropout: {config_info['dropout']}")
print("="*80)

# Visualization
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Best epoch vs model
models = training_stats['Model'].values
epochs = training_stats['Best_Epoch'].values
axes[0].barh(models, epochs, alpha=0.7, color='steelblue')
axes[0].set_xlabel('Best Epoch')
axes[0].set_ylabel('Model')
axes[0].set_title('Convergence Speed (Lower is Faster)')
axes[0].grid(axis='x', alpha=0.3)

# Plot 2: Validation vs test performance correlation
val_perf = df_results['Best_Val_NDCG@10'].values
test_perf = df_results['NDCG@10'].values
axes[1].scatter(val_perf, test_perf, s=100, alpha=0.7)
for i, model in enumerate(df_results['Model'].values):
    axes[1].annotate(model, (val_perf[i], test_perf[i]), 
                    fontsize=8, ha='right', va='bottom')
axes[1].plot([min(val_perf), max(val_perf)], [min(val_perf), max(val_perf)], 
             'r--', alpha=0.5, label='Perfect correlation')
axes[1].set_xlabel('Validation NDCG@10')
axes[1].set_ylabel('Test NDCG@10')
axes[1].set_title('Validation vs Test Performance')
axes[1].legend()
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('results/training_dynamics.png', dpi=300, bbox_inches='tight')
print("\n✅ Figure saved: results/training_dynamics.png")
plt.show()

# %% [markdown]
# ## Step 9: Computational Cost Analysis
#
# Analyze parameters, memory usage, and training efficiency

# %%
import torch
import sys
sys.path.insert(0, '/kaggle/working/length-adaptive')

from src.models.bert4rec import BERT4Rec
from src.models.sasrec import SASRec
from src.models.gru4rec import GRU4Rec
from src.models.caser import Caser
from src.models.lightgcn import LightGCN

print("="*80)
print("💻 COMPUTATIONAL COST ANALYSIS")
print("="*80)

# Model configurations
num_items = 3706  # MovieLens-1M
d_model = 64
n_heads = 2
n_blocks = 2
gnn_layers = 2
max_len = 50

computational_costs = []

# BERT4Rec baseline
print("\nAnalyzing BERT4Rec...")
model = BERT4Rec(num_items, d_model, n_heads, n_blocks, max_len=max_len)
bert_params = sum(p.numel() for p in model.parameters())
bert_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
computational_costs.append({
    'Model': 'bert4rec',
    'Model_Type': 'Baseline',
    'Total_Params': bert_params,
    'Trainable_Params': bert_trainable,
    'Params_M': bert_params / 1e6
})

# SASRec baseline
print("Analyzing SASRec...")
model = SASRec(num_items, d_model, n_heads, n_blocks, max_len=max_len)
sas_params = sum(p.numel() for p in model.parameters())
sas_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
computational_costs.append({
    'Model': 'sasrec',
    'Model_Type': 'Baseline',
    'Total_Params': sas_params,
    'Trainable_Params': sas_trainable,
    'Params_M': sas_params / 1e6
})

# GRU4Rec baseline
print("Analyzing GRU4Rec...")
model = GRU4Rec(num_items, d_model, n_blocks)
gru_params = sum(p.numel() for p in model.parameters())
gru_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
computational_costs.append({
    'Model': 'gru4rec',
    'Model_Type': 'Baseline',
    'Total_Params': gru_params,
    'Trainable_Params': gru_trainable,
    'Params_M': gru_params / 1e6
})

# Caser baseline
print("Analyzing Caser...")
model = Caser(num_items, d_model, max_len=max_len)
caser_params = sum(p.numel() for p in model.parameters())
caser_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
computational_costs.append({
    'Model': 'caser',
    'Model_Type': 'Baseline',
    'Total_Params': caser_params,
    'Trainable_Params': caser_trainable,
    'Params_M': caser_params / 1e6
})

# LightGCN baseline
print("Analyzing LightGCN...")
from torch_geometric.data import Data
# Create dummy edge index for parameter count
edge_index = torch.tensor([[0, 1], [1, 0]], dtype=torch.long)
model = LightGCN(num_items, d_model, gnn_layers)
gcn_params = sum(p.numel() for p in model.parameters())
gcn_trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
computational_costs.append({
    'Model': 'lightgcn',
    'Model_Type': 'Baseline',
    'Total_Params': gcn_params,
    'Trainable_Params': gcn_trainable,
    'Params_M': gcn_params / 1e6
})

df_costs = pd.DataFrame(computational_costs)

# Add training time from results
df_costs = df_costs.merge(
    df_results[['Model', 'Best_Epoch']], 
    on='Model', 
    how='left'
)

print("\n" + "="*80)
print("MODEL SIZE COMPARISON")
print("="*80)
print("\nBASELINES:")
print(df_costs[['Model', 'Total_Params', 'Params_M']].to_string(index=False))

print("\n" + "="*80)
print("PARAMETER BREAKDOWN:")
print("-"*80)
for idx, row in df_costs.iterrows():
    model = row['Model']
    params = row['Total_Params']
    print(f"{model:30s}: {params:>10,} params")

print("="*80)

# Merge with actual performance
df_costs = df_costs.merge(
    df_results[['Model', 'NDCG@10']], 
    on='Model', 
    how='left'
)

# Calculate efficiency metric: Performance per million parameters
df_costs['Efficiency'] = df_costs['NDCG@10'] / df_costs['Params_M']

print("\nEFFICIENCY ANALYSIS (NDCG@10 per million parameters):")
print("-"*80)
df_efficiency = df_costs[['Model', 'Model_Type', 'NDCG@10', 'Params_M', 'Efficiency']].copy()
df_efficiency = df_efficiency.sort_values('Efficiency', ascending=False)
print(df_efficiency.to_string(index=False))
print("="*80)

# Visualization
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Plot 1: Parameters comparison
models = df_costs['Model'].values
params_m = df_costs['Params_M'].values

# Sort by parameters
sort_idx = np.argsort(params_m)
axes[0].barh(range(len(models)), params_m[sort_idx], color='steelblue', alpha=0.7)
axes[0].set_yticks(range(len(models)))
axes[0].set_yticklabels(models[sort_idx])
axes[0].set_xlabel('Parameters (millions)')
axes[0].set_title('Model Size Comparison (Baseline Models)')
axes[0].grid(axis='x', alpha=0.3)

# Plot 2: Performance vs parameters
ndcg = df_costs['NDCG@10'].values

axes[1].scatter(params_m, ndcg, s=150, alpha=0.7, c='steelblue', marker='o')

for i, model in enumerate(models):
    axes[1].annotate(model, (params_m[i], ndcg[i]), 
                    fontsize=9, ha='right', va='bottom')

axes[1].set_xlabel('Parameters (millions)')
axes[1].set_ylabel('NDCG@10')
axes[1].set_title('Performance vs Model Size (Baseline Models)')
axes[1].grid(alpha=0.3)

plt.tight_layout()
plt.savefig('results/computational_costs.png', dpi=300, bbox_inches='tight')
print("\n✅ Figure saved: results/computational_costs.png")
plt.show()

# %% [markdown]
# ## Step 10: Export Results for Paper
#
# Generate publication-ready tables in multiple formats (CSV, LaTeX, Markdown)

# %%
import os

print("="*80)
print("📝 EXPORTING PUBLICATION-READY TABLES")
print("="*80)

# Create export directory
os.makedirs('paper_results', exist_ok=True)

# 1. Main results table (baseline models only)
main_results = df_results[['Model', 'Model_Type', 'HR@5', 'HR@10', 'HR@20', 
                           'NDCG@5', 'NDCG@10', 'NDCG@20',
                           'MRR@5', 'MRR@10', 'MRR@20', 'Best_Epoch']].copy()

# Save as CSV
main_results.to_csv('paper_results/table1_main_results.csv', index=False, float_format='%.6f')
print("✅ Saved: paper_results/table1_main_results.csv")

# Generate LaTeX table
latex_main = main_results.to_latex(index=False, float_format='%.4f', 
                                   caption='Overall Performance Comparison (Baseline Models)',
                                   label='tab:main_results')
with open('paper_results/table1_main_results.tex', 'w') as f:
    f.write(latex_main)
print("✅ Saved: paper_results/table1_main_results.tex")

# 2. Sequence length analysis
length_analysis = pd.DataFrame({
    'Model': df_results['Model'],
    'Type': df_results['Model_Type'],
    'Short_HR@10': df_results['Short_HR@10'],
    'Short_NDCG@10': df_results['Short_NDCG@10'],
    'Short_MRR@10': df_results['Short_MRR@10'],
    'Medium_HR@10': df_results['Medium_HR@10'],
    'Medium_NDCG@10': df_results['Medium_NDCG@10'],
    'Medium_MRR@10': df_results['Medium_MRR@10'],
})

length_analysis.to_csv('paper_results/table2_length_analysis.csv', index=False, float_format='%.6f')
print("✅ Saved: paper_results/table2_length_analysis.csv")

latex_length = length_analysis.to_latex(index=False, float_format='%.4f',
                                       caption='Performance by Sequence Length (Baseline Models)',
                                       label='tab:length_analysis')
with open('paper_results/table2_length_analysis.tex', 'w') as f:
    f.write(latex_length)
print("✅ Saved: paper_results/table2_length_analysis.tex")

# 3. Computational costs
comp_results = df_costs[['Model', 'Model_Type', 'Total_Params', 'Params_M', 
                         'Best_Epoch', 'NDCG@10', 'Efficiency']].copy()

comp_results.to_csv('paper_results/table3_computational_costs.csv', index=False, float_format='%.6f')
print("✅ Saved: paper_results/table3_computational_costs.csv")

latex_costs = comp_results.to_latex(index=False, float_format='%.4f',
                                    caption='Computational Cost Analysis (Baseline Models)',
                                    label='tab:computational_costs')
with open('paper_results/table3_computational_costs.tex', 'w') as f:
    f.write(latex_costs)
print("✅ Saved: paper_results/table3_computational_costs.tex")

# 4. Create summary markdown
best_model = df_results.iloc[0]
worst_model = df_results.iloc[-1]

summary_md = f"""# Paper Results Summary - Baseline Models

## Dataset
- **Name:** MovieLens-1M
- **Users:** 6,040
- **Items:** 3,706
- **Interactions:** 1,000,209
- **Test Users:** 6,034
- **Short Sequences (<10):** 162 users (2.7%)
- **Medium Sequences (10-50):** 5,872 users (97.3%)

## Models Evaluated (5 baselines)

### Baselines
1. BERT4Rec (bidirectional transformer)
2. SASRec (unidirectional transformer)
3. GRU4Rec (RNN-based)
4. Caser (CNN-based)
5. LightGCN (pure GNN)

## Best Results

### Overall Performance (NDCG@10)
- **Best Baseline:** {best_model['Model']} ({best_model['NDCG@10']:.6f})
- **Worst Baseline:** {worst_model['Model']} ({worst_model['NDCG@10']:.6f})

### Performance Gap
- **NDCG@10:** {((best_model['NDCG@10'] - worst_model['NDCG@10']) / worst_model['NDCG@10'] * 100):.2f}%
- **HR@10:** {((best_model['HR@10'] - worst_model['HR@10']) / worst_model['HR@10'] * 100):.2f}%
- **MRR@10:** {((best_model['MRR@10'] - worst_model['MRR@10']) / worst_model['MRR@10'] * 100):.2f}%

## Key Findings

1. **Best Performing Model:** {best_model['Model']}
   - NDCG@10: {best_model['NDCG@10']:.6f}
   - HR@10: {best_model['HR@10']:.6f}
   - MRR@10: {best_model['MRR@10']:.6f}

2. **Parameter Efficiency:** 
   - Smallest model: {df_costs.loc[df_costs['Total_Params'].idxmin(), 'Model']} ({df_costs['Total_Params'].min():,} parameters)
   - Largest model: {df_costs.loc[df_costs['Total_Params'].idxmax(), 'Model']} ({df_costs['Total_Params'].max():,} parameters)

3. **Convergence Speed:**
   - Average best epoch: {df_results['Best_Epoch'].mean():.1f}
   - Range: {df_results['Best_Epoch'].min()}-{df_results['Best_Epoch'].max()} epochs

## Files Generated

- `table1_main_results` - Overall performance metrics (5 baseline models)
- `table1_main_results` - Overall performance metrics (4 baseline models)
- `table2_length_analysis` - Performance by sequence length
- `table3_computational_costs` - Model size and efficiency

### Figures (PNG, 300 DPI)
- `performance_by_length.png` - NDCG@10 comparison by sequence length
- `training_dynamics.png` - Convergence and validation analysis
- `computational_costs.png` - Parameter and efficiency analysis

### Raw Data
- All experimental results in results/ directory
- Per-model config, history, and results JSON files
"""

with open('paper_results/README.md', 'w') as f:
    f.write(summary_md)
print("✅ Saved: paper_results/README.md")

print("\n" + "="*80)
print("✅ ALL TABLES AND FIGURES EXPORTED")
print("="*80)
print("\nGenerated files:")
print("  📊 3 CSV files (Excel-compatible)")
print("  📄 3 LaTeX files (ready for paper)")
print("  📈 3 PNG figures (300 DPI, publication quality)")
print("  📝 1 Summary README")
print("\nLocation: paper_results/")
print("="*80)

# %% [markdown]
# ## Step 11: Create Downloadable Archive
#
# Package all results, figures, and tables for easy download

# %%
# Create comprehensive results archive
# !mkdir -p final_package

# Copy all paper-ready materials
# !cp -r paper_results final_package/
# !cp -r results/*.png final_package/ 2>/dev/null || true
# !cp results/*_comparison_*.csv final_package/paper_results/ 2>/dev/null || true

# Copy experimental results (baseline models only)
# !mkdir -p final_package/raw_results
# !cp -r results/bert4rec_* final_package/raw_results/ 2>/dev/null || true
# !cp -r results/sasrec_* final_package/raw_results/ 2>/dev/null || true
# !cp -r results/gru4rec_* final_package/raw_results/ 2>/dev/null || true
# !cp -r results/caser_* final_package/raw_results/ 2>/dev/null || true
# !cp -r results/lightgcn_* final_package/raw_results/ 2>/dev/null || true

# Create archive
# !zip -r paper_results_package.zip final_package/

print("="*80)
print("📦 FINAL PACKAGE CREATED")
print("="*80)
print("\n✅ File: paper_results_package.zip")
print("\nContents:")
print("  📁 paper_results/")
print("     ├── table1_main_results.csv + .tex (4 baseline models)")
print("     ├── table2_length_analysis.csv + .tex")
print("     ├── table3_computational_costs.csv + .tex")
print("     ├── performance_by_length.png")
print("     ├── training_dynamics.png")
print("     ├── computational_costs.png")
print("     └── README.md")
print("  📁 raw_results/")
print("     ├── bert4rec_*/")
print("     ├── sasrec_*/")
print("     ├── gru4rec_*/")
print("     └── lightgcn_*/")
print("")
print("📥 Download this file to use in your paper!")
print("="*80)

# Display file size
import os
file_size = os.path.getsize('paper_results_package.zip') / 1024 / 1024

print(f"\nPackage size: {file_size:.2f} MB")print(f"\nPackage size: {file_size:.2f} MB")

# %% [markdown]
# ## 📋 Final Summary
#
# ### ✅ What Was Collected:
#
# 1. **Performance Metrics**
#    - Overall test performance (HR@5/10/20, NDCG@5/10/20, MRR@5/10/20)
#    - Performance by sequence length (short vs medium)
#    - Baseline model comparisons
#
# 2. **Training Analysis**
#    - Convergence speed (best epochs)
#    - Validation performance tracking
#    - Training configuration details
#
# 3. **Computational Costs**
#    - Model parameters (total and trainable) for all 5 baseline models
#    - Parameter comparison analysis
#    - Efficiency metrics (performance per parameter)
#
# 4. **Publication Materials**
#    - CSV tables (Excel-compatible)
#    - LaTeX tables (ready for paper)
#    - High-resolution figures (300 DPI PNG)
#    - Summary documentation
#
# ### 📊 Models Compared:
#
# **Baselines (5):**
# - BERT4Rec
# - SASRec
# - GRU4Rec
# - Caser
# - LightGCN
#
# ### 📥 Next Steps:
#
# 1. Download `paper_results_package.zip`
# 2. Review all tables and figures
# 3. Use LaTeX tables directly in your paper
# 4. Include figures with captions
# 5. Use these baseline results to compare with hybrid models
#
# **Ready for paper submission!** 🎉

# %%
# !zip -r /kaggle/working/.virtual_documents/length-adaptive.zip /kaggle/working/length-adaptive
