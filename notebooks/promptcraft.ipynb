# %% [markdown]
# # PromptCraft Training on MovieLens-1M
#
# This notebook runs PromptCraft experiments with the same preprocessing and training stack used by the project baselines for fair comparison.
#
# Models trained:
# - BERT4Rec baseline (random initialization)
# - PromptCraft P1: title only
# - PromptCraft P2: title + genre
# - PromptCraft P3: user-centric
# - PromptCraft P4: hybrid

# %% [markdown]
# ## Step 1: Clone Repository

# %%
# !git clone https://github.com/faroukq1/length-adaptive.git
# %cd length-adaptive
# !ls -lh scripts/
# Out:
# Cloning into 'length-adaptive'...
# remote: Enumerating objects: 841, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 841 (delta 49), reused 97 (delta 37), pack-reused 724 (from 2)
# Receiving objects: 100% (841/841), 218.73 MiB | 40.57 MiB/s, done.
# Resolving deltas: 100% (355/355), done.
# /kaggle/working/length-adaptive
# total 36K
# -rwxr-xr-x 1 root root 2.0K Apr  7 11:12 merge_kaggle_results.sh
# -rwxr-xr-x 1 root root 2.9K Apr  7 11:12 run_all_experiments.sh
# -rw-r--r-- 1 root root 3.6K Apr  7 11:12 run_baselines.sh
# -rwxr-xr-x 1 root root 4.7K Apr  7 11:12 run_bert_hybrid_experiments.sh
# -rw-r--r-- 1 root root 5.5K Apr  7 11:12 run_paper_experiments.sh
# -rw-r--r-- 1 root root 3.0K Apr  7 11:12 run_promptcraft.sh
# -rw-r--r-- 1 root root 2.0K Apr  7 11:12 setup_kaggle.sh

# %% [markdown]
# ## Step 2: Install Dependencies

# %%
# %pip install -q torch-geometric tqdm scikit-learn pandas matplotlib seaborn transformers sentencepiece

import torch
print('PyTorch:', torch.__version__)
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.9 MB/s eta 0:00:00a 0:00:01
# Note: you may need to restart the kernel to use updated packages.
# PyTorch: 2.10.0+cu128
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# ## Step 3: Run PromptCraft Experiments via Shell Script

# %%
# Optional overrides before running
# %env EPOCHS=200
# %env PATIENCE=20
# %env EMB_BATCH_SIZE=256
# %env EVAL_EVERY=5

# %env DATASET=ml-1m
# %env DATA_PATH=data/ml-1m/processed/sequences.pkl
# %env RAW_DATA_DIR=data/ml-1m/raw
# %env EMB_CACHE_DIR=data/ml-1m/embeddings
# %env MODEL=bert4rec
# %env STYLES=P1_title_only P2_title_genre P3_user_centric P4_hybrid
# %env RUN_BASELINE=1

# !bash scripts/run_promptcraft.sh
# Out:
# env: MODEL=bert4rec
# env: STYLES=P1_title_only P2_title_genre P3_user_centric P4_hybrid
# env: RUN_BASELINE=1
# ...
# PROMPTCRAFT EXPERIMENTS - MOVIELENS-100K
# ...
#
# Working directory: /kaggle/working/length-adaptive
#
# Training config:
#   model=bert4rec, loss=bpr
#   styles=P1_title_only P2_title_genre P3_user_centric P4_hybrid
#   epochs=200, patience=20, batch_size=256
#   lr=0.001, d_model=64, n_heads=2, n_blocks=2
#   max_len=50, dropout=0.2, grad_clip_norm=0.0
#   num_neg_samples=1, hard_neg_ratio=0.0
#   init_mix_alpha=1.0, init_scale=1.0
#   embedding_batch_size=256
#   eval_every=5 (prints once every 5 epochs)
#
# Baseline: enabled
# Running styles: P1_title_only P2_title_genre P3_user_centric P4_hybrid
#
# ...
# PROMPTCRAFT ML-100K EXPERIMENTS
# ...
# Device: cuda
# Model: bert4rec | Loss: bpr
# Styles: P1_title_only, P2_title_genre, P3_user_centric, P4_hybrid
# Epochs: 200 | Patience: 20 | d_model: 64 | negatives: 1 | hard_neg_ratio: 0.0
# ...

# %% [markdown]
# ## Step 4: Inspect and Export Results

# %%
# !ls -lh results/promptcraft/
# !find results -maxdepth 1 -type d -name 'promptcraft_*' | sort
# Out:
# total 16K
# -rw-r--r-- 1 root root 1.2K Apr  7 12:00 summary_20260407_120003.csv
# -rw-r--r-- 1 root root 9.0K Apr  7 12:00 summary_20260407_120003.json
# results/promptcraft_baseline_random_init_20260407_111334
# results/promptcraft_p1_title_only_20260407_112312
# results/promptcraft_p2_title_genre_20260407_113303
# results/promptcraft_p3_user_centric_20260407_114301
# results/promptcraft_p4_hybrid_20260407_115125

# %%
# !zip -r /kaggle/working/promptcraft_results.zip results/promptcraft_* results/promptcraft
# Out:
#   adding: results/promptcraft_baseline_random_init_20260407_111334/ (stored 0%)
#   adding: results/promptcraft_baseline_random_init_20260407_111334/checkpoint_epoch_160.pt (deflated 9%)
#   adding: results/promptcraft_baseline_random_init_20260407_111334/checkpoint_epoch_120.pt (deflated 9%)
#   adding: results/promptcraft_baseline_random_init_20260407_111334/checkpoint_epoch_150.pt (deflated 9%)
#   adding: results/promptcraft_baseline_random_init_20260407_111334/checkpoint_epoch_200.pt (deflated 9%)
#   adding: results/promptcraft_baseline_random_init_20260407_111334/checkpoint.pt (deflated 9%)
#   adding: results/promptcraft_baseline_random_init_20260407_111334/checkpoint_epoch_70.pt (deflated 9%)
#   adding: results/promptcraft_baseline_random_init_20260407_111334/checkpoint_epoch_90.pt (deflated 9%)
#   adding: results/promptcraft_baseline_random_init_20260407_111334/checkpoint_epoch_130.pt (deflated 9%)
# ...
